# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

# %%
uri='http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE028226---'
uri='http://publications.europa.eu/resource/authority/corporate-body/EAEC_COM'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX rdfs:<http://www.w3.org/1999/02/22-rdf-syntax-ns#>
SELECT DISTINCT ?s ?o 
                    where {{?s rdfs:type ?o
                    }
                   filter(?s=<"""+uri+""">).
                   }
                   """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [], 'vars': ['s', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EAEC_COM'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EAEC_COM'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EAEC_COM'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#Corporate'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
SELECT ?entity
WHERE {
  # ?entity rdf:type ?type.
  # ?type rdfs:subClassOf* :C.
}filter(?entity=<"""+uri+""">).

# %%
https://publications.europa.eu/webapi/rdf/sparql?query=%
    0APREFIX%20xsd%3A%20%3Chttp%3A%2F%2Fwww.w3.org%2F2001%2FXMLSchema%23%3E%20%0A%20%20%20%20PREFIX%20skos%3A%20%3Chttp%3A%2F%2Fwww.w3.org%2F2004%2F02%2Fskos%2Fcore%23%3E%0A%20%20%20%20PREFIX%20org%3A%20%3Chttp%3A%2F%2Fwww.w3.org%2Fns%2Forg%23%3E%0A%20%20%20%20PREFIX%20euvoc%3A%20%3Chttp%3A%2F%2Fpublications.europa.eu%2Fontology%2Feuvoc%23%3E%0A%20%20%20%20PREFIX%20foaf%3A%20%3Chttp%3A%2F%2Fxmlns.com%2Ffoaf%2F0.1%2F%3E%0A%20%20%20%20PREFIX%20resource%3A%20%3Chttp%3A%2F%2Fpublications.europa.eu%2Fresource%2F%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20ASK%20where%20%7B%7B%3Fmembership_uri%20org%3Aorganization%20%3FdirectoryOrg_uri%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20euvoc%3ApositionComplement%20%3Fmembership.%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3FdirectoryOrg_uri%20skos%3AprefLabel%20%3FdirectoryOrg.%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Fperson_uri%20org%3AhasMembership%20%3Fmembership_uri%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20foaf%3Aname%20%3Fperson.%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20OPTIONAL%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Fperson_uri%20foaf%3Aimg%20%3Fperson_image%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20resource%3Apersoncitizenship%20%3Fperson_citizUri.%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%3Fperson_citizUri%20skos%3AprefLabel%20%3Fperson_citiz.%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20FILTER(langMatches(lang(%3Fperson_citiz)%2C%20%22en%22)).%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20BIND%20(STRBEFORE(STRAFTER(%20STR(%3Fperson_image)%2C%20%22https%3A%2F%2Fwww.europarl.europa.eu%2Fmepphoto%2F%22%20)%2C%20%22.jpg%22%20)%20AS%20%3Fperson_id)%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23BIND%20(regex(STR(%3Fperson_img)%2C%20%22%5Ehttps%22%2C%20%22i%22)%20AS%20%3Fstr_event)%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20FILTER(STR(%3Fmembership)%3D).%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20filter(%3FdirectoryOrg_uri%3D%3Chttp%3A%2F%2Fpublications.europa.eu%2Fresource%2Fauthority%2Fcorporate-body%2FEP_GROUP_EPP%3E).%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20FILTER(langMatches(lang(%3Fmembership)%2C%20%22en%22)).%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20FILTER(langMatches(lang(%3FdirectoryOrg)%2C%20%22en%22)).%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D&format=json&callback=jQuery3510917775304436196_1633707067186&_=1633707067210

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX resource: <http://publications.europa.eu/resource/>
        SELECT ?membership ?membership_uri ?person ?person_uri (?person AS ?person_name) ?person_gender ?person_genderUri ?person_citiz ?person_image ?person_id
         where {{?membership_uri org:organization ?directoryOrg_uri;
                       euvoc:positionComplement ?membership.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?person_uri org:hasMembership ?membership_uri;
                                foaf:name ?person.
                    OPTIONAL{
                        # ?person_uri foaf:img ?person_image;
                                    resource:personcitizenship ?person_citizUri.
                        # ?person_citizUri skos:prefLabel ?person_citiz.
                        FILTER(langMatches(lang(?person_citiz), "en")).
                        BIND (STRBEFORE(STRAFTER( STR(?person_image), "https://www.europarl.europa.eu/mepphoto/" ), ".jpg" ) AS ?person_id)
                        #BIND (regex(STR(?person_img), "^https", "i") AS ?str_event)
                    }
                    } 
                   FILTER(STR(?membership)='Member').
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_EPP>).
                   FILTER(langMatches(lang(?membership), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   }
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [],
#   'vars': ['membership',
#    'membership_uri',
#    'person',
#    'person_uri',
#    'person_name',
#    'person_gender',
#    'person_genderUri',
#    'person_citiz',
#    'person_image',
#    'person_id']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'membership': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE028226---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Christian EHLER'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE028226'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Christian EHLER'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Germany'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/28226.jpg'},
#     'person_id': {'type': 'literal', 'value': '28226'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE024922---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Pascal ARIMONT'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE024922'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Pascal ARIMONT'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Belgium'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/24922.jpg'},
#     'person_id': {'type': 'literal', 'value': '24922'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE096772---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Peter JAHR'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE096772'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Peter JAHR'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Germany'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/96772.jpg'},
#     'person_id': {'type': 'literal', 'value': '96772'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE001927---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Peter LIESE'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE001927'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Peter LIESE'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Germany'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/1927.jpg'},
#     'person_id': {'type': 'literal', 'value': '1927'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE197455---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Cindy FRANSSEN'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE197455'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Cindy FRANSSEN'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Belgium'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/197455.jpg'},
#     'person_id': {'type': 'literal', 'value': '197455'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE197408---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Hildegard BENTELE'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE197408'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Hildegard BENTELE'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Germany'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/197408.jpg'},
#     'person_id': {'type': 'literal', 'value': '197408'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE197458---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Benoît LUTGEN'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE197458'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Benoît LUTGEN'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Belgium'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/197458.jpg'},
#     'person_id': {'type': 'literal', 'value': '197458'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE028223---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Andreas SCHWAB'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE028223'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Andreas SCHWAB'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Germany'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/28223.jpg'},
#     'person_id': {'type': 'literal', 'value': '28223'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE197410---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Stefan BERGER'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE197410'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Stefan BERGER'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Germany'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/197410.jpg'},
#     'person_id': {'type': 'literal', 'value': '197410'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE099945---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Lena DÜPONT'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE099945'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Lena DÜPONT'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Germany'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/99945.jpg'},
#     'person_id': {'type': 'literal', 'value': '99945'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE096756---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Sabine VERHEYEN'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE096756'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Sabine VERHEYEN'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Germany'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/96756.jpg'},
#     'person_id': {'type': 'literal', 'value': '96756'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE197426---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Sven SIMON'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE197426'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Sven SIMON'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Germany'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/197426.jpg'},
#     'person_id': {'type': 'literal', 'value': '197426'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE002323---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Rainer WIELAND'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE002323'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Rainer WIELAND'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Germany'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/2323.jpg'},
#     'person_id': {'type': 'literal', 'value': '2323'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE096780---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Monika HOHLMEIER'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE096780'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Monika HOHLMEIER'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Germany'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/96780.jpg'},
#     'person_id': {'type': 'literal', 'value': '96780'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE197429---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Marion WALSMANN'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE197429'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Marion WALSMANN'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Germany'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/197429.jpg'},
#     'person_id': {'type': 'literal', 'value': '197429'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE028224---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Markus PIEPER'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE028224'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Markus PIEPER'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Germany'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/28224.jpg'},
#     'person_id': {'type': 'literal', 'value': '28224'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE124806---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'David MCALLISTER'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE124806'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'David MCALLISTER'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Germany'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto
}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE197771---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Vladimír BILČÍK'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE197771'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Vladimír BILČÍK'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Slovakia'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/197771.jpg'},
#     'person_id': {'type': 'literal', 'value': '197771'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE098582---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Loránt VINCZE'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE098582'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Loránt VINCZE'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Romania'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/98582.jpg'},
#     'person_id': {'type': 'literal', 'value': '98582'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE125104---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Romana TOMC'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE125104'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Romana TOMC'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Slovenia'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/125104.jpg'},
#     'person_id': {'type': 'literal', 'value': '125104'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE197649---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Gheorghe FALCĂ'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE197649'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Gheorghe FALCĂ'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Romania'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/197649.jpg'},
#     'person_id': {'type': 'literal', 'value': '197649'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE096933---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Milan ZVER'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE096933'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Milan ZVER'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Slovenia'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/96933.jpg'},
#     'person_id': {'type': 'literal', 'value': '96933'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE197765---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Peter POLLÁK'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE197765'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Peter POLLÁK'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Slovakia'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/197765.jpg'},
#     'person_id': {'type': 'literal', 'value': '197765'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE125004---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Franc BOGOVIČ'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE125004'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Franc BOGOVIČ'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Slovenia'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/125004.jpg'},
#     'person_id': {'type': 'literal', 'value': '125004'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE039725---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Iuliu WINKLER'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE039725'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Iuliu WINKLER'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Romania'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/39725.jpg'},
#     'person_id': {'type': 'literal', 'value': '39725'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE197421---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Isabel WISELER-LIMA'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE197421'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Isabel WISELER-LIMA'},
#     'person_citiz': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Luxembourg'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/197421.jpg'},
#     'person_id': {'type': 'literal', 'value': '197421'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE193419---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Christophe HANSEN'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE193419'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Christophe HANSEN'},
#     'person_citiz': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Luxembourg'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/193419.jpg'},
#     'person_id': {'type': 'literal', 'value': '193419'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE197636---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Ioan-Rareş BOGDAN'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE197636'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Ioan-Rareş BOGDAN'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Romania'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/197636.jpg'},
#     'person_id': {'type': 'literal', 'value': '197636'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE125012---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Daniel BUDA'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE125012'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Daniel BUDA'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Romania'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/125012.jpg'},
#     'person_id': {'type': 'literal', 'value': '125012'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE197637---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Vasile BLAGA'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE197637'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Vasile BLAGA'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Romania'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/197637.jpg'},
#     'person_id': {'type': 'literal', 'value': '197637'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE028294---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Ljudmila NOVAK'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE028294'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Ljudmila NOVAK'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Slovenia'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/28294.jpg'},
#     'person_id': {'type': 'literal', 'value': '28294'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE033982---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Marian-Jean MARINESCU'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE033982'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Marian-Jean MARINESCU'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Romania'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/33982.jpg'},
#     'person_id': {'type': 'literal', 'value': '33982'}},
#    {'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEPPE-DPPE038420---'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Cristian-Silviu BUŞOI'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE038420'},
#     'person_name': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Cristian-Silviu BUŞOI'},
#     'person_citiz': {'type': 'literal', 'xml:lang': 'en', 'value': 'Romania'},
#     'person_image': {'type': 'uri',
#      'value': 'https://www.europarl.europa.eu/mepphoto/38420.jpg'},
#     'person_id': {'type': 'literal', 'value': '38420'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>  
    PREFIX dcterms: <http://purl.org/dc/terms/>  
             select *
             where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:work_is_about_concept_eurovoc/^skos:hasTopConcept ?eurovocTop_uri.
                    # ?eurovocTop_uri euvoc:domain ?eurovocDomain_uri.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri;
                    cdm:expression_title ?text.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # 
},
#     'eurovocDomain': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '10 EUROPEAN UNION'}},
#    ...]}}

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_EPP'
uri2='http://eurovoc.europa.eu/100200'
uri3='http://eurovoc.europa.eu/100148'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>  
    PREFIX dcterms: <http://purl.org/dc/terms/>  
             select ?s ?p ?o
             where {{?s ?p ?o
                    } 
                   FILTER(?s=<"""+uri3+""">).
                   }""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/schema#Domain'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/created'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '1995-10-02'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#versionInfo'},
#     'o': {'type': 'literal', 'value': 'n/a'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/domains'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'es',
#      'value': '24 ASUNTOS FINANCIEROS'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'en', 'value': '24 FINANCE'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'sl', 'value': '24 FINANCE'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'fr', 'value': '24 FINANCES'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'sk', 'value': '24 FINANCIE'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'hr', 'value': '24 FINANCIJE'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'nl', 'value': '24 FINANCIËN'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'sq', 'value': '24 FINANCË'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'lt', 'value': '24 FINANSAI'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'pl', 'value': '24 FINANSE'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'da', 'value': '24 FINANSER'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'sv', 'value': '24 FINANSER'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'lv', 'value': '24 FINANSES'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'fi', 'value': '24 FINANSSIASIAT'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'it', 'value': '24 FINANZE'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'mt', 'value': '24 FINANZI'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'de', 'value': '24 FINANZWESEN'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'pt', 'value': '24 FINANÇAS'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'cs', 'value': '24 FINANČNICTVÍ'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'ro', 'value': '24 FINANŢE'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'hu', 'value': '24 PÉNZÜGYEK'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'et', 'value': '24 RAHANDUS'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'el', 'value': '24 ΔΗΜΟΣΙΟΝΟΜΙΚΑ'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'bg', 'value': '24 ФИНАНСИ'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'sr', 'value': '24 ФИНАНСИЈЕ'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'mk', 'value': '24 ФИНАНСИИ'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'ga', 'value': '24 AIRGEADAS'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/identifier'},
#     'o': {'type': 'literal', 'value': '24'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_fi_7b38af6a'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_ro_748e0b65'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_lv_5b62d001'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_es_18fd6ab9'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_el_e2408941'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_sq_2d9c156f'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_sr_612fd036'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_da_9780e7ef'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_sl_23a7c8c0'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_bg_3b211f8d'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_cs_fd729cd4'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_de_6684ce97'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_en_70ce3ab0'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_et_0e114c89'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_fr_cd48df1e'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_hr_fd05d644'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_hu_7a666e62'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_it_40f42898'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_lt_46e0e263'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_mk_9861d4a4'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_mt_9ed2583f'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_nl_01869a82'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_pl_4bf72630'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_pt_443f42e9'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_sk_4117ad10'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_sv_4552c443'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/xl_ga_6dea010662e8'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#notation'},
#     'o': {'type': 'literal', 'value': '24'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#topConceptOf'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/domains'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#status'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/concept-status/CURRENT'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/note_a090d6958faaa9ebfd3fc6ed85ba4c08'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'p': {'type': 'uri',
#      'value': 'http://purl.org/dc/elements/1.1/identifier'},
#     'o': {'type': 'literal', 'value': '24'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
        PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
        PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
        PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

                #SELECT DISTINCT ?opTheme ?opTheme_uri ?corporateBody ?corporateBody_uri ?opTheme_uri AS ?corporateBody_opTheme (group_concat(distinct ?corporateBody_class;separator="; ") as ?corporateBody_classes)
                SELECT DISTINCT ?opTheme ?opTheme_uri ?corporateBody ?corporateBody_uri ?opTheme_uri AS ?corporateBody_opTheme (group_concat(distinct ?corporateBody_class;separator="; ") as ?corporateBody_classes)
                where {{?publicationDocument_uri cdm:publication_general_is_about_concept_op_theme ?opTheme_uri;
                           cdm:work_authored_by_agent ?corporateBody_uri.
                        # ?opTheme_uri skos:prefLabel ?opTheme.
                        # ?corporateBody_uri skos:prefLabel ?corporateBody;
                            rdfs:type ?corporateBody_class
                        } 
                       filter(?opTheme_uri=<http://publications.europa.eu/resource/authority/pub-theme/I>)
                       FILTER(langMatches(lang(?corporateBody), "en")).
                       FILTER(langMatches(lang(?opTheme), "en")).
                       }ORDER BY ?opTheme ?corporateBody""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [],
#   'vars': ['opTheme',
#    'opTheme_uri',
#    'corporateBody',
#    'corporateBody_uri',
#    'corporateBody_opTheme',
#    'corporateBody_classes']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Commission'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EAEC_COM'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'DG III – Industry'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/DG03'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'DG XXIII – Enterprise Policy, Distributive Trades, Tourism and Cooperatives'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/DG23'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Delegation to Sri Lanka and the Maldives'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/DEL_LKA_MDV'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for the Information Society and Media'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/INFSO'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Internal Market, Industry, Entrepreneurship and SMEs'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/GROW'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Climate Action'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CLIMA'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Communication'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/COMMU'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Energy'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ENER'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Enterprise and Industry'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ENTR'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Environment'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ENV'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Justice and Consumers'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/JUST'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Regional and Urban Policy'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/REGIO'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Research and Innovation'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/RTD'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Economic and Financial Affairs'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ECFIN'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Education, Youth, Sport and Culture'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EAC'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Internal Policies of the Union'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_INTERNAL_POL'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Employment, Social Affairs and Inclusion'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EMPL'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Eurofound'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EUROFOUND'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Central Bank'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ECB'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Chemicals Agency'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ECHA'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Commission'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/COM'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Court of Auditors'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ECA'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Economic and Social Committee'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EESC'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Institute for Gender Equality'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EIGE'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Institute of Innovation and Technology'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EIT'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Investment Bank'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EIB'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Parliament'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Union Agency for Cybersecurity'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ENISA'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European University Institute'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EUI'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Eurostat'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ESTAT'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Executive Agency for Small and Medium-sized Enterprises'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EASME'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for Energy and Transport'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/JRCPETT'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for Environment and Sustainability'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/IES'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for Health and Consumer Protection'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/IHCP'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for Prospective Technological Studies'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/JRCSEV'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for Reference Materials and Measurements'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/JRCGEEL'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for the Protection and Security of the Citizen'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/IPSC'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Joint Research Centre'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/JRC'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Organisation for Economic Co-operation and Development'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/OECD'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Publications Office'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/PUBL'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/2006/vcard/ns#Kind; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Representation in Greece'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/REPRES_GRC'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Safety and Health Commission for the Mining and other Extractive Industries'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/SHCMOEI'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
        PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
        PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
        PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

                #SELECT DISTINCT ?opTheme ?opTheme_uri ?corporateBody ?corporateBody_uri ?opTheme_uri AS ?corporateBody_opTheme (group_concat(distinct ?corporateBody_class;separator="; ") as ?corporateBody_classes)
                SELECT DISTINCT ?opTheme ?opTheme_uri ?corporateBody ?corporateBody_uri ?opTheme_uri AS ?corporateBody_opTheme (group_concat(distinct ?corporateBody_class;separator="; ") as ?corporateBody_classes)
                where {{?publicationDocument_uri cdm:publication_general_is_about_concept_op_theme ?opTheme_uri;
                           cdm:work_authored_by_agent ?corporateBody_uri.
                        # ?opTheme_uri skos:prefLabel ?opTheme.
                        # ?corporateBody_uri skos:prefLabel ?corporateBody;
                            rdfs:type ?corporateBody_class
                        } 
                       filter(?opTheme_uri=<http://publications.europa.eu/resource/authority/pub-theme/I>)
                       FILTER(langMatches(lang(?corporateBody), "en")).
                       FILTER(langMatches(lang(?opTheme), "en")).
                       }ORDER BY ?opTheme ?corporateBody""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [],
#   'vars': ['opTheme',
#    'opTheme_uri',
#    'corporateBody',
#    'corporateBody_uri',
#    'corporateBody_opTheme',
#    'corporateBody_classes']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Commission'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EAEC_COM'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'DG III – Industry'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/DG03'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'DG XXIII – Enterprise Policy, Distributive Trades, Tourism and Cooperatives'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/DG23'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Delegation to Sri Lanka and the Maldives'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/DEL_LKA_MDV'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for the Information Society and Media'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/INFSO'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Internal Market, Industry, Entrepreneurship and SMEs'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/GROW'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Climate Action'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CLIMA'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Communication'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/COMMU'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Energy'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ENER'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Enterprise and Industry'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ENTR'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Environment'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ENV'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Justice and Consumers'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/JUST'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Regional and Urban Policy'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/REGIO'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Research and Innovation'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/RTD'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Economic and Financial Affairs'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ECFIN'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Education, Youth, Sport and Culture'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EAC'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Internal Policies of the Union'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_INTERNAL_POL'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Employment, Social Affairs and Inclusion'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EMPL'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Eurofound'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EUROFOUND'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Central Bank'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ECB'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Chemicals Agency'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ECHA'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Commission'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/COM'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Court of Auditors'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ECA'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Economic and Social Committee'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EESC'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Institute for Gender Equality'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EIGE'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Institute of Innovation and Technology'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EIT'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Investment Bank'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EIB'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Parliament'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Union Agency for Cybersecurity'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ENISA'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European University Institute'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EUI'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Eurostat'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ESTAT'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Executive Agency for Small and Medium-sized Enterprises'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EASME'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for Energy and Transport'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/JRCPETT'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for Environment and Sustainability'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/IES'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for Health and Consumer Protection'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/IHCP'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for Prospective Technological Studies'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/JRCSEV'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for Reference Materials and Measurements'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/JRCGEEL'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for the Protection and Security of the Citizen'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/IPSC'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Joint Research Centre'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/JRC'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Organisation for Economic Co-operation and Development'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/OECD'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Publications Office'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/PUBL'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/2006/vcard/ns#Kind; http://www.w3.org/ns/org#Organization'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Representation in Greece'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/REPRES_GRC'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Safety and Health Commission for the Mining and other Extractive Industries'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/SHCMOEI'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'corporateBody_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

            SELECT DISTINCT ?directoryOrg ?directoryOrg2 ?directoryOrg2_uri ?directoryOrg_order ?directoryOrg_protocolLevel ?directoryOrg_email ?directoryOrg_telephone ?directoryOrg_locality ?directoryOrg_postalCode ?directoryOrg_streetAddress ?directoryOrg_homepage (group_concat(distinct ?directoryOrg2_class;separator="; ") as ?directoryOrg2_classes)
            where {{?directoryOrg_uri org:hasSubOrganization ?directoryOrg2_uri.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?directoryOrg2_uri skos:prefLabel ?directoryOrg2;
                                      rdfs:type ?directoryOrg2_class;
                                      euvoc:order ?directoryOrg_order;
                                      euvoc:protocolLevel ?directoryOrg_protocolLevel.
                                      #euvoc:contactPoint ?directoryOrg_contactPoint.
                    #OPTIONAL {
                    #?directoryOrg_uri2 euvoc:contactPoint ?directoryOrg_contactPoint2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:hasEmail ?directoryOrg_email2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:hasTelephone ?directoryOrg_telephoneBN2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:locality ?directoryOrg_locality2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:postal-code ?directoryOrg_postalCode2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:street-address ?directoryOrg_streetAddress2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 foaf:homepage ?directoryOrg_homepage2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_telephoneBN2 vcard:hasValue ?directoryOrg_telephone2.  
                    #}
                    } 
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP>).
                   FILTER(langMatches(lang(?directoryOrg2), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   }
                   #ORDER BY ?whoiswhoOrg ?country ?location
                   #LIMIT 50""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [],
#   'vars': ['directoryOrg',
#    'directoryOrg2',
#    'directoryOrg2_uri',
#    'directoryOrg_order',
#    'directoryOrg_protocolLevel',
#    'directoryOrg_email',
#    'directoryOrg_telephone',
#    'directoryOrg_locality',
#    'directoryOrg_postalCode',
#    'directoryOrg_streetAddress',
#    'directoryOrg_homepage',
#    'directoryOrg2_classes']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Parliament’s political groups'},
#     'directoryOrg2': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the European People’s Party'},
#     'directoryOrg2_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_EPP'},
#     'directoryOrg_order': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '9'},
#     'directoryOrg_protocolLevel': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'directoryOrg2_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Parliament’s political groups'},
#     'directoryOrg2': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Non-attached Members'},
#     'directoryOrg2_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_NI'},
#     'directoryOrg_order': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '16'},
#     'directoryOrg_protocolLevel': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'directoryOrg2_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Parliament’s political groups'},
#     'directoryOrg2': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'The Left group in the European Parliament — GUE/NGL'},
#     'directoryOrg2_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EP_MEPS/EP_DPPETHELEFT'},
#     'directoryOrg_order': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '15'},
#     'directoryOrg_protocolLevel': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'directoryOrg2_classes': {'type': 'literal',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Parliament’s political groups'},
#     'directoryOrg2': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'directoryOrg2_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg_order': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '12'},
#     'directoryOrg_protocolLevel': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'directoryOrg2_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Parliament’s political groups'},
#     'directoryOrg2': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'},
#     'directoryOrg2_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_order': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '11'},
#     'directoryOrg_protocolLevel': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'directoryOrg2_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Parliament’s political groups'},
#     'directoryOrg2': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Progressive Alliance of Socialists and Democrats in the European Parliament'},
#     'directoryOrg2_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_SD'},
#     'directoryOrg_order': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '10'},
#     'directoryOrg_protocolLevel': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'directoryOrg2_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution; http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Parliament’s political groups'},
#     'directoryOrg2': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Identity and Democracy Group'},
#     'directoryOrg2_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ID'},
#     'directoryOrg_order': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '13'},
#     'directoryOrg_protocolLevel': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'directoryOrg2_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}},
#    {'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Parliament’s political groups'},
#     'directoryOrg2': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Conservatives and Reformists Group'},
#     'directoryOrg2_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ECR'},
#     'directoryOrg_order': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '14'},
#     'directoryOrg_protocolLevel': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'},
#     'directoryOrg2_classes': {'type': 'literal',
#      'value': 'http://publications.europa.eu/ontology/euvoc#Corporate; http://www.w3.org/2004/02/skos/core#Concept; http://www.w3.org/ns/org#Organization'}}]}}

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/EAC'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            SELECT DISTINCT ?s ?p ?o
            where {{?s rdfs:type ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EAC'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EAC'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EAC'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#Organization'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EAC'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#Corporate'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX : <http://publications.europa.eu/ontology/cdm#>

    SELECT DISTINCT ?class ?class_uri ?class_comment ?property ?property_uri ?property_comment
    WHERE 
    {{ ?property_uri rdfs:domain ?class_uri;
         rdfs:label ?property;
         rdfs:comment ?property_comment.
    # ?class_uri rdfs:label ?class;
        rdfs:comment ?class_comment. 
    }filter(?class_uri=<http://publications.europa.eu/ontology/cdm#question_parliamentary>)
    }ORDER BY ?class ?property
        """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['class',
#    'class_uri',
#    'class_comment',
#    'property',
#    'property_uri',
#    'property_comment']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'class': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Parliamentary question'},
#     'class_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary'},
#     'class_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Parliamentary questions (= sector 9 in EUR-Lex)'},
#     'property': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Date of reply'},
#     'property_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary_date_reply'},
#     'property_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Date of the answer of the institution to a parliamentary question. Relevant for legal analysis: true'}},
#    {'class': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Parliamentary question'},
#     'class_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary'},
#     'class_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Parliamentary questions (= sector 9 in EUR-Lex)'},
#     'property': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Nationality of MEP'},
#     'property_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary_nationality_mep'},
#     'property_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Nationality of MEP asking a question. Refers to the nationality of the member of the European Parliament who asked the question. It is mandatory for Parliamentary questions Relevant for legal analysis: true.\nCurrently coded by FD Table 289, could also be a link to a country. Example: 92004E1202. AF (1). AF_GROUP and AF_NAT occur together."\nRelevant for legal analysis: true '}},
#    {'class': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Parliamentary question'},
#     'class_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary'},
#     'class_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Parliamentary questions (= sector 9 in EUR-Lex)'},
#     'property': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Number of session'},
#     'property_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary_number_session'},
#     'property_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'DEPRECATED. Number of session during which this act was debated or voted (EP, EESC, CoR, …). Relevant for legal analysis: true'}},
#    {'class': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Parliamentary question'},
#     'class_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary'},
#     'class_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Parliamentary questions (= sector 9 in EUR-Lex)'},
#     'property': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Parliamentary Querstion asked by parliamentary group'},
#     'property_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary_asked_by_group_parliamentary'},
#     'property_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'This refers to political affiliation and nationality of the Member of the European Parliament who asked the question. \nOriginally coded by FD_290, that shall be replaced by NAL corporate-body. Relevant for legal analysis: true'}},
#    {'class': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Parliamentary question'},
#     'class_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary'},
#     'class_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Parliamentary questions (= sector 9 in EUR-Lex)'},
#     'property': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Parliamentary term'},
#     'property_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary_term_parliamentary'},
#     'property_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'This indicates the Parliamentary term during which an EP document was voted or EP question was raised.\xa0Relevant for legal analysis: true.\nCurrently coded with FD_Table 285. However, only codes are exposed (not decoded), so 01, 02 etc. '}},
#    {'class': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Parliamentary question'},
#     'class_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary'},
#     'class_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Parliamentary questions (= sector 9 in EUR-Lex)'},
#     'property': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Question published?'},
#     'property_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary_published'},
#     'property_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Has this debate ever been published in "EP debates"?\nIndicates if this debate has ever been published in "EP Debates" (examples: 91998H0002, 91998H0001). In this case we have a  manifestation_print with information on the relevant publication, e.g. "Debates of the EP (French ed.):No 514 P. 0193". This type of parliamentary questions was published in the OJ from 1979 to 2000'}}]}}

# %%
uri='http://publications.europa.eu/ontology/cdm#question_parliamentary'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            SELECT DISTINCT ?s ?p ?o
            where {{?
},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal', 'xml:lang': 'en', 'value': '16 ECONOMICS'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100146'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '08 INTERNATIONAL RELATIONS'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100143'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal', 'xml:lang': 'en', 'value': '04 POLITICS'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100142'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal', 'xml:lang': 'en', 'value': '24 FINANCE'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '28 SOCIAL QUESTIONS'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100149'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '44 EMPLOYMENT AND WORKING CONDITIONS'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100153'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '32 EDUCATION AND COMMUNICATIONS'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100150'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal', 'xml:lang': 'en', 'value': '48 TRANSPORT'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100154'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '40 BUSINESS AND COMPETITION'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100152'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '56 AGRICULTURE, FORESTRY AND FISHERIES'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100156'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '52 ENVIRONMENT'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100155'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal', 'xml:lang': 'en', 'value': '68 INDUSTRY'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100160'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '60 AGRI-FOODSTUFFS'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100157'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '64 PRODUCTION, TECHNOLOGY AND RESEARCH'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100158'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal', 'xml:lang': 'en', 'value': '66 ENERGY'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100159'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal', 'xml:lang': 'en', 'value': '72 GEOGRAPHY'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100161'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'eurovoc': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '76 INTERNATIONAL ORGANISATIONS'},
#     'eurovoc_uri': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100162'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'},
#     'eurovoc_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}}]}}

# %%
len(results["results"]["bindings"])
# Out:
# 6

# %%
uri2='http://eurovoc.europa.eu/100161'

# %%
uri3='http://eurovoc.europa.eu/100280'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>  
    PREFIX dcterms: <http://purl.org/dc/terms/>  
    
            SELECT DISTINCT ?eurovocTop ?eurovocTop_uri ?eurovocDomain ?eurovocDomain_uri ?directoryOrg_uri ?directoryOrg
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:work_is_about_concept_eurovoc/^skos:hasTopConcept ?eurovocTop_uri.
                    # ?eurovocTop_uri euvoc:domain ?eurovocDomain_uri.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?eurovocTop_uri skos:prefLabel ?eurovocTop.
                    # ?eurovocDomain_uri skos:prefLabel ?eurovocDomain.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   filter(?eurovocDomain_uri=<"""+uri2+""">).
                   FILTER(langMatches(lang(?eurovocTop), "en")).
                   FILTER(langMatches(lang(?eurovocDomain), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['eurovocTop',
#    'eurovocTop_uri',
#    'eurovocDomain',
#    'eurovocDomain_uri',
#    'directoryOrg_uri',
#    'directoryOrg']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'eurovocTop': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '7211 regions of EU Member States'},
#     'eurovocTop_uri': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/100278'},
#     'eurovocDomain': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '72 GEOGRAPHY'},
#     'eurovocDomain_uri': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/100161'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'eurovocTop': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '7221 Africa'},
#     'eurovocTop_uri': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/100280'},
#     'eurovocDomain': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '72 GEOGRAPHY'},
#     'eurovocDomain_uri': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/100161'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'eurovocTop': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '7231 economic geography'},
#     'eurovocTop_uri': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/100282'},
#     'eurovocDomain': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '72 GEOGRAPHY'},
#     'eurovocDomain_uri': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/100161'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'eurovocTop': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '7206 Europe'},
#     'eurovocTop_uri': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/100277'},
#     'eurovocDomain': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '72 GEOGRAPHY'},
#     'eurovocDomain_uri': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/100161'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'eurovocTop': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '7216 America'},
#     'eurovocTop_uri': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/100279'},
#     'eurovocDomain': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '72 GEOGRAPHY'},
#     'eurovocDomain_uri': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/100161'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'eurovocTop': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '7226 Asia and Oceania'},
#     'eurovocTop_uri': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/100281'},
#     'eurovocDomain': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '72 GEOGRAPHY'},
#     'eurovocDomain_uri': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/100161'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>  
    PREFIX dcterms: <http://purl.org/dc/terms/>  
    
            SELECT DISTINCT ?eurovoc ?eurovocTop ?eurovocDomain ?directoryOrg_uri ?directoryOrg
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:work_is_about_concept_eurovoc ?eurovoc_uri.
                    # ?eurovoc_uri ^skos:hasTopConcept ?eurovocTop_uri.
                    # ?eurovoc_top euvoc:domain ?eurovocDomain_uri.
                            #cdm:work_is_about_concept_eurovoc ?eurovoc_uri.
                            #cdm:resource_legal_id_celex ?parlamentaryQuestion;
                            #cdm:work_date_document ?parlamentaryQuestion_date.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?eurovoc_uri skos:prefLabel ?eurovoc.
                    # ?eurovocTop_uri skos:prefLabel ?eurovocTop.
                    # ?eurovocDomain_uri skos:prefLabel ?eurovocDomain.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   filter(?eurovocDomain_uri=<"""+uri2+""">).
                   filter(?eurovocTop_uri=<"""+uri3+""">).
                   FILTER(langMatches(lang(?eurovoc), "en")).
                   FILTER(langMatches(lang(?eurovocTop), "en")).
                   FILTER(langMatches(lang(?eurovocDomain), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['eurovoc',
#    'eurovocTop',
#    'eurovocDomain',
#    'directoryOrg_uri',
#    'directoryOrg']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'eurovoc': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Africa'},
#     'eurovocTop': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '7221 Africa'},
#     'eurovocDomain': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '72 GEOGRAPHY'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'eurovoc': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'sub-Saharan Africa'},
#     'eurovocTop': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '7221 Africa'},
#     'eurovocDomain': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '72 GEOGRAPHY'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'eurovoc': {'type': 'literal', 'xml:lang': 'en', 'value': 'North Africa'},
#     'eurovocTop': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '7221 Africa'},
#     'eurovocDomain': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': '72 GEOGRAPHY'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>  
    PREFIX dcterms: <http://purl.org/dc/terms/>  
    
            SELECT DISTINCT ?text
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:work_is_about_concept_eurovoc/euvoc:domain ?eurovoc_uri.
                    #?eurovoc_uri ^skos:hasTopConcept ?eurovocTop_uri.
                    #?eurovoc_top euvoc:domain ?eurovocDomain_uri.
                            #cdm:work_is_about_concept_eurovoc ?eurovoc_uri.
                            #cdm:resource_legal_id_celex ?parlamentaryQuestion;
                            #cdm:work_date_document ?parlamentaryQuestion_date.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri;
                    cdm:expression_title ?text.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?eurovoc_uri skos:prefLabel ?eurovoc.
                    #?eurovocTop_uri skos:prefLabel ?eurovocTop.
                    #?eurovocDomain_uri skos:prefLabel ?eurovocDomain.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   filter(?eurovoc_uri=<"""+uri2+""">).
                   #filter(?eurovoc_uri=<"""+uri3+""">).
                   #filter(?eurovocDomain_uri=<"""+uri2+""">).
                   #filter(?eurovocTop_uri=<"""+uri3+""">).
                   FILTER(langMatches(lang(?eurovoc), "en")).
                   #FILTER(langMatches(lang(?eurovocTop), "en")).
                   #FILTER(langMatches(lang(?eurovocDomain), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['text']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>  
    PREFIX dcterms: <http://purl.org/dc/terms/>  
    
            SELECT DISTINCT ?text
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            #cdm:work_is_about_concept_eurovoc/(^skos:hasTopConcept)* ?eurovoc_uri.
                            #(cdm:work_is_about_concept_eurovoc/^skos:hasTopConcept/euvoc:domain)|(cdm:work_is_about_concept_eurovoc/^skos:hasTopConcept)|cdm:work_is_about_concept_eurovoc ?eurovoc_uri.
                    #?eurovoc_uri ^skos:hasTopConcept ?eurovocTop_uri.
                    #?eurovoc_top euvoc:domain ?eurovocDomain_uri.
                            #cdm:work_is_about_concept_eurovoc ?eurovoc_uri.
                            #cdm:resource_legal_id_celex ?parlamentaryQuestion;
                            #cdm:work_date_document ?parlamentaryQuestion_date.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri;
                    cdm:expression_title ?text.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?eurovoc_uri skos:prefLabel ?eurovoc.
                    # ?eurovocTop_uri skos:prefLabel ?eurovocTop.
                    # ?eurovocDomain_uri skos:prefLabel ?eurovocDomain.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   filter(?eurovoc_uri=<"""+uri2+""">).
                   #filter(?eurovocTop_uri=<"""+uri3+""">).
                   FILTER(langMatches(lang(?eurovoc), "en")).
                   #FILTER(langMatches(lang(?eurovocTop), "en")).
                   #FILTER(langMatches(lang(?eurovocDomain), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   }
    """)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#    1072             else:
# -> 1073                 response = urlopener(request)
#    1074             return response, self.returnFormat
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 400: Bad Request
#
# During handling of the above exception, another exception occurred:
#
# QueryBadFormed                            Traceback (most recent call last)
# <ipython-input-115-ec7c5549ba22> in <module>
#      37     """)
#      38 sparql.setReturnFormat(JSON)
# ---> 39 results = sparql.query().convert()
#      40 results
#
# /usr/local/lib/python3.7/site-packages/SPARQLWrapper/Wrapper.py in query(self)
#    1105             :rtype: :class:`QueryResult` instance
#    1106         """
# -> 1107         return QueryResult(self._query())
#    1108
#    1109     def queryAndConvert(self):
#
# /usr/local/lib/python3.7/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#    1075         except urllib.error.HTTPError as e:
#    1076             if e.code == 400:
# -> 1077                 raise QueryBadFormed(e.read())
#    1078             elif e.code == 404:
#    1079                 raise EndPointNotFound(e.read())
#
# QueryBadFormed: QueryBadFormed: a bad request has been sent to the endpoint, probably the sparql query is bad formed.
#
# Response:
# b'Virtuoso 37000 Error SP030: SPARQL compiler, line 20: syntax error at \'?parlamentaryQuestion_uri\' before \';\'\n\nSPARQL query:\n\n#output-format:application/sparql-results+json\n\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#> \n    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>\n    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>\n    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>\n    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>  \n    PREFIX dcterms: <http://purl.org/dc/terms/>  \n    \n            SELECT DISTINCT ?text\n            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;\n                            #cdm:work_is_about_concept_eurovoc/(^skos:hasTopConcept)* ?eurovoc_uri.\n                            #(cdm:work_is_about_concept_eurovoc/^skos:hasTopConcept/euvoc:domain)|(cdm:work_is_about_concept_eurovoc/^skos:hasTopConcept)|cdm:work_is_about_concept_eurovoc ?eurovoc_uri.\n                    #?eurovoc_uri ^skos:hasTopConcept ?eurovocTop_uri.\n                    #?eurovoc_top euvoc:domain ?eurovocDomain_uri.\n                            #cdm:work_is_about_concept_eurovoc ?eurovoc_uri.\n                            #cdm:resource_legal_id_celex ?parlamentaryQuestion;\n                            #cdm:work_date_document ?parlamentaryQuestion_date.\n                    ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;\n                    cdm:expression_uses_language ?expression_languageUri;\n                    cdm:expression_title ?text.\n                    ?directoryOrg_uri skos:prefLabel ?directoryOrg.\n                    ?eurovoc_uri skos:prefLabel ?eurovoc.\n                    ?eurovocTop_uri skos:prefLabel ?eurovocTop.\n                    ?eurovocDomain_uri skos:prefLabel ?eurovocDomain.\n                    } \n                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA>).\n                   filter(?eurovoc_uri=<http://eurovoc.europa.eu/100161>).\n                   #filter(?eurovocTop_uri=<http://eurovoc.europa.eu/100280>).\n                   FILTER(langMatches(lang(?eurovoc), "en")).\n                   #FILTER(langMatches(lang(?eurovocTop), "en")).\n                   #FILTER(langMatches(lang(?eurovocDomain), "en")).\n                   FILTER(langMatches(lang(?directoryOrg), "en")).\n                   FILTER(str(?expression_languageUri)=\'http://publications.europa.eu/resource/authority/language/ENG\').\n                   }\n    '

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>  
    PREFIX dcterms: <http://purl.org/dc/terms/>  
    
            SELECT DISTINCT ?text
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:work_is_about_concept_eurovoc/^skos:hasTopConcept/euvoc:domain ?eurovocDomain_uri.
                            #cdm:work_is_about_concept_eurovoc ?eurovoc_uri.
                            #cdm:resource_legal_id_celex ?parlamentaryQuestion;
                            #cdm:work_date_document ?parlamentaryQuestion_date.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri;
                    cdm:expression_title ?text.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?eurovocDomain_uri skos:prefLabel ?eurovocDomain.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   filter(?eurovocDomain_uri=<"""+uri2+""">).
                   FILTER(langMatches(lang(?eurovocDomain), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['text']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-004949/11 Marisa Matias (GUE/NGL) and Philippe Lamberts (Verts/ALE) to the Commission. Quarries in Natura\xa02000 area, Monchique, Portugal'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'WRITTEN QUESTION E-2456/01 by Camilo Nogueira Román (Verts/ALE) to the Commission. Statements by the Spanish Finance Minister on the tax raison powers of the Spanish Autonomous communities.'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-006904/11 Frieda Brepoels (Verts/ALE) to the Council. Attendance of dignitaries at the beatification of Pope John Paul II '}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-011172/10 Sven Giegold (Verts/ALE) to the Commission. Public debt of EU Member States'}},
#    {'text': {'type': 'literal',
#      'value': 'Written question E-1090/10 by Michail Tremopoulos (Verts/ALE) to the Commission. Greenhouse gases and soil management'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-004874/12 Andrea Zanoni (ALDE), Bart Staes (Verts/ALE), Niccolò Rinaldi (ALDE), Giommaria Uggias (ALDE), Nadja Hirsch (ALDE), Carl Schlyter (Verts/ALE), Raül Romeva i Rueda (Verts/ALE), Sabine Wils (GUE/NGL), Pavel Poc (S&D), Dan Jørgensen (S&D) and Bas Eickhout (Verts/ALE) to the Commission. Bird poaching in Ischia and Procida during migratory spring season — failure to take action and prevent the phenomenon, violating the Birds Directive\xa02009/147/EC'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'WRITTEN QUESTION E-
}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-008577/12 Ian Hudghton (Verts/ALE) to the Commission. Winter tyres across the EU'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-010851/12 Bart Staes (Verts/ALE) and Kathleen Van Brempt (S&D) to the Commission. Measures to combat waste incineration overcapacity in order to prevent dumping tariffs'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-005958/13 Isabella Lövin (Verts/ALE) and Raül Romeva i Rueda (Verts/ALE) to the Commission. Article\xa016 of the basic regulation of the CFP'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-013974/13 Gerben-Jan Gerbrandy (ALDE), Karl-Heinz Florenz (PPE), Jo Leinen (S&D) and Bas Eickhout (Verts/ALE) to the Commission. Importance of the Guiana Shield Facility'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': "Written question E-001569/12 Raül Romeva i Rueda (Verts/ALE) to the Commission. The new Spanish government's water policy"}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-012627/11 Michail Tremopoulos (Verts/ALE) to the Commission. Reduced VAT rates and islands'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-008792/12 Alyn Smith (Verts/ALE) to the Commission. National Roma integration strategies'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-010717/13 Ian Hudghton (Verts/ALE) to the Commission. Reducing the carbon footprint in Europe'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>  
    PREFIX dcterms: <http://purl.org/dc/terms/>  
    
            ASK where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:work_is_about_concept_eurovoc/^skos:hasTopConcept/euvoc:domain ?eurovocDomain_uri.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?eurovocDomain_uri skos:prefLabel ?eurovocDomain.
                    } 
                   filter(?directoryOrg_uri=<http://eurovoc.europa.eu/100145>).
                   FILTER(langMatches(lang(?eurovocDomain), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': []}, 'boolean': False}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>  
    PREFIX dcterms: <http://purl.org/dc/terms/>  
    
            SELECT DISTINCT ?text
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:work_is_about_concept_eurovoc ?eurovoc_uri.
                    # ?eurovoc_uri ^skos:hasTopConcept ?eurovocTop_uri.
                    # ?eurovoc_top euvoc:domain ?eurovocDomain_uri.
                            #cdm:work_is_about_concept_eurovoc ?eurovoc_uri.
                            #cdm:resource_legal_id_celex ?parlamentaryQuestion;
                            #cdm:work_date_document ?parlamentaryQuestion_date.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri;
                    cdm:expression_title ?text.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?eurovoc_uri skos:prefLabel ?eurovoc.
                    # ?eurovocTop_uri skos:prefLabel ?eurovocTop.
                    # ?eurovocDomain_uri skos:prefLabel ?eurovocDomain.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   filter(?eurovocDomain_uri=<"""+uri2+""">).
                   #filter(?eurovocTop_uri=<"""+uri3+""">).
                   FILTER(langMatches(lang(?eurovoc), "en")).
                   FILTER(langMatches(lang(?eurovocTop), "en")).
                   FILTER(langMatches(lang(?eurovocDomain), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['text']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'WRITTEN QUESTION P-0575/02 by Carlos Bautista Ojeda (Verts/ALE) to the Council. Council position on the situation in Western Sahara.'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'WRITTEN QUESTION E-0432/01 by Camilo Nogueira Román (Verts/ALE) to the Commission. EU participation in new Indian Ocean multilateral fisheries organisation.'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'WRITTEN QUESTION E-3772/00 by Patricia McKenna (Verts/ALE) to the Commission. Law reform in Russia.'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'WRITTEN QUESTION P-1681/02 by Bart Staes (Verts/ALE) to the Commission. Entry documents for Kosovo.'}},
#    {'text': {'type': 'literal',
#      'value': 'WRITTEN QUESTION E-1375/03 by Bart Staes (Verts/ALE) to the Commission. Radioactive contamination of mineworkers in Shinkolobwe heterogenite mines.'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'WRITTEN QUESTION E-2869/00 by Camilo Nogueira Román (Verts/ALE) to the Commission. Fishing in Latin American southern Pacific waters outside the 200-mile zone.'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'WRITTEN QUESTION E-3634/02 by Miquel Mayol i Raynal (Verts/ALE) to the Commission. Association Agreement between the EU and Chile and respect for the rights of the Mapuche people.'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'WRITTEN QUESTION E-4061/00 by Patricia McKenna (Verts/ALE) to the Council. Falun Gong.'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'WRITTEN QUESTION E-0589/03 by Miquel Mayol i Raynal (Verts/ALE) to the Commission. Freedom of association in Romania.'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'WRITTEN QUESTION E-3026/02 by Patricia McKenna (Verts/ALE) to the Council. EU-Sudan relations.'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'WRITTEN QUESTION E-4062/00 by Patricia McKenna (Verts/ALE) to the Commission. Falun Gong.'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': "WRITTEN QUEST
}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-008085/12 Chris Davies (ALDE), Gerben-Jan Gerbrandy (ALDE), Jo Leinen (S&D), Satu Hassi (Verts/ALE), Bas Eickhout (Verts/ALE) and Linda McAvan (S&D) to the Council. Basis for reaching Council ‘conclusions’, including those concerning international agreements'}},
#    ...]}}

# %%
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
            SELECT DISTINCT ?text
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:resource_legal_is_about_subject-matter ?subjectMatter_uri;
                            cdm:resource_legal_id_celex ?parlamentaryQuestion.
                            #cdm:work_date_document ?parlamentaryQuestion_date.
                    # ?expression_uri cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                            cdm:expression_uses_language ?expression_languageUri;
                            cdm:expression_title ?text.
                    #cdm:expression_uses_language ?expression_languageUri.
                    # ?manifestation cdm:manifestation_manifests_expression ?expression_uri;
                                cdm:manifestation_type ?manifestation_type.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?subjectMatter_uri skos:prefLabel ?subjectMatter.
                    } 
                   filter(?directoryOrg_uri=<PARAMETER2>).
                   filter(?subjectMatter_uri=<PARAMETER>).
                   FILTER(langMatches(lang(?subjectMatter), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   #filter(?expression_languageUri=<http://publications.europa.eu/resource/authority/language/ENG>)
                   }

# %%
uri='http://eurovoc.europa.eu/1158'
uri='http://eurovoc.europa.eu/100141'
uri='http://eurovoc.europa.eu/1092'
uri='http://eurovoc.europa.eu/1021'
#uri='http://eurovoc.europa.eu/6029'
#uri='http://eurovoc.europa.eu/100206'

# %%
uri='http://eurovoc.europa.eu/100148'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>  
    PREFIX dcterms: <http://purl.org/dc/terms/>  
    
            SELECT DISTINCT ?s ?o
            where {{?s skos:inScheme ?o
                    } 
                   filter(?s=<"""+uri+""">).

                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/100148'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/domains'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>  
    PREFIX dcterms: <http://purl.org/dc/terms/>  
    
            SELECT DISTINCT ?label_s ?o ?label
            where {{?s skos:topConceptOf/euvoc:domain ?o;
                    skos:prefLabel ?label_s.
                    # ?o skos:prefLabel ?label.
                    } 
                   filter(?s=<"""+uri+""">).
                   FILTER(langMatches(lang(?label), "en")).
                   FILTER(langMatches(lang(?label_s), "en")).
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['label_s', 'o', 'label']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'label_s': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'tax system'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100148'},
#     'label': {'type': 'literal', 'xml:lang': 'en', 'value': '24 FINANCE'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>  
    PREFIX dcterms: <http://purl.org/dc/terms/>  
    
            SELECT DISTINCT ?p
            where {{?s ?p ?o
                    } 
                   filter(?s=<"""+uri+""">).
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['p']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2002/07/owl#versionInfo'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'}},
#    {'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/hasPart'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#hasTopConcept'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>  
    PREFIX dcterms: <http://purl.org/dc/terms/>  
    
            SELECT DISTINCT ?s ?p ?o
            where {{?s ?p ?o
                    } 
                   filter(?s=<"""+uri+""">).
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2002/07/owl#NamedIndividual'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#ConceptScheme'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://eurovoc.europa.eu/schema#Thesaurus'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'literal', 'xml:lang': 'en', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#versionInfo'},
#     'o': {'type': 'literal', 'value': '4.13'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'en', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'da', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'de', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'it', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'nl', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'fr', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'sl', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'bg', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'sk', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'el', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'sv', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'pt', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'lt', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'ro', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'hr', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'es', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'pl', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'lv', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'cs', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'mt', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'et', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'fi', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'hu', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'sr', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'mk', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'sq', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal', 'xml:lang': 'ga', 'value': 'EuroVoc'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001550'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001551'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001552'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001553'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001554'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001555'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001556'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001557'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001558'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001559'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001560'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001561'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001562'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001563'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001564'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001565'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001566'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001541'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001542'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001543'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001544'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001545'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001546'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001547'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001548'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1001549'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/xl_ga_35ea8912'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/hasPart'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100176'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/hasPart'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100205'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/hasPart'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100251'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/hasPart'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100267'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/hasPart'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100185'}},
#    {'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/100141'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/hasPart'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/
},
#     'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/074020'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Products processed from fruit and vegetables'},
#     'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/036063'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Relations in the context of the General Agreement on Tariffs and Trade (GATT)'},
#     'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/113010'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Bank for Reconstruction and Development'},
#     'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/115010'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Taxation'},
#     'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/07304030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>

            SELECT DISTINCT ?conceptDirectoryCode_uri ?directoryOrg_uri ?directoryOrg
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:resource_legal_is_about_concept_directory-code/^skos:narrower ?conceptDirectoryCode_uri.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    #?conceptDirectoryCodeBroader_uri skos:narrower+ ?conceptDirectoryCode_uri;
                    #    skos:prefLabel ?conceptDirectoryCodeBroader.
                    #} 
                    }
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   #FILTER(langMatches(lang(?conceptDirectoryCodeBroader), "en")).
                   #FILTER(langMatches(lang(?conceptDirectoryCode), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['conceptDirectoryCode_uri', 'directoryOrg_uri', 'directoryOrg']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/01'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0350'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0930'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1510'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/151020'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/15'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/052005'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/114010'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1140'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1210'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/12'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1310'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1320'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1330'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/16'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/17'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1910'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/05'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/07'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0740'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/151030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0520'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0420'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0140'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1520'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/10'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/11'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0320'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/19'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/09'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/06'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/062020'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/08'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1160'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1610'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/13'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/072040'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1130'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0710'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1170'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1930'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0410'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/14'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0330'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/052030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0360'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1240'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/052040'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/117020'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/20'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/052020'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/072030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1250'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0310'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/191030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0630'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/073040'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/03'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/04'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/041030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/116030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/074020'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0720'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0620'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0920'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0730'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/024010'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0220'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/116040'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/117040'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/074050'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/131030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0370'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1730'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1150'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/133014'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0820'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/02'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1440'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/062010'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCode_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/023030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}}]}}

# %%
len(results["results"]["bindings"])
# Out:
# 83

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?subjectMatter ?subjectMatter_uri ?directoryOrg_uri ?directoryOrg
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:resource_legal_is_about_subject-matter ?subjectMatter_uri.
                    # ?subjectMatter_uri skos:prefLabel ?subjectMatter.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   FILTER(langMatches(lang(?subjectMatter), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['subjectMatter',
#    'subjectMatter_uri',
#    'directoryOrg_uri',
#    'directoryOrg']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture and Fisheries'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/AGRI'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'State aids'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/AIDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Development cooperation'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/CDEV'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Citizenship of the Union'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/CIT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Judicial cooperation in criminal matters'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/COJP'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Competition'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/CONC'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Cooperation'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/COOP'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Foodstuffs'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/D-AL'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Environment'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/ENV'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'External relations'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/EXT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Financial provisions'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/FIN'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Taxation'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/FISC'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Information and verification'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/INFO'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Provisions governing the Institutions'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/INST'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Justice and home affairs'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/J-AI'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Free movement of workers'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/LCT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Freedom of establishment'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/LES'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Internal market - Principles'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/MARI'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Commercial policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PCOM'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Fisheries policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PECH'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Common foreign and security policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PESC'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Small and medium-sized enterprises'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PME'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Consumer protection'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PROT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Research and technological development'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/RDT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Public health'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/SANT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Social security for migrant workers'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/SESO'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Transport'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/TRAN'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Veterinary legislation'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/VETE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Food aid'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/ALIM'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Human rights'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/DDLH'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Area of freedom, security and justice'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/ELSJ'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Energy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/ENER'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Immigration and asylum policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/IMMI'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Free movement of persons'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/LCP'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Plant health legislation'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PHYT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Principles, objectives and tasks of the Treaties'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PRIN'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Intellectual, industrial and commercial property'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PROP'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Trans-European networks'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/RTR'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Social provisions'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/SOCI'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agricultural structures'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/STRA'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Telecommunications'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/TELE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Economic and Monetary Union'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/UEM'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Culture'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/CULT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Education, vocational training and youth'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/EFPJ'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Investments'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/INV'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Regional policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PREG'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Seeds and seedlings'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/SEME'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Anti-discrimination'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/DISC'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Free movement of capital'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/LCC'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Safety at work and elsewhere'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/SECU'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Employment'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/EMPL'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Public procurement in the European Union'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/MARC'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Monetary measures in the field of agriculture'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/MONA'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Nuclear common market'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/NUCL'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Economic policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PECO'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Economic and monetary policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PEM'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'World Trade Organization'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/OMC'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Tobacco'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/TABA'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Euro'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/EURO'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Forestry'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/SILV'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Humanitarian aid'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/HUMA'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industrial policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PIND'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Sport'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/SPOR'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Tourism'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/TOUR'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Dissemination of information'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/DIFF'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Electronic data processing'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/INFQ'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'International agreements'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/ACIN'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Police cooperation'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/COPO'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Area of freedom, security and justice'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/ELSJ'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Education, vocational training and youth'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/EFPJ'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Employment'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/EMPL'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Financial provisions'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/FIN'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Provisions governing the Institutions'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/INST'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Public procurement in the European Union'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/MARC'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Regional policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/PREG'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Principles, objectives and tasks of the Treaties'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/PRIN'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Trans-European networks'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/RTR'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Monetary measures in the field of agriculture'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/MONA'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Consumer protection'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/PROT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Citizenship of the Union'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/CIT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Culture'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/CULT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Regional Development Fund (ERDF)'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/FEDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Harmonisation of laws'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/HARM'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Approximation of laws'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/RAPL'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Immigration and asylum policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/IMMI'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Intellectual, industrial and commercial property'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/PROP'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Public health'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/SANT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture and Fisheries'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/AGRI'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Energy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/ENER'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Taxation'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/FISC'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Environment'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/ENV'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Free movement of workers'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/LCT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Asylum policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/ASIL'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'External relations'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/EXT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Humanitarian aid'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/HUMA'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Freedom of establishment'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/LES'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Social provisions'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/SOCI'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
# ...
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Economic and Monetary Union'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/UEM'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Beef and veal'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/BOV'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Customs Union'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/UD'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Civil protection'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PCIV'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Conservation of marine biological resources'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/CRBM'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Quotas - third countries'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/CONT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Development Fund (EDF)'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/FED'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'African, Caribbean and Pacific States (ACP)'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/ACP'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Agricultural Guidance and Guarantee Fund (EAGGF)'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/FEOG'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Judicial cooperation in civil matters'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/COJC'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Alcohol'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/ALCO'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Dominant position'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/POSI'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Plants and flowers'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/P-F'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Scientific and technical information and documentation'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/IDST'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Value added tax'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/TVA'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Small and medium-sized enterprises'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/PME'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Freedom to provide services'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/SERV'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Food aid'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/ALIM'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Investments'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/INV'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Common organisation of agricultural markets'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/OCM'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Preferential systems'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/RPRE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'General Agreement on Tariffs and Trade (GATT)'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/GATT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Products from third countries'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/MEXT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European political cooperation'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/COPE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Steel'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/ACIE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Milk products'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/LAIT'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Tobacco'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/TABA'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Dominant position'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/POSI'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Investment Bank (EIB)'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/BEI'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Alcohol'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/ALCO'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Free movement of capital'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/LCC'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Civil protection'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/PCIV'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}}]}}

# %%
uri='http://publications.europa.eu/resource/authority/fd_070/COJP'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?subjectMatter_uri ?broader
            where {{?subjectMatter_uri skos:broader ?broader.
                    #?subjectMatter_uri skos:prefLabel ?subjectMatter.
                    #?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    } 
                   filter(?subjectMatter_uri=<"""+uri+""">).
                   #FILTER(langMatches(lang(?subjectMatter), "en")).
                   #FILTER(langMatches(lang(?directoryOrg), "en")).
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['subjectMatter_uri', 'broader']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
uri='http://publications.europa.eu/resource/authority/fd_555/15103030'
uri='http://eurovoc.europa.eu/1092'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?s ?p ?o
            where {{?s skos:broader ?o.
                    } 
                   filter(?s=<"""+uri+""">).
                   #FILTER(langMatches(lang(?subjectMatter), "en")).
                   #FILTER(langMatches(lang(?directoryOrg), "en")).
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1092'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/3944'}}]}}

# %%
len(results["results"]["bindings"])
# Out:
# 240

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?subjectMatter ?subjectMatter_uri ?directoryOrg_uri ?directoryOrg
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:resource_legal_is_about_subject-matter ?subjectMatter_uri.
                    # ?subjectMatter_uri skos:prefLabel ?subjectMatter.
                            #cdm:work_is_about_concept_eurovoc ?eurovoc_uri.
                            #cdm:resource_legal_id_celex ?parlamentaryQuestion;
                            #cdm:work_date_document ?parlamentaryQuestion_date.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    #?eurovoc_uri skos:prefLabel ?eurovoc;
                    #        skos:inScheme ?eurovocThesauri_uri.
                    #?eurovocThesauri_uri skos:prefLabel ?eurovocThesauri.
                    #        euvoc:domain ?eurovocDomain_uri.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   FILTER(langMatches(lang(?subjectMatter), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-21-c8f05edafbc8> in <module>
#      30
#      31 sparql.setReturnFormat(JSON)
# ---> 32 results = sparql.query().convert()
#      33 results
#
# /usr/local/lib/python3.7/site-packages/SPARQLWrapper/Wrapper.py in query(self)
#    1105             :rtype: :class:`QueryResult` instance
#    1106         """
# -> 1107         return QueryResult(self._query())
#    1108
#    1109     def queryAndConvert(self):
#
# /usr/local/lib/python3.7/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#    1071                 response = urlopener(request, timeout=self.timeout)
#    1072             else:
# -> 1073                 response = urlopener(request)
#    1074             return response, self.returnFormat
#    1075         except urllib.error.HTTPError as e:
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#    1321         except:
#
# URLError: <urlopen error [Errno 8] nodename nor servname provided, or not known>

# %%
len(results["results"]["bindings"])
# Out:
# 240

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>

            SELECT DISTINCT ?conceptDirectoryCode ?conceptDirectoryCode_uri ?directoryOrg_uri ?directoryOrg
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:resource_legal_is_about_concept_directory-code ?conceptDirectoryCode_uri.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?conceptDirectoryCode_uri skos:narrower+ ?conceptDirectoryCode_uri;
                        skos:prefLabel ?conceptDirectoryCode.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   FILTER(langMatches(lang(?conceptDirectoryCode), "en")).
                   #FILTER(langMatches(lang(?conceptDirectoryCode), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#    1072             else:
# -> 1073                 response = urlopener(request)
#    1074             return response, self.returnFormat
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 500: SPARQL Request Failed
#
# During handling of the above exception, another exception occurred:
#
# EndPointInternalError                     Traceback (most recent call last)
# <ipython-input-91-71b9fb9b8a54> in <module>
#      26
#      27 sparql.setReturnFormat(JSON)
# ---> 28 results = sparql.query().convert()
#      29 results
#
# /usr/local/lib/python3.7/site-packages/SPARQLWrapper/Wrapper.py in query(self)
#    1105             :rtype: :class:`QueryResult` instance
#    1106         """
# -> 1107         return QueryResult(self._query())
#    1108
#    1109     def queryAndConvert(self):
#
# /usr/local/lib/python3.7/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#    1083                 raise URITooLong(e.read())
#    1084             elif e.code == 500:
# -> 1085                 raise EndPointInternalError(e.read())
#    1086             else:
#    1087                 raise e
#
# EndPointInternalError: EndPointInternalError: endpoint returned code 500 and response.
#
# Response:
# b'Virtuoso 37000 Error SQ156: Internal Optimized compiler error : unknown table for a column dfe in sqldf.c:1529.\nPlease report the statement compiled.\n\nSPARQL query:\n\n#output-format:application/sparql-results+json\n\n    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> \n    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>\n    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>\n    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>\n    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>\n\n            SELECT DISTINCT ?conceptDirectoryCode ?conceptDirectoryCode_uri ?directoryOrg_uri ?directoryOrg\n            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;\n                            cdm:resource_legal_is_about_concept_directory-code ?conceptDirectoryCode_uri.\n                    ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;\n                    cdm:expression_uses_language ?expression_languageUri.\n                    ?directoryOrg_uri skos:prefLabel ?directoryOrg.\n                    ?conceptDirectoryCode_uri skos:narrower+ ?conceptDirectoryCode_uri;\n                        skos:prefLabel ?conceptDirectoryCode.\n                    } \n                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA>).\n                   FILTER(langMatches(lang(?conceptDirectoryCode), "en")).\n                   #FILTER(langMatches(lang(?conceptDirectoryCode), "en")).\n                   FILTER(langMatches(lang(?directoryOrg), "en")).\n                   FILTER(str(?expression_languageUri)=\'http://publications.europa.eu/resource/authority/language/ENG\').\n                   }\n    '

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>

            SELECT DISTINCT ?conceptDirectoryCodeBroader ?conceptDirectoryCodeBroader_uri ?directoryOrg_uri ?directoryOrg
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:resource_legal_is_about_concept_directory-code ?conceptDirectoryCode_uri.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?conceptDirectoryCodeBroader_uri skos:narrower+ ?conceptDirectoryCode_uri;
                        skos:prefLabel ?conceptDirectoryCodeBroader.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   FILTER(langMatches(lang(?conceptDirectoryCodeBroader), "en")).
                   #FILTER(langMatches(lang(?conceptDirectoryCode), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   }ORDER BY ?conceptDirectoryCodeBroader
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['conceptDirectoryCodeBroader',
#    'conceptDirectoryCodeBroader_uri',
#    'directoryOrg_uri',
#    'directoryOrg']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Action in favour of countries in transition'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1150'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agricultural structural funds'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0320'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agricultural structures'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0330'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/03'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Aid to developing countries'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/117020'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Air transport'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0740'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Application of the Common Customs Tariff'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0230'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Approximation of laws and health measures'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0350'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Area of freedom, security and justice'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/19'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Associations'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/117040'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Asylum policy'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/191030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Autonomous regional action'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1440'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Basic customs instruments'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0220'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Basic provisions'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0310'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Bilateral agreements with non-member countries'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1140'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Commercial policy'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1160'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Common fisheries policy'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0410'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Competition policy'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/08'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Conservation of resources'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/041030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Consumers'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1520'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Customs Union and free movement of goods'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/02'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Development policy'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1170'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Direct taxation'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0920'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Economic and commercial law'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1730'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Economic and monetary policy and free movement of capital'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/10'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Economic policy'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Employment and unemployment'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/052030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Energy'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/12'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Environment'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1510'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Environment, consumers and health protection'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/15'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European countries'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/114010'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'External relations'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/11'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'External relations'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0420'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Financial and budgetary provisions'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Fisheries'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/04'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Foodstuffs'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/133014'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Free movement of persons'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1910'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Freedom of movement for workers and social policy'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/05'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'General principles and programmes'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1210'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'General social provisions'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/052005'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'General, financial and institutional matters'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/01'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Indirect taxation'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0930'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industrial policy and internal market'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/13'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industrial policy: general, programmes, statistics and research'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1310'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industrial policy: sectoral operations'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1320'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Inland transport'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0720'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Internal market: approximation of laws'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1330'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'International relations'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/074050'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Law relating to undertakings'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/17'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Market operation'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/074020'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Market operation'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/072030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Movement of goods'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/024010'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Multilateral relations'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1130'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Nuclear energy'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1240'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Oil and gas'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1250'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': "People's Europe"},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/20'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Police and judicial cooperation in criminal and customs matters'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1930'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Pollution and nuisances'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/151020'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Production and processing activities'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/062010'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Products not subject to market organisation'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0370'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Products subject to market organisation'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0360'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Provisions governing the institutions'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0140'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Public contracts'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0630'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Regional policy and coordination of structural instruments'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/14'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Research and technological development'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/131030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Restrictive practices'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0820'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Right of establishment and freedom to provide services'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/06'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Science'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/1610'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Science, information, education and culture'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/16'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Sectoral application'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0620'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Service activities'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/062020'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Shipping'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0730'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Social policy'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0520'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Social security'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/052040'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Space, environment and natural resources'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/151030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Specific customs rules'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0240'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Structural harmonisation'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/072040'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Structural harmonisation'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/073040'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Tariff derogations'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/023030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Taxation'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/09'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Trade arrangements'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/116030'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Trade protection'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/116040'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Transport infrastructure'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0710'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Transport policy'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/07'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Working conditions'},
#     'conceptDirectoryCodeBroader_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/052020'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>

            SELECT DISTINCT ?conceptDirectoryCodeBroader ?directoryOrg_uri ?directoryOrg where {
            #?conceptDirectoryCodeBroader_uri skos:narrower/skos:narrower ?conceptDirectoryCode_uri;
            # ?conceptDirectoryCodeBroader_uri skos:narrower+ ?conceptDirectoryCode_uri;
             #?conceptDirectoryCode_uri skos:broader ?conceptDirectoryCodeBroader_uri;
                                         skos:prefLabel ?conceptDirectoryCodeBroader.
            {
            SELECT DISTINCT ?conceptDirectoryCode ?conceptDirectoryCode_uri ?directoryOrg_uri ?directoryOrg
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:resource_legal_is_about_concept_directory-code ?conceptDirectoryCode_uri.
                    # ?conceptDirectoryCode_uri skos:prefLabel ?conceptDirectoryCode.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   FILTER(langMatches(lang(?conceptDirectoryCode), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   }
            }
            FILTER(langMatches(lang(?conceptDirectoryCodeBroader), "en")).
            }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['conceptDirectoryCodeBroader', 'directoryOrg_uri', 'directoryOrg']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industrial policy and internal market'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Environment, consumers and health protection'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'General social provisions'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Social policy'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Area of freedom, security and justice'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'External relations'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Pollution and nuisances'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industrial policy: general, programmes, statistics and research'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Law relating to undertakings'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Internal market: approximation of laws'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Free movement of persons'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Bilateral agreements with non-member countries'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'General, financial and institutional matters'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Environment'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Freedom of movement for workers and social policy'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'General principles and programmes'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Approximation of laws and health measures'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European countries'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Energy'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Science, information, education and culture'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Taxation'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industrial policy: sectoral operations'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Indirect taxation'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Provisions governing the institutions'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Space, environment and natural resources'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Consumers'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Transport policy'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Fisheries'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agricultural structural funds'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Air transport'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Economic and monetary policy and free movement of capital'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Competition policy'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Right of establishment and freedom to provide services'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Science'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Service activities'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Commercial policy'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Sectoral application'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Transport infrastructure'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Structural harmonisation'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Inland transport'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Development policy'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Multilateral relations'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Common fisheries policy'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Police and judicial cooperation in criminal and customs matters'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Nuclear energy'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agricultural structures'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Products subject to market organisation'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Employment and unemployment'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Regional policy and coordination of structural instruments'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Aid to developing countries'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Social security'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': "People's Europe"},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Working conditions'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Asylum policy'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Shipping'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Basic provisions'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Oil and gas'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Public contracts'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Market operation'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Conservation of resources'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Trade arrangements'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Economic policy'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Direct taxation'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Customs Union and free movement of goods'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Specific customs rules'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Movement of goods'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Financial and budgetary provisions'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Basic customs instruments'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Trade protection'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Associations'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'International relations'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Research and technological development'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Products not subject to market organisation'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Economic and commercial law'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Action in favour of countries in transition'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Foodstuffs'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Restrictive practices'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Autonomous regional action'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Production and processing activities'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Application of the Common Customs Tariff'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'conceptDirectoryCodeBroader': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Tariff derogations'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}}]}}

# %%
{
  select ?film {
   # ?film rdf:type <http://schema.org/Movie> .
  }
  group by ?film
  limit 1
 }

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            #SELECT DISTINCT ?conceptDirectoryCode ?conceptDirectoryCode_uri ?directoryOrg_uri ?directoryOrg
            SELECT DISTINCT ?directoryOrg_uri ?directoryOrg
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri.
                            #cdm:resource_legal_is_about_concept_directory-code ?conceptDirectoryCode_uri.
                    #?conceptDirectoryCode_uri skos:prefLabel ?conceptDirectoryCode.
                            #cdm:work_is_about_concept_eurovoc ?eurovoc_uri.
                            #cdm:resource_legal_id_celex ?parlamentaryQuestion;
                            #cdm:work_date_document ?parlamentaryQuestion_date.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri.
                    #?conceptDirectoryCode_uri skos:prefLabel ?conceptDirectoryCode.
                    #?eurovoc_uri skos:prefLabel ?eurovoc;
                    #        skos:inScheme ?eurovocThesauri_uri.
                    #?eurovocThesauri_uri skos:prefLabel ?eurovocThesauri.
                    #        euvoc:domain ?eurovocDomain_uri.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   #FILTER(langMatches(lang(?conceptDirectoryCode), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['directoryOrg_uri', 'directoryOrg']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            #SELECT DISTINCT ?conceptDirectoryCode ?conceptDirectoryCode_uri ?directoryOrg_uri ?directoryOrg
            SELECT DISTINCT ?directoryOrg_uri ?directoryOrg
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['directoryOrg_uri', 'directoryOrg']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?eurovocThesauri ?eurovoc ?eurovoc_uri ?directoryOrg_uri ?directoryOrg
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:work_is_about_concept_eurovoc ?eurovoc_uri.
                            #cdm:resource_legal_id_celex ?parlamentaryQuestion;
                            #cdm:work_date_document ?parlamentaryQuestion_date.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?eurovoc_uri skos:prefLabel ?eurovoc;
                            skos:inScheme ?eurovocThesauri_uri.
                    # ?eurovocThesauri_uri skos:prefLabel ?eurovocThesauri.
                    #        euvoc:domain ?eurovocDomain_uri.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   FILTER(langMatches(lang(?eurovoc), "en")).
                   FILTER(langMatches(lang(?eurovocThesauri), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-1bf3109af2f8> in <module>
#      29
#      30 sparql.setReturnFormat(JSON)
# ---> 31 results = sparql.query().convert()
#      32 results
#
# /usr/local/lib/python3.7/site-packages/SPARQLWrapper/Wrapper.py in query(self)
#    1105             :rtype: :class:`QueryResult` instance
#    1106         """
# -> 1107         return QueryResult(self._query())
#    1108
#    1109     def queryAndConvert(self):
#
# /usr/local/lib/python3.7/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#    1071                 response = urlopener(request, timeout=self.timeout)
#    1072             else:
# -> 1073                 response = urlopener(request)
#    1074             return response, self.returnFormat
#    1075         except urllib.error.HTTPError as e:
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
# -> 1320             r = h.getresponse()
#    1321         except:
#    1322             h.close()
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1050                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1051                   self.__class__)
# -> 1052             return self.read(nbytes, buffer)
#    1053         else:
#    1054             return super().recv_into(buffer, nbytes, flags)
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in read(self, len, buffer)
#     909         try:
#     910             if buffer is not None:
# --> 911                 return self._sslobj.read(len, buffer)
#     912             else:
#     913                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
uri2='http://eurovoc.europa.eu/1590'
uri2='http://publications.europa.eu/resource/authority/fd_070/ENV'
uri2='http://publications.europa.eu/resource/authority/fd_555/0320'
uri='http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'

# %%
cdm:resource_legal_is_about_concept_directory-code ?conceptDirectoryCode_uri.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?conceptDirectoryCodeBroader_uri skos:narrower+ ?conceptDirectoryCode_uri;
                        skos:prefLabel ?conceptDirectoryCodeBroader.

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
            SELECT DISTINCT ?parlamentaryQuestion ?parlamentaryQuestion_uri ?expression ?expression_languageUri ?expression_uri ?manifestation ?manifestation_type
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:resource_legal_is_about_concept_directory-code ?conceptDirectoryCode_uri;
                            cdm:resource_legal_id_celex ?parlamentaryQuestion.
                            #cdm:work_date_document ?parlamentaryQuestion_date.
                    # ?expression_uri cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                            cdm:expression_uses_language ?expression_languageUri;
                            cdm:expression_title ?expression.
                    #cdm:expression_uses_language ?expression_languageUri.
                    # ?manifestation cdm:manifestation_manifests_expression ?expression_uri;
                                cdm:manifestation_type ?manifestation_type.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    #?conceptDirectoryCode_uri skos:prefLabel ?conceptDirectoryCode.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   filter(?subjectMatter_uri=<"""+uri2+""">).
                   #FILTER(langMatches(lang(?conceptDirectoryCode), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   #filter(?expression_languageUri=<http://publications.europa.eu/resource/authority/language/ENG>)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['parlamentaryQuestion',
#    'parlamentaryQuestion_uri',
#    'expression',
#    'expression_languageUri',
#    'expression_uri',
#    'manifestation',
#    'manifestation_type']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
            SELECT DISTINCT ?subjectMatter ?subjectMatter_uri ?parlamentaryQuestion ?parlamentaryQuestion_uri ?expression ?expression_languageUri ?expression_uri ?manifestation ?manifestation_type
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:resource_legal_is_about_subject-matter ?subjectMatter_uri;
                            cdm:resource_legal_id_celex ?parlamentaryQuestion.
                            #cdm:work_date_document ?parlamentaryQuestion_date.
                    # ?expression_uri cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                            cdm:expression_uses_language ?expression_languageUri;
                            cdm:expression_title ?expression.
                    #cdm:expression_uses_language ?expression_languageUri.
                    # ?manifestation cdm:manifestation_manifests_expression ?expression_uri;
                                cdm:manifestation_type ?manifestation_type.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?subjectMatter_uri skos:prefLabel ?subjectMatter.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   filter(?subjectMatter_uri=<"""+uri2+""">).
                   FILTER(langMatches(lang(?subjectMatter), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   #filter(?expression_languageUri=<http://publications.europa.eu/resource/authority/language/ENG>)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['subjectMatter',
#    'subjectMatter_uri',
#    'parlamentaryQuestion',
#    'parlamentaryQuestion_uri',
#    'expression',
#    'expression_languageUri',
#    'expression_uri',
#    'manifestation',
#    'manifestation_type']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
            SELECT DISTINCT ?subjectMatter ?subjectMatter_uri ?parlamentaryQuestion ?parlamentaryQuestion_uri ?expression ?expression_languageUri ?expression_uri ?manifestation ?manifestation_type
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:resource_legal_is_about
}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#sameAs'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/celex/92013E012378'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/annotation#build_info'},
#     'o': {'type': 'literal',
#      'value': 'cdm:CDM_2.1.7  tdm:1523  xslt:3945 saxon:9.0.0.1J JVM:1.6.0_29 metaconvJar:1.2.0 builddate:10/11/2014 11:25:54'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#date_creation_legacy'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-08-07'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary_asked_by_group_parliamentary'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary_date_reply'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2013-12-16'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary_term_parliamentary'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': '7'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal_addresses_institution'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/COM'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal_date_dispatch'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2013-10-31'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal_id_celex'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': '92013E012378'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal_id_sector'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': '9'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal_is_about_concept_directory-code'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/074030'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal_is_about_subject-matter'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/TRAN'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal_number_natural_celex'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#positiveInteger',
#      'value': '12378'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal_published_in_official-journal'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/5e53694e-0d8a-11e4-a7d0-01aa75ed71a1'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal_type'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'E'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal_year'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#gYear',
#      'value': '2013'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#work_created_by_agent'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#work_created_by_agent'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/OP_DATPRO'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#work_date_creation'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-10'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#work_date_creation_legacy'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-08-07'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#work_date_document'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2013-10-31'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#work_has_resource-type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/resource-type/QUEST_WRITTEN'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#work_id_document'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'celex:92013E012378'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#work_id_document'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'ep:P7_RE(2013)012378'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#work_id_obsolete_notice'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#positiveInteger',
#      'value': '1190450'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#work_is_about_concept_eurovoc'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/5234'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#work_is_about_concept_eurovoc'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/5887'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#work_is_about_concept_eurovoc'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/863'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#work_is_about_concept_eurovoc'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/4438'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#work_is_about_concept_eurovoc'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/5368'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#work_part_of_collection_document'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/document-collection/CELEX'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#work_part_of_collection_document'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/document-collection/PE'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm/cmr#lastModificationDate'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'value': '2021-07-19T11:10:10.640+02:00'}}]}}

# %%
uri='http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX cmr: <http://publications.europa.eu/ontology/cdm/cmr#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX rdfs:<http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX owl:<http://www.w3.org/2002/07/owl#>
            #SELECT DISTINCT ?work
            SELECT DISTINCT ?expression ?manifestation ?item
            where {{
                    #?manifestation cdm:manifestation_has_item ?item.
                    # ?manifestation cdm:manifestation_manifests_expression ?expression.
                    #?manifestation <http://publications.europa.eu/ontology/cdm#manifestation_manifests_expression> ?expression.
                    # ?expression cdm:expression_belongs_to_work ?work;
                    cdm:expression_uses_language ?expression_languageUri.
                    #?work ?p <http://publications.europa.eu/ontology/cdm#resource_legal>.
                    #?work rdfs:type cdm:resource_legal.
                    #?item cmr:manifestationMimeType 'application/pdf'.
                    #?manifestation cdm:manifestation_type ?manifestation_type
                    #owl:sameAs ?same
                    } 
                   filter(?work=<"""+uri+""">)
                   filter(?expression_languageUri=<http://publications.europa.eu/resource/authority/language/ENG>)
                   #filter(?p!=<http://publications.europa.eu/ontology/cdm#signature_digital_signs_manifestation>)
                   #filter(?p!=<http://www.w3.org/2002/07/owl#annotatedSource>)
                   #filter(?p=<http://www.w3.org/2000/01/rdf-schema#subClassOf>)
                   #filter(?o=<http://publications.europa.eu/ontology/cdm#work>)
                   #filter(?o='application/pdf')
                   #FILTER(langMatches(lang(?label), "en")).
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['expression', 'manifestation', 'item']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'expression': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443.0002'},
#     'manifestation': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443.0002.01'}}]}}

# %%
uri='http://publications.europa.eu/resource/cellar/b160b17f-8296-4c2d-ae54-556602d59443.0002.01'
uri='http://publications.europa.eu/resource/authority/fd_555/0160'
#uri='http://publications.europa.eu/resource/authority/fd_555/016060'
#uri='http://publications.europa.eu/resource/authority/fd_555'

# %%
'http://www.w3.org/2004/02/skos/core#narrower'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            SELECT DISTINCT ?s ?p ?o
            where {{?s skos:narrower ?o.
                    } 
                   filter(?o=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/01'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            SELECT DISTINCT ?s ?p ?o
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_directory-code'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#ATTO_FD_555'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'es',
#      'value': 'Disposiciones financieras y presupuestarias'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'fr',
#      'value': 'Dispositions financières et budgétaires'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'it',
#      'value': 'Disposizioni finanziarie e di bilancio'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'mt',
#      'value': 'Disposizzjonijiet finanzjarji u baġitarji'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'pt',
#      'value': 'Disposições financeiras e orçamentais'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'ro',
#      'value': 'Dispoziţii financiare şi bugetare'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Financial and budgetary provisions'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'hr',
#      'value': 'Financijske i proračunske odredbe'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'nl',
#      'value': 'Financiële en budgettaire bepalingen'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'sv',
#      'value': 'Finansiella bestämmelser och budgetbestämmelser'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'da',
#      'value': 'Finansielle og budgetmæssige bestemmelser'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'lt',
#      'value': 'Finansų ir biudžeto nuostatos'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'et',
#      'value': 'Finants- ja eelarvesätted'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'de',
#      'value': 'Finanz- und Haushaltsvorschriften'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'sl',
#      'value': 'Finančni in proračunski predpisi'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'sk',
#      'value': 'Finančné a rozpočtové ustanovenia'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'cs',
#      'value': 'Finanční a rozpočtová ustanovení'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'lv',
#      'value': 'Finanšu un budžeta noteikumi'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'ga',
#      'value': 'Forálacha airgeadais agus buiséadacha'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'pl',
#      'value': 'Przepisy finansowe i budżetowe'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'hu',
#      'value': 'Pénzügyi és költségvetési rendelkezések'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'fi',
#      'value': 'Rahoitusta ja varainhoitoa koskevat säännökset'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'el',
#      'value': 'Χρηματοπιστωτικές και δημοσιονομικές διατάξεις'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'bg',
#      'value': 'Финансови и бюджетни разпоредби'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#narrower'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/016030'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#narrower'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/016020'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#narrower'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/016040'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#narrower'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/016050'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#narrower'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/016010'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#narrower'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/016060'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://purl.org/dc/elements/1.1/identifier'},
#     'o': {'type': 'literal', 'value': '0160'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/op-code'},
#     'o': {'type': 'literal', 'value': '0160'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_555/0160'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/op-code'},
#     'o': {'type': 'literal', 'value': '0160'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
            SELECT DISTINCT ?corporateBody ?corporateBody_uri ?publicationDocument ?publicationDocument_uri ?publicationDocument_documentUri ?publicationDocument_date
            where {{?publicationDocument_documentUri cdm:publication_general_is_about_concept_op_theme ?opTheme_uri;
                       cdm:work_authored_by_agent ?corporateBody_uri.
                    # ?opTheme_uri skos:prefLabel ?opTheme.
                    # ?corporateBody_uri skos:prefLabel ?corporateBody.
                    # ?publicationDocument_documentUri cdm:work_date_document ?publicationDocument_date.
                    # ?publicationDocument_uri cdm:expression_belongs_to_work ?publicationDocument_documentUri;
                       cdm:expression_uses_language ?expression_languageUri;
                       cdm:expression_title ?publicationDocument.
                    # ?expression_languageUri skos:prefLabel ?expression_language.
                    } 
                   filter(?opTheme_uri=<http://publications.europa.eu/resource/authority/pub-theme/N>)
                   filter(?corporateBody_uri=<http://publications.europa.eu/resource/authority/corporate-body/IPSC>)
                   FILTER(langMatches(lang(?corporateBody), "en")).
                   FILTER(langMatches(lang(?opTheme), "en")).
                   FILTER(langMatches(lang(?expression_language), "en")).
                   }ORDER BY ?corporateBody ?publicationDocument
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['corporateBody',
#    'corporateBody_uri',
#    'publicationDocument',
#    'publicationDocument_uri',
#    'publicationDocument_documentUri',
#    'publicationDocument_date']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for the Protection and Security of the Citizen'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/IPSC'},
#     'publicationDocument': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'An inventory of risk-related or resilience-related composite indicators and ratings.'},
#     'publicationDocument_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b4226fab-4a8a-4e93-b86b-77e00d4625b7.0001'},
#     'publicationDocument_documentUri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/b4226fab-4a8a-4e93-b86b-77e00d4625b7'},
#     'publicationDocument_date': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2013-01-17'}},
#    {'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for the Protection and Security of the Citizen'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/IPSC'},
#     'publicationDocument': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Corruption perceptions index 2012 (SSI) : statistical assessment.'},
#     'publicationDocument_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/d2acf84c-f979-4fa3-b359-f6db968ff74f.0001'},
#     'publicationDocument_documentUri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/d2acf84c-f979-4fa3-b359-f6db968ff74f'},
#     'publicationDocument_date': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2013-01-18'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
 PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?subjectMatter ?subjectMatter_uri (?directoryOrg_uri AS ?subjectMatter_directoryOrg) ?directoryOrg_uri ?directoryOrg
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:resource_legal_is_about_subject-matter ?subjectMatter_uri.
                    # ?subjectMatter_uri skos:prefLabel ?subjectMatter.
                            #cdm:work_is_about_concept_eurovoc ?eurovoc_uri.
                            #cdm:resource_legal_id_celex ?parlamentaryQuestion;
                            #cdm:work_date_document ?parlamentaryQuestion_date.
                    # ?expression cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                    cdm:expression_uses_language ?expression_languageUri.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    #?eurovoc_uri skos:prefLabel ?eurovoc;
                    #        skos:inScheme ?eurovocThesauri_uri.
                    #?eurovocThesauri_uri skos:prefLabel ?eurovocThesauri.
                    #        euvoc:domain ?eurovocDomain_uri.
                    } 
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE>).
                   FILTER(langMatches(lang(?subjectMatter), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['subjectMatter',
#    'subjectMatter_uri',
#    'subjectMatter_directoryOrg',
#    'directoryOrg_uri',
#    'directoryOrg']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Competition'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/CONC'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Foodstuffs'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/D-AL'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Environment'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/ENV'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Financial provisions'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/FIN'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Taxation'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/FISC'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Information and verification'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/INFO'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Internal market - Principles'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/MARI'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Commercial policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PCOM'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Common foreign and security policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PESC'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Consumer protection'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PROT'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Approximation of laws'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/RAPL'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Research and technological development'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/RDT'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Public health'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/SANT'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Social Policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/SOPO'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Transport'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/TRAN'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Veterinary legislation'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/VETE'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Energy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/ENER'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Tourism'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/TOUR'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Environment'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/ENV'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Social provisions'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/SOCI'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Freedom to provide services'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/SERV'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Free movement of goods'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/LCM'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Intellectual, industrial and commercial property'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PROP'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'External relations'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/EXT'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Employment'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/EMPL'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Transport'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/TRAN'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Anti-discrimination'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/DISC'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Approximation of laws'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/RAPL'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Social Policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/SOPO'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Budget'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/BUDG'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Trans-European networks'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/RTR'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Human rights'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/DDLH'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Pigmeat'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PORC'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Public health'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/SANT'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Social provisions'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/SOCI'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Justice and home affairs'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/J-AI'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture and Fisheries'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/AGRI'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'State aids'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/AIDE'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'External relations'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/EXT'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Freedom of establishment'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/LES'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Oils and fats'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/MGRA'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Small and medium-sized enterprises'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PME'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Freedom to provide services'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/SERV'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Common customs tariff'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/TDC'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Human rights'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/DDLH'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Technical barriers'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/ETEC'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Principles, objectives and tasks of the Treaties'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PRIN'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Telecommunications'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/TELE'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Education, vocational training and youth'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/EFPJ'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Regional policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PREG'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Seeds and seedlings'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/SEME'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Employment'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/EMPL'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Preferential systems'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/RPRE'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'General provisions'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/DGEN'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Monetary measures in the field of agriculture'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/MONA'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Tobacco'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/TABA'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Processed fruit and vegetables'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/FLT'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Electronic data processing'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/INFQ'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Telecommunications'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/TELE'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Fruit and vegetables'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/F-L'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Energy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/ENER'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Taxation'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/FISC'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Milk products'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/LAIT'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Freedom of establishment'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/LES'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Food aid'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/ALIM'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Sugar'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/SUCR'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Common foreign and security policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/PESC'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Internal market - Principles'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/MARI'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Economic policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/PECO'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Competition'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/CONC'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Accession'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/ADH'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Judicial cooperation in criminal matters'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/COJP'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Provisions governing the Institutions'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/INST'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Fisheries policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PECH'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Area of freedom, security and justice'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/ELSJ'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Immigration and asylum policy'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/IMMI'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/INDU'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Free movement of persons'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/LCP'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Public procurement in the European Union'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/MARC'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
# ...
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Textiles'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/TXTL'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Customs Union'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/UD'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Research and training'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/RECH'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Wine'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/VIN'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Acts of the institutions'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/ACTE'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Plants and flowers'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/P-F'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Wine'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/VIN'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Animal feedingstuffs'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/AL-A'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Products from third countries'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/MEXT'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Cohesion Fund'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/COHE'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Development Fund (EDF)'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/FED'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'World Trade Organization'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/OMC'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Harmonisation of customs law: various'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/HARX'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Customs duties: suspensions'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/TDCS'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Civil protection'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/PCIV'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Common organisation of agricultural markets'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/OCM'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Eggs and poultry'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/O-V'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Harmonisation of customs law: warehouses, free zones'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/HARE'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Euro'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/EURO'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Steel'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/ACIE'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal', 'xml:lang': 'en', 'value': 'Dumping'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/DUMP'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Dominant position'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/POSI'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Customs procedures'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/RDOU'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Potatoes'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/PDET'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Social Fund (ESF)'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_070/FSE'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}},
#    {'subjectMatter': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Forestry'},
#     'subjectMatter_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter/SILV'},
#     'subjectMatter_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Renew Europe Group'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
            SELECT DISTINCT ?text
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:resource_legal_is_about_subject-matter ?subjectMatter_uri;
                            cdm:resource_legal_id_celex ?parlamentaryQuestion.
                            #cdm:work_date_document ?parlamentaryQuestion_date.
                    # ?expression_uri cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                            cdm:expression_uses_language ?expression_languageUri;
                            cdm:expression_title ?text.
                    #cdm:expression_uses_language ?expression_languageUri.
                    # ?manifestation cdm:manifestation_manifests_expression ?expression_uri;
                                cdm:manifestation_type ?manifestation_type.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?subjectMatter_uri skos:prefLabel ?subjectMatter.
                    } 
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALD
}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-008158/12 Fiona Hall (ALDE) to the Commission. Applicability of EU trade agreements if a Member State leaves the EU'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-010919/12 Chris Davies (ALDE) to the Commission. Embalmment and preservation of human corpses'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-008083/12 Catherine Bearder (ALDE) to the Commission. Trade in wild animals'}},
#    {'text': {'type': 'literal',
#      'value': 'Written question E-002649/14 Phil Bennion (ALDE), Baroness Sarah Ludford (ALDE), George Lyon (ALDE), Bill Newton Dunn (ALDE), Rebecca Taylor (ALDE), Sir Graham Watson (ALDE), Chris Davies (ALDE), Catherine Bearder (ALDE), Andrew Duff (ALDE) and Sharon Bowles (ALDE) to the Commission. Protection of geographical indications'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-006934/13 Cristiana Muscardini (ECR), Roberta Angelilli (PPE), Patrizia Toia (S&D) and Niccolò Rinaldi (ALDE) to the Commission. Anti-dumping blackmail by China'}},
#    {'text': {'type': 'literal',
#      'value': "Written question E-008733/13 Angelika Werthmann (ALDE) to the Commission. France's trade deficit and its consequences"}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-010947/13 Angelika Werthmann (ALDE) to the Commission. Trade relations with China'}},
#    {'text': {'type': 'literal',
#      'value': 'Written question E-008731/12 Marian Harkin (ALDE) to the Commission. Anti-dumping duties'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-003311/13 Andrea Zanoni (ALDE) to the Commission. Possible breach of Regulation (EC) No\xa01007/2009 of the European Parliament and of the Council and Regulation (EU) No\xa0737/2010 of the Commission'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-012334/13 Chris Davies (ALDE) to the Commission. Eco-labelling of fish products'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-008945/13 Pat the Cope Gallagher (ALDE) to the Commission. Trade agreements and human rights'}},
#    {'text': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Written question E-002249/12 Pat the Cope Gallagher (ALDE) to the Commission. Review of Regulation (EC) No\xa01007/2009 on trade in seal products'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
            SELECT DISTINCT ?subjectMatter ?subjectMatter_uri ?parlamentaryQuestion ?parlamentaryQuestion_uri ?parlamentaryQuestion_date ?parlamentaryQuestion_type
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:resource_legal_is_about_subject-matter ?subjectMatter_uri;
                            #cdm:resource_legal_id_celex ?parlamentaryQuestion;
                            cdm:work_date_document ?parlamentaryQuestion_date.
                    # ?expression_uri cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                            cdm:expression_uses_language ?expression_languageUri;
                            cdm:expression_title ?parlamentaryQuestion.
                    #cdm:expression_uses_language ?expression_languageUri.
                    # ?manifestation_uri cdm:manifestation_manifests_expression ?expression_uri;
                                cdm:manifestation_type ?parlamentaryQuestion_type.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?subjectMatter_uri skos:prefLabel ?subjectMatter.
                    } 
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE>).
                   filter(?subjectMatter_uri=<http://publications.europa.eu/resource/authority/fd_070/PCOM>).
                   FILTER(langMatches(lang(?subjectMatter), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   FILTER(str(?parlamentaryQuestion_type)!='print').
                   #filter(?expression_languageUri=<http://publications.europa.eu/resource/authority/language/ENG>)
                   }ORDER BY DESC(?parlamentaryQuestion_date)
     """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['subjectMatter',
#    'subjectMatter_uri',
#    'parlamentaryQuestion',
#    'parlamentaryQuestion_uri',
#    'parlamentaryQuestion_date',
#    'parlamentaryQuestion_type']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
            SELECT DISTINCT ?parlamentaryQuestion_type
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:resource_legal_is_about_subject-matter ?subjectMatter_uri;
                            #cdm:resource_legal_id_celex ?parlamentaryQuestion;
                            cdm:work_date_document ?parlamentaryQuestion_date.
                    # ?expression_uri cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                            cdm:expression_uses_language ?expression_languageUri;
                            cdm:expression_title ?parlamentaryQuestion.
                    #cdm:expression_uses_language ?expression_languageUri.
                    # ?manifestation_uri cdm:manifestation_manifests_expression ?expression_uri;
                                cdm:manifestation_type ?parlamentaryQuestion_type.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?subjectMatter_uri skos:prefLabel ?subjectMatter.
                    } 
                   #filter(?directoryOrg_uri=<http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE>).
                   #filter(?subjectMatter_uri=<http://publications.europa.eu/resource/authority/fd_070/PCOM>).
                   FILTER(langMatches(lang(?subjectMatter), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   FILTER(str(?parlamentaryQuestion_type)!='print').
                   #filter(?expression_languageUri=<http://publications.europa.eu/resource/authority/language/ENG>)
                   }ORDER BY DESC(?parlamentaryQuestion_date)
     """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-88b370bab570> in <module>
#      31
#      32 sparql.setReturnFormat(JSON)
# ---> 33 results = sparql.query().convert()
#      34 results
#
# /usr/local/lib/python3.7/site-packages/SPARQLWrapper/Wrapper.py in query(self)
#    1105             :rtype: :class:`QueryResult` instance
#    1106         """
# -> 1107         return QueryResult(self._query())
#    1108
#    1109     def queryAndConvert(self):
#
# /usr/local/lib/python3.7/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#    1071                 response = urlopener(request, timeout=self.timeout)
#    1072             else:
# -> 1073                 response = urlopener(request)
#    1074             return response, self.returnFormat
#    1075         except urllib.error.HTTPError as e:
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
# -> 1320             r = h.getresponse()
#    1321         except:
#    1322             h.close()
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1050                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1051                   self.__class__)
# -> 1052             return self.read(nbytes, buffer)
#    1053         else:
#    1054             return super().recv_into(buffer, nbytes, flags)
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/ssl.py in read(self, len, buffer)
#     909         try:
#     910             if buffer is not None:
# --> 911                 return self._sslobj.read(len, buffer)
#     912             else:
#     913                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
            SELECT DISTINCT ?parlamentaryQuestion
            where {{?parlamentaryQuestion_uri cdm:question_parliamentary_asked_by_group_parliamentary ?directoryOrg_uri;
                            cdm:resource_legal_is_about_subject-matter ?subjectMatter_uri;
                            #cdm:resource_legal_id_celex ?parlamentaryQuestion;
                            cdm:work_date_document ?parlamentaryQuestion_date.
                    # ?expression_uri cdm:expression_belongs_to_work ?parlamentaryQuestion_uri;
                            cdm:expression_uses_language ?expression_languageUri;
                            cdm:expression_title ?parlamentaryQuestion.
                    #cdm:expression_uses_language ?expression_languageUri.
                    # ?manifestation_uri cdm:manifestation_manifests_expression ?expression_uri;
                                cdm:manifestation_type ?parlamentaryQuestion_type.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?subjectMatter_uri skos:prefLabel ?subjectMatter.
                    } 
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_ALDE>).
                   filter(?subjectMatter_uri=<http://publications.europa.eu/resource/authority/fd_070/PCOM>).
                   FILTER(langMatches(lang(?subjectMatter), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(str(?expression_languageUri)='http://publications.europa.eu/resource/authority/language/ENG').
                   FILTER(str(?parlamentaryQuestion_type)!='print').
                   #filter(?expression_languageUri=<http://publications.europa.eu/resource/authority/language/ENG>)
                   }ORDER BY DESC(?parlamentaryQuestion_date)
     """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['parlamentaryQuestion']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}
