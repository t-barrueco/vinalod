# %%
import pandas as pd
import math

# %% [markdown]
# ## Read file

# %%
filename="config_basicMode.txt"

# %%
df=pd.read_csv(filename, sep='\t')

# %%
df.columns
# Out:
# Index(['CLASS', 'URL', 'QUERY', 'HIERARCHY', 'PROPERTIES', 'OPTION',
#        'OPTION_TEXT', 'TYPE', 'CLASSES', 'PARAMETERS', 'FILTERS', 'TOOLTIP',
#        'FUNCTION', 'COLUMNS'],
#       dtype='object')

# %%
df.iloc[27]["PROPERTIES"]
# Out:
# 'membership-membership_order;membership-membership_positionStatus;person-person_image'

# %%
query=""" PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
    PREFIX cmr: <http://publications.europa.eu/ontology/cdm/cmr#>
            SELECT DISTINCT ?item
            where {
                    {
                    # ?item cdm:item_belongs_to_manifestation ?manifestation_uri;
                          cmr:manifestationMimeType ?mimeType
                    } 
                   filter(?manifestation_uri=<PARAMETER>)
                   filter(?mimeType='application/pdf')
                   }"""

# %%
df.at[26, 'URL'] = "https://publications.europa.eu/webapi/rdf/sparql"

# %%
df.iloc[22]["FILTERS"]
# Out:
# 'manifestation_type-dropdown'

# %%
df.iloc[22]["CLASSES"]
# Out:
# 'expression-Publication Document;manifestation-Publication Manifestation'

# %%
df
# Out:
#                         CLASS  \
# 0                 opThemeMain
# 1                  Membership
# 2      Directory Organization
# 3                    OP Theme
# 4                     eurovoc
# 5             Eurovoc Concept
# 6                        nuts
# 7                    taxonomy
# 8              Taxonomy Level
# 9                         det
# 10            Eurovoc Concept
# 11                  DET Level
# 12                  DET Level
# 13                 Continents
# 14                 Continents
# 15               Organisation
# 16                      eurun
# 17              corporateBody
# 18     Directory Organization
# 19            Membership Type
# 20                     Person
# 21                   OP Theme
# 22       Publication Document
# 23              corporateBody
# 24     Directory Organization
# 25                 DEUCatalog
# 26  Publication Manifestation
# 27     Directory Organization
#
#                                                  URL  \
# ...

# %% [raw]
# df["COLUMNS"]=""

# %% [markdown]
# ## Show cell value

# %%
df.iloc[19].QUERY
# Out:
# '\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#> \n    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>\n    PREFIX org: <http://www.w3.org/ns/org#>\n    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>\n    PREFIX foaf: <http://xmlns.com/foaf/0.1/>\n    PREFIX resource: <http://publications.europa.eu/resource/>\n            SELECT DISTINCT ?membership ?membership_uri ?membership_startDate ?membership_endDate ?membership_order ?membership_positionStatusUri ?membership_positionStatus ?person ?person_uri ?person_id ?person_image ?person_citiz ?person_gender ?person_genderUri\n            where {{?membership_uri org:organization ?directoryOrg_uri;\n                       euvoc:startDate ?membership_startDate;\n                       euvoc:endDate ?membership_endDate;\n                       euvoc:order ?membership_order;\n                       euvoc:positionComplement ?membership;\n                       euvoc:positionStatus ?membership_positionStatusUri.\n           
# ...

# %%
df.iloc[27].PROPERTIES
# Out:
# 'membership-membership_order;membership-membership_positionStatus;person-person_image'

# %%
df.iloc[18].PROPERTIES

# %%
df.iloc[22].TOOLTIP
# Out:
# 'manifestation_type-Manifestation Type'

# %%
df.iloc[22].FILTERS
# Out:
# 'manifestation_type-dropdown'

# %%
df.iloc[22].QUERY
# Out:
# '\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#> \n    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>\n    PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>\n            SELECT DISTINCT ?expression ?expression_uri ?manifestation ?manifestation_uri ?manifestation_image ?manifestation_type\n            where {\n                    {\n                    ?manifestation_uri cdm:manifestation_manifests_expression ?expression_uri.\n                    ?manifestation_uri cdm:manifestation_has_thumbnail ?manifestation_image;\n                                       cdm:manifestation_number_catalogue ?manifestation;\n                                       cdm:manifestation_type ?manifestation_type.\n                                       #cdm:manifestation_isbn ?manifestation_isbn.\n                    ?expression_uri cdm:expression_title ?expression.\n                    } \n                   filter(?expression_uri=<PARAMETER>)\n                   }ORDER BY ?expression ?manife
# ...

# %%
df.iloc[17].PROPERTIES
# Out:
# 'directoryOrg-directoryOrg_uri;directoryOrg-directoryOrg_order;directoryOrg-directoryOrg_protocolLevel;directoryOrg-directoryOrg_email;directoryOrg-directoryOrg_telephone;directoryOrg-directoryOrg_locality;directoryOrg-directoryOrg_postalCode;directoryOrg-directoryOrg_streetAddress;directoryOrg-directoryOrg_homepage'

# %%
directoryOrg_locality

# %%
df.iloc[0].PROPERTIES
# Out:
# 'opThemeMain-opThemeMain_uri;opTheme-opTheme_uri'

# %%
df.iloc[0].FILTERS
# Out:
# 'opTheme_dateCreated-date'

# %%
df.iloc[0].QUERY
# Out:
# 'PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>\nPREFIX skos: <http://www.w3.org/2004/02/skos/core#>\nPREFIX cdm: <http://publications.europa.eu/ontology/cdm#>\nPREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>\nPREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>\nPREFIX dcterms: <http://purl.org/dc/terms/>\nSELECT DISTINCT ?opThemeMain ?opThemeMain_uri ?opTheme ?opTheme_uri ?opTheme_dateCreated\n    where\n    {\n        {?opTheme_uri rdf:type ?opThemeMain_uri;\n        skos:prefLabel ?opTheme;\n        dcterms:created ?opTheme_dateCreated.\n        ?opThemeMain_uri rdfs:label ?opThemeMain                    \n        }\n    filter(?opThemeMain_uri=<http://publications.europa.eu/ontology/cdm#concept_op_theme>)\n    FILTER(langMatches(lang(?opTheme), "en")).\n    filter not exists {\n        ?opTheme_uri skos:broader ?broader\n        }\n    }ORDER BY ?opThemeMain ?opTheme'

# %% [markdown]
# ## Change cell value

# %%
df.at[27, 'COLUMNS'] = 'membership;person;person_image'

# %%
df.at[18, 'PROPERTIES'] = 'membership-membership_directoryOrg;membership-membership_startDate;membership-membership_order'

# %%
df.at[18,'FILTERS']='membership_startDate-date;membership_order-number'

# %%
df.at[18, 'TOOLTIP'] ='membership_startDate-Start Date;membership_order-Order number'

# %%
df.at[0, 'FILTERS'] = "OP Theme_Publication date-date;OP Theme_Theme name-text;OP Theme Main_Publication date-date;OP Theme Main_Publication number-number"

# %% [markdown]
# df.at[0, 'OPTION_TEXT'] = "PUBLICATIONS - Publications by OP Theme"
# corporateBody_country-dropdown

# %%
query="""\nPREFIX xsd: <http://www.w3.org/2001/XMLSchema#> \n    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>\n    PREFIX org: <http://www.w3.org/ns/org#>\n    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>\n    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>\n    PREFIX foaf: <http://xmlns.com/foaf/0.1/>\n    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>\n    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>\n            SELECT DISTINCT ?corporateBody ?directoryOrg ?directoryOrg_uri ?directoryOrg_order ?directoryOrg_protocolLevel ?directoryOrg_email ?directoryOrg_telephone ?directoryOrg_locality ?directoryOrg_postalCode ?directoryOrg_streetAddress ?directoryOrg_homepage\n            where {{?corporateBody_uri skos:prefLabel ?corporateBody.\n                    ?corporateBody_uri org:hasSubOrganization ?directoryOrg_uri. \n                    ?directoryOrg_uri skos:prefLabel ?directoryOrg.\n                    OPTIONAL {\n                    ?directoryOrg_uri euvoc:order ?directoryOrg_order.\n                    }\n                    OPTIONAL {\n                    ?directoryOrg_uri euvoc:protocolLevel ?directoryOrg_protocolLevel.\n                    }\n                    #OPTIONAL {\n                    #?directoryOrg_uri euvoc:contactPoint ?directoryOrg_contactPoint.\n                    #}\n                    #OPTIONAL {\n                    #?directoryOrg_contactPoint vcard:hasEmail ?directoryOrg_email.\n                    #}\n                    #OPTIONAL {\n                    #?directoryOrg_contactPoint vcard:hasTelephone ?directoryOrg_telephoneBN.\n                    #}\n                    #OPTIONAL {\n                    #?directoryOrg_contactPoint vcard:locality ?directoryOrg_locality.\n                    #}\n                    #OPTIONAL {\n                    #?directoryOrg_contactPoint vcard:postal-code ?directoryOrg_postalCode.\n                    #}\n                    #OPTIONAL {\n                    #?directoryOrg_contactPoint vcard:street-address ?directoryOrg_streetAddress.\n                    #}\n                    #OPTIONAL {\n                    #?directoryOrg_contactPoint foaf:homepage ?directoryOrg_homepage.\n                    #}\n                    #OPTIONAL {\n                    #?directoryOrg_telephoneBN vcard:hasValue ?directoryOrg_telephone.  \n                    #}\n                    } \n                   filter(?corporateBody_uri=<PARAMETER>).\n                   FILTER(langMatches(lang(?directoryOrg), "en")).\n                   FILTER(langMatches(lang(?corporateBody), "en")).\n                   }\n                   #ORDER BY ?whoiswhoOrg ?country ?location\n                   #LIMIT 50\n    
"""

# %%
query="""PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX org: <http://www.w3.org/ns/org#>
PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
SELECT DISTINCT ?directoryOrg ?membership ?directoryOrg_uri AS ?membership_directoryOrg ?membership_startDate ?membership_order
where {{?membership_uri org:organization ?directoryOrg_uri;
        euvoc:order ?membership_order;
        euvoc:positionComplement ?membership;
        euvoc:startDate ?membership_startDate;
        euvoc:order ?membership_order.
        # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
       } 
       filter(?directoryOrg_uri=<PARAMETER>).
       FILTER(langMatches(lang(?membership), "en")).
       FILTER(langMatches(lang(?directoryOrg), "en")).
      }GROUP BY ?membership    
    """

# %%
df.at[18, 'QUERY'] = query

# %%
df.at[0, 'PROPERTIES']='opThemeMain-opThemeMain_uri;opTheme-opTheme_uri;opTheme-opTheme_dateCreated'

# %%
df.at[0, 'FILTERS'] ='opTheme_dateCreated-date'

# %% [markdown]
# ## Example of a new row

# %%
className="Publication Manifestationn"

# %%
url=""

# %%
hierarchy=""

# %%
properties=""

# %%
option="Open pdf"

# %%
option_text="Open pdf document"

# %%
query=""""""

# %%
rowType="PDF"

# %%
classes=""

# %%
parameters=""

# %%
tooltip=""

# %%
filters=""

# %%
function=""

# %%
record={'CLASS':className, 'URL':url, 'QUERY':query, 'HIERARCHY':hierarchy, 'PROPERTIES':properties,
        'OPTION':option,'OPTION_TEXT':option_text,'TYPE':rowType, 'CLASSES':classes, 'PARAMETERS':parameters, 'FILTERS':filters, 'TOOLTIP':tooltip,
       'FUNCTION':function}

# %%
df_record=pd.DataFrame([record])

# %%
df_record
# Out:
#                         CLASS URL QUERY HIERARCHY PROPERTIES    OPTION  \
# 0  Publication Manifestationn                                 Open pdf
#
#          OPTION_TEXT TYPE CLASSES PARAMETERS FILTERS TOOLTIP FUNCTION
# 0  Open pdf document  PDF

# %%
df=pd.concat([df,df_record])

# %%
className="Directory Organization"

# %%
url="https://publications.europa.eu/webapi/rdf/sparql"

# %%
hierarchy="membership-person"

# %%
properties="membership-membership_order;membership-membership_positionStatus;person-person_image"

# %%
option="Hierarchy membership and persons"

# %%
option_text="Hierarchy membership and persons"

# %%
query="""PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX org: <http://www.w3.org/ns/org#>
PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX resource: <http://publications.europa.eu/resource/>
SELECT DISTINCT ?membership ?membership_order ?membership_positionStatus ?person ?person_image 

where {{?membership_uri org:organization ?directoryOrg_uri;
                        euvoc:order ?membership_order;
                        euvoc:positionComplement ?membership;
                        euvoc:positionStatus ?membership_positionStatusUri.
    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
    # ?membership_positionStatusUri skos:prefLabel ?membership_positionStatus.
    # ?person_uri org:hasMembership ?membership_uri;
                foaf:name ?person.
OPTIONAL{
    # ?person_uri foaf:img ?person_image.
    BIND (STRBEFORE(STRAFTER( STR(?person_image), "https://www.europarl.europa.eu/mepphoto/" ), ".jpg" ) AS ?person_id)
    }
    } 
filter(?directoryOrg_uri=<PARAMETER>).
FILTER(langMatches(lang(?membership), "en")).
FILTER(langMatches(lang(?membership_positionStatus), "en")).
FILTER(langMatches(lang(?directoryOrg), "en")).
}ORDER BY ?membership_order ?person"""

# %%
rowType="TREEGRAPH"

# %%
classes="membership-Membership;person-Person"

# %%
parameters=""

# %%
tooltip=""

# %%
filters=""

# %%
function=""

# %%
record={'CLASS':className, 'URL':url, 'QUERY':query, 'HIERARCHY':hierarchy, 'PROPERTIES':properties,
        'OPTION':option,'OPTION_TEXT':option_text,'TYPE':rowType, 'CLASSES':classes, 'PARAMETERS':parameters, 'FILTERS':filters, 'TOOLTIP':tooltip,
       'FUNCTION':function}

# %%
df_record=pd.DataFrame([record])

# %%
df_record
# Out:
#                     CLASS                                               URL  \
# 0  Directory Organization  https://publications.europa.eu/webapi/rdf/sparql
#
#                                                QUERY          HIERARCHY  \
# 0  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#...  membership-person
#
#                                           PROPERTIES  \
# 0  membership-membership_order;membership-members...
#
#                              OPTION                       OPTION_TEXT  \
# 0  Hierarchy membership and persons  Hierarchy membership and persons
#
#         TYPE                              CLASSES PARAMETERS FILTERS TOOLTIP  \
# 0  TREEGRAPH  membership-Membership;person-Person
#
#   FUNCTION
# 0

# %% [markdown]
# ## Copy row dataframe

# %%
df_record=df.iloc[24].to_frame().transpose()

# %%
df=pd.concat([df,df_record])

# %%
df
# Out:
#                         CLASS  \
# 0                 opThemeMain
# 1                  Membership
# 2      Directory Organization
# 3                    OP Theme
# 4                     eurovoc
# 5             Eurovoc Concept
# 6                        nuts
# 7                    taxonomy
# 8              Taxonomy Level
# 9                         det
# 10            Eurovoc Concept
# 11                  DET Level
# 12                  DET Level
# 13                 Continents
# 14                 Continents
# 15               Organisation
# 16                      eurun
# 17              corporateBody
# 18     Directory Organization
# 19            Membership Type
# 20                     Person
# 21                   OP Theme
# 22       Publication Document
# 23              corporateBody
# 24     Directory Organization
# 25                 DEUCatalog
# 26  Publication Manifestation
# 24     Directory Organization
#
#                                                  URL  \
# ...

# %%
df=df.reset_index()
del df["index"]
df
# Out:
#     index                      CLASS  \
# 0       0                opThemeMain
# 1       1                 Membership
# 2       2     Directory Organization
# 3       3                   OP Theme
# 4       4                    eurovoc
# 5       5            Eurovoc Concept
# 6       6                       nuts
# 7       7                   taxonomy
# 8       8             Taxonomy Level
# 9       9                        det
# 10     10            Eurovoc Concept
# 11     11                  DET Level
# 12     12                  DET Level
# 13     13                 Continents
# 14     14                 Continents
# 15     15               Organisation
# 16     16                      eurun
# 17     17              corporateBody
# 18     18     Directory Organization
# 19     19            Membership Type
# 20     20                     Person
# 21     21                   OP Theme
# 22     22       Publication Document
# 23     23              corporateBody
# ...

# %%
df
# Out:
#                         CLASS  \
# 0                 opThemeMain
# 1                  Membership
# 2      Directory Organization
# 3                    OP Theme
# 4                     eurovoc
# 5             Eurovoc Concept
# 6                        nuts
# 7                    taxonomy
# 8              Taxonomy Level
# 9                         det
# 10            Eurovoc Concept
# 11                  DET Level
# 12                  DET Level
# 13                 Continents
# 14                 Continents
# 15               Organisation
# 16                      eurun
# 17              corporateBody
# 18     Directory Organization
# 19            Membership Type
# 20                     Person
# 21                   OP Theme
# 22       Publication Document
# 23              corporateBody
# 24     Directory Organization
# 25                 DEUCatalog
# 26  Publication Manifestation
# 27     Directory Organization
#
#                                                  URL  \
# ...

# %%
df.at[27, 'TYPE'] = "TABLE"

# %%
df.at[27, 'OPTION'] = "Table membership and persons"
df.at[27, 'OPTION_TEXT'] = "Table membership and persons"

# %% [markdown]
# ## Save file

# %%
df.to_csv("config_basicMode.txt", sep='\t',index=False,encoding="utf-8")

# %% [markdown]
# ## JSON FILE

# %%
config_json=[{"class":"", "endpoint_url":"", "query":"","hierarchy":[{"parent":"","child":""}],"property":[{"class":"","property":""}],"option":"",
 "option_text":"","classes_text":[{"class":"","text":""}],"parameters":[{"property":""}],"filters":[{"property":"","filter_type":""}],"tooltip":[{"property":"","tooltip_text":""}]}]

# %%
config_json
# Out:
# [{'class': '',
#   'endpoint_url': '',
#   'query': '',
#   'hierarchy': [{'parent': '', 'child': ''}],
#   'property': [{'class': '', 'property': ''}],
#   'option': '',
#   'option_text': '',
#   'classes_text': [{'class': '', 'text': ''}],
#   'parameters': [{'property': ''}],
#   'filters': [{'property': '', 'filter_type': ''}],
#   'tooltip': [{'property': '', 'tooltip_text': ''}]}]

# %%
df_notTree=df[df["TYPE"]!="TREE"].reset_index(drop=True)

# %%
df=df[df["TYPE"]=="TREE"].reset_index(drop=True)

# %%
df
# Out:
#                      CLASS                                               URL  \
# 0              opThemeMain  https://publications.europa.eu/webapi/rdf/sparql
# 1               Membership  https://publications.europa.eu/webapi/rdf/sparql
# 2   Directory Organization  https://publications.europa.eu/webapi/rdf/sparql
# 3                 OP Theme  https://publications.europa.eu/webapi/rdf/sparql
# 4                  eurovoc  https://publications.europa.eu/webapi/rdf/sparql
# 5          Eurovoc Concept  https://publications.europa.eu/webapi/rdf/sparql
# 6                     nuts  https://publications.europa.eu/webapi/rdf/sparql
# 7                 taxonomy  https://publications.europa.eu/webapi/rdf/sparql
# 8           Taxonomy Level  https://publications.europa.eu/webapi/rdf/sparql
# 9                      det  https://publications.europa.eu/webapi/rdf/sparql
# 10         Eurovoc Concept  https://publications.europa.eu/webapi/rdf/sparql
# ...

# %%
df_notTree
# Out:
#                     CLASS                                               URL  \
# 0                     org  https://publications.europa.eu/webapi/rdf/sparql
# 1                  Person                 https://query.wikidata.org/sparql
# 2  Directory Organization  https://publications.europa.eu/webapi/rdf/sparql
#
#                                                QUERY          HIERARCHY  \
# 0  PREFIX skos: <http://www.w3.org/2004/02/skos/c...                org
# 1  \n    PREFIX xsd: <http://www.w3.org/2001/XMLS...     person-article
# 2  PREFIX xsd: <http://www.w3.org/2001/XMLSchema#...  membership-person
#
#                                           PROPERTIES  \
# 0  org-org_desc;org-org_code;org-org_startDate;or...
# 1                                            article
# 2  membership-membership_order;membership-members...
#
#                              OPTION                       OPTION_TEXT  \
# 0            Timeline organisations            Timeline organisations
# ...

# %%
corporateBody_country-dropdown;corporateBody_l

# %%
def convert_json(df):
    json_lines=[]
    for index,row in df.iterrows():
        line={}
        line["class"]=row["CLASS"]
        line["endpoint_url"]=row["URL"]
        line["query"]=row["QUERY"].replace('\n',' ')
        line["hierarchy"]=[]
        line["properties"]=[]
        line["classes_text"]=[]
        line["parameters"]=[]
        line["filters"]=[]
        line["tooltip"]=[]
        #for c in row["HIERARCHY"].split("-"):
        hierarchy=row["HIERARCHY"].split("-")
        for x in range(len(hierarchy)-1): 
            line["hierarchy"].append({"parent":hierarchy[x],"child":hierarchy[x+1]})
        for p in row["PROPERTIES"].split(";"):
            properties=p.split("-")
            line["properties"].append({"class":properties[0],"property":properties[1]})
        line["option"]=row["OPTION"]
        line["option_text"]=row["OPTION_TEXT"]
        for c in row["CLASSES"].split(";"):
            classes_text=c.split("-")
            if c!="":
                line["classes_text"].append({"class":classes_text[0],"text":classes_text[1]})  
        if(isinstance(row["PARAMETERS"], str)):
            for p in row["PARAMETERS"].split(";"):
                line["parameters"].append({"property":p})
        if(isinstance(row["FILTERS"], str)):
            for f in row["FILTERS"].split(";"):
                filters=f.split("-")
                if f!="":
                    line["filters"].append({"property":filters[0],"filter_type":filters[1]})
        if(isinstance(row["TOOLTIP"], str)):
            for t in row["TOOLTIP"].split(";"):
                tooltip=t.split("-")
                if t!="":
                    line["tooltip"].append({"property":tooltip[0],"tooltip_text":tooltip[1]})
        json_lines.append(line)
    return json_lines

# %%
import json
json_string=convert_json(df)
json_string = json.dumps(json_string)
jsonFile = open("data.json", "w")
jsonFile.write(json_string)
jsonFile.close()

# %%
from SPARQLWrapper import SPARQLWrapper,JSON
json_loaded=json.loads(json_string)
for j in json_loaded:
    #print(j["endpoint_url"])
    sparql = SPARQLWrapper(j["endpoint_url"])
    print(j["query"])
    sparql.setQuery(j["query"])
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    print(results)
# Out:
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> PREFIX skos: <http://www.w3.org/2004/02/skos/core#> PREFIX cdm: <http://publications.europa.eu/ontology/cdm#> PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> PREFIX dcterms: <http://purl.org/dc/terms/> SELECT DISTINCT ?opThemeMain ?opThemeMain_uri ?opTheme ?opTheme_uri ?opTheme_dateCreated     where     {         {?opTheme_uri rdf:type ?opThemeMain_uri;         skos:prefLabel ?opTheme;         dcterms:created ?opTheme_dateCreated.         ?opThemeMain_uri rdfs:label ?opThemeMain                             }     filter(?opThemeMain_uri=<http://publications.europa.eu/ontology/cdm#concept_op_theme>)     FILTER(langMatches(lang(?opTheme), "en")).     filter not exists {         ?opTheme_uri skos:broader ?broader         }     }ORDER BY ?opThemeMain ?opTheme
# ...

# %%
[{"class":"", "endpoint_url":"", "query":"","hierarchy":[{"parent":"","child":""}],"property":[{"class":"","property":""}],"option":"",
 "option_text":"","classes_text":[{"class":"","text":""}],"parameters":[{"property":""}],"filters":[{"property":"","filter_type":""}],"tooltip":[{"property":"","tooltip_text":""}]}]
