# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

# %% [markdown]
# ## QUERY IN CONFIGURATION FILE

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX org: <http://www.w3.org/ns/org#>
PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
SELECT DISTINCT ?corporateBody ?directoryOrg ?directoryOrg_uri ?directoryOrg_order ?directoryOrg_protocolLevel ?directoryOrg_email ?directoryOrg_telephone ?directoryOrg_locality ?directoryOrg_postalCode ?directoryOrg_streetAddress ?directoryOrg_homepage
where {{?corporateBody_uri skos:prefLabel ?corporateBody.
        # ?corporateBody_uri org:hasSubOrganization ?directoryOrg_uri.
        # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
        #OPTIONAL {
        #    ?directoryOrg_uri euvoc:order ?directoryOrg_order.
        #}
        #OPTIONAL {
        #    ?directoryOrg_uri euvoc:protocolLevel ?directoryOrg_protocolLevel.
        #}                    
        #OPTIONAL {
            #?directoryOrg_uri euvoc:contactPoint ?directoryOrg_contactPoint.
        #}
        #OPTIONAL {
            #?directoryOrg_contactPoint vcard:hasEmail ?directoryOrg_email.
        #}
        #OPTIONAL {
            #?directoryOrg_contactPoint vcard:hasTelephone ?directoryOrg_telephoneBN.
        #}
        #OPTIONAL {
        #    ?directoryOrg_contactPoint vcard:locality ?directoryOrg_locality.
        #}
        #OPTIONAL {
            #?directoryOrg_contactPoint vcard:postal-code ?directoryOrg_postalCode.
        #}
        #OPTIONAL {
            #?directoryOrg_contactPoint vcard:street-address ?directoryOrg_streetAddress.
        #}
        #OPTIONAL {
            #?directoryOrg_contactPoint foaf:homepage ?directoryOrg_homepage.
        #}
        #OPTIONAL {
            #?directoryOrg_telephoneBN vcard:hasValue ?directoryOrg_telephone.
        #}
       } \n                   
       filter(?corporateBody_uri=<PARAMETER>).
       FILTER(langMatches(lang(?directoryOrg), "en")).
       FILTER(langMatches(lang(?corporateBody), "en")).
       }
       #ORDER BY ?whoiswhoOrg ?country ?location
       #LIMIT 50\n    
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['corporateBody', 'directoryOrg', 'directoryOrg_uri']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
uri="http://publications.europa.eu/resource/directory/membership/COM_COLL/COM-MDR_COM_COLL-00006A0440FF-000022A263-PRESID_COM-"
#uri="http://publications.europa.eu/resource/directory/person/EP_EP_096864"
#uri="http://publications.europa.eu/resource/directory/organization/PUBL/COM_CRF_245238"
#uri="http://publications.europa.eu/resource/directory/organization/EP"
#uri="http://publications.europa.eu/resource/authority/corporate-body/CONSIL"
#uri="http://publications.europa.eu/resource/directory/PUBL"

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                       #skos:prefLabel ?label.
                    } 
                   filter(?s=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/COM_COLL/COM-MDR_COM_COLL-00006A0440FF-000022A263-PRESID_COM-'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#Membership'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/COM_COLL/COM-MDR_COM_COLL-00006A0440FF-000022A263-PRESID_COM-'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#startDate'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2019-12-01'}},
#    {'s': {'type': 'uri',
# ...

# %%
'http://www.w3.org/ns/org#member'-'http://publications.europa.eu/resource/directory/person/COM_00006A0440FF'

# %%
'http://www.w3.org/ns/org#organization'-'http://publications.europa.eu/resource/authority/corporate-body/COM_COLL'

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/PUBL'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
            SELECT DISTINCT ?directoryOrg ?directoryOrg2 ?directoryOrg2_uri ?directoryOrg_order ?directoryOrg_protocolLevel ?directoryOrg_email ?directoryOrg_telephone ?directoryOrg_locality ?directoryOrg_postalCode ?directoryOrg_streetAddress ?directoryOrg_homepage
            where {{?directoryOrg_uri org:hasSubOrganization ?directoryOrg_uri2.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?directoryOrg2_uri skos:prefLabel ?directoryOrg2;
                                      euvoc:order ?directoryOrg_order;
                                      euvoc:protocolLevel ?directoryOrg_protocolLevel.
                                      #euvoc:contactPoint ?directoryOrg_contactPoint.
                    #OPTIONAL {
                    #?directoryOrg_uri2 euvoc:contactPoint ?directoryOrg_contactPoint2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:hasEmail ?directoryOrg_email2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:hasTelephone ?directoryOrg_telephoneBN2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:locality ?directoryOrg_locality2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:postal-code ?directoryOrg_postalCode2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:street-address ?directoryOrg_streetAddress2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 foaf:homepage ?directoryOrg_homepage2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_telephoneBN2 vcard:hasValue ?directoryOrg_telephone2.  
                    #}
                    } 
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/authority/corporate-body/EP_SG>).
                   FILTER(langMatches(lang(?directoryOrg2), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   }
                   #ORDER BY ?whoiswhoOrg ?country ?location
                   #LIMIT 50
    """)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['directoryOrg',
#    'directoryOrg2',
#    'directoryOrg2_uri',
#    'directoryOrg_order',
#    'directoryOrg_protocolLevel',
#    'directoryOrg_email',
#    'directoryOrg_telephone',
#    'directoryOrg_locality',
#    'directoryOrg_postalCode',
#    'directoryOrg_streetAddress',
#    'directoryOrg_homepage']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Secretariat-General of the European Parliament'},
#     'directoryOrg2': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Delegation to the United States of America'},
#     'directoryOrg2_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/DEL_USA'},
#     'directoryOrg_order': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '37884'},
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
            SELECT DISTINCT ?directoryOrg_uri ?directoryOrg2_uri 
            where {{?directoryOrg_uri org:hasSubOrganization ?directoryOrg2_uri.
                    #?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    #?directoryOrg2_uri skos:prefLabel ?directoryOrg2;
                    } 
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/authority/corporate-body/EP_SG>).
                   #FILTER(langMatches(lang(?directoryOrg2), "en")).
                   #FILTER(langMatches(lang(?directoryOrg), "en")).
                   }
                   #ORDER BY ?whoiswhoOrg ?country ?location
                   #LIMIT 50
    """)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['directoryOrg_uri', 'directoryOrg2_uri']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_SG'},
#     'directoryOrg2_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_INTERNAL_POL'}},
#    {'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_SG'},
#     'directoryOrg2_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_RESEARCH'}},
#    {'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_SG'},
#     'directoryOrg2_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_EXTERN_POL'}},
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
            SELECT DISTINCT ?directoryOrg ?directoryOrg2 ?directoryOrg2_uri ?directoryOrg_order ?directoryOrg_protocolLevel ?directoryOrg_email ?directoryOrg_telephone ?directoryOrg_locality ?directoryOrg_postalCode ?directoryOrg_streetAddress ?directoryOrg_homepage
            where {{?directoryOrg_uri org:hasSubOrganization ?directoryOrg_uri2.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?directoryOrg2_uri skos:prefLabel ?directoryOrg2;
                                      euvoc:order ?directoryOrg_order;
                                      euvoc:protocolLevel ?directoryOrg_protocolLevel.
                                      #euvoc:contactPoint ?directoryOrg_contactPoint.
                    #OPTIONAL {
                    #?directoryOrg_uri2 euvoc:contactPoint ?directoryOrg_contactPoint2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:hasEmail ?directoryOrg_email2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:hasTelephone ?directoryOrg_telephoneBN2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:locality ?directoryOrg_locality2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:postal-code ?directoryOrg_postalCode2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:street-address ?directoryOrg_streetAddress2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 foaf:homepage ?directoryOrg_homepage2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_telephoneBN2 vcard:hasValue ?directoryOrg_telephone2.  
                    #}
                    } 
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/authority/corporate-body/EP_SG>).
                   FILTER(langMatches(lang(?directoryOrg2), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   }
                   #ORDER BY ?whoiswhoOrg ?country ?location
                   #LIMIT 50
                   """)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['directoryOrg',
#    'directoryOrg2',
#    'directoryOrg2_uri',
#    'directoryOrg_order',
#    'directoryOrg_protocolLevel',
#    'directoryOrg_email',
#    'directoryOrg_telephone',
#    'directoryOrg_locality',
#    'directoryOrg_postalCode',
#    'directoryOrg_streetAddress',
#    'directoryOrg_homepage']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Secretariat-General of the European Parliament'},
#     'directoryOrg2': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Delegation to the United States of America'},
#     'directoryOrg2_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/DEL_USA'},
#     'directoryOrg_order': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '37884'},
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> 
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?org ?orgLabel ?roleLabel
            where {{?s rdf:type org:Membership;
                       org:organization ?org;
                       org:role ?role.
                    # ?org skos:prefLabel ?orgLabel.
                    # ?role skos:prefLabel ?roleLabel.
                    } 
                   #filter(?s=<"""+uri+""">)
                   FILTER(langMatches(lang(?roleLabel), "en")).
                   FILTER(langMatches(lang(?orgLabel), "en")).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'org', 'orgLabel', 'roleLabel']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'bnode', 'value': 'nodeID://b72928736'},
#     'org': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EUMS9'},
#     'orgLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'The nine Member States: Belgium, Denmark, Germany, Ireland, France, Italy, Luxembourg, Netherlands, United Kingdom'},
#     'roleLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'}},
#    {'s': {'type': 'bnode', 'value': 'nodeID://b72929528'},
#     'org': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EUMS9'},
#     'orgLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'The nine Member States: Belgium, Denmark, Germany, Ireland, France, Italy, Luxembourg, Netherlands, United Kingdom'},
# ...

# %%
# ?r org:hasMembership ?member1.

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> 
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?o
            where {{?s org:hasMembership ?o.} 
                   #filter(?s=<"""+uri+""">)
                   #FILTER(langMatches(lang(?roleLabel), "en")).
                   #FILTER(langMatches(lang(?orgLabel), "en")).
                   filter (!strStarts(str(?s), 'http://publications.europa.eu/resource/authority/country/')).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
result_value=[]
for r in results["results"]["bindings"]:
    result_value.append({"person":r["s"]["value"],"membership":r["o"]["value"]})
df_temp=pd.DataFrame(result_value)
df_temp
# Out:
#                                                   person  \
# 0      http://publications.europa.eu/resource/directo...
# 1      http://publications.europa.eu/resource/directo...
# 2      http://publications.europa.eu/resource/directo...
# 3      http://publications.europa.eu/resource/directo...
# 4      http://publications.europa.eu/resource/directo...
# ...                                                  ...
# 49425  http://publications.europa.eu/resource/directo...
# 49426  http://publications.europa.eu/resource/directo...
# 49427  http://publications.europa.eu/resource/directo...
# 49428  http://publications.europa.eu/resource/directo...
# 49429  http://publications.europa.eu/resource/directo...
#
#                                               membership
# 0      http://publications.europa.eu/resource/directo...
# 1      http://publications.europa.eu/resource/directo...
# 2      http://publications.europa.eu/resource/directo...
# ...

# %%
df_temp.to_excel("df_temp.xlsx",index=False,encoding="utf-8")

# %%
df_temp.iloc[50224]["membership"]
# Out:
# 'nodeID://b72955868'

# %%
uri='http://publications.europa.eu/resource/directory/person/COM_000007F66F'

# %%
uri='http://publications.europa.eu/resource/directory/membership/EMPL/COM-CRF_1583-00000A472-0000006026--'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                    } 
                   filter(?o=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EMPL/COM-CRF_80890-000007F66F-000033F3D7--'},
#     'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#member'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/COM_000007F66F'}}]}}

# %%
uri='http://publications.europa.eu/resource/directory/membership/EMPL/COM-CRF_80890-000007F66F-000033F3D7--'
uri="http://publications.europa.eu/resource/directory/person/COM_00000AA30C66"

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/COM_00000AA30C66'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/Person'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/COM_00000AA30C66'},
#     'p': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/name'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'H. KASK'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/COM_00000AA30C66'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#notation'},
#     'o': {'type': 'typed-literal',
# ...

# %%
'http://xmlns.com/foaf/0.1/name'
'http://www.w3.org/2006/vcard/ns#hasGender'
'http://www.w3.org/ns/org#hasMembership'

# %%
uri="http://publications.europa.eu/resource/directory/membership/REGIO/COM-CRF_64111-00000AA30C66-0000D00FC--"

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?membership ?person ?person_uri ?person_gender ?person_genderUri 
            where {{?person_uri org:hasMembership ?membership_uri;
                                vcard:hasGender ?person_genderUri;
                                foaf:name ?person.
                    # ?membership_uri euvoc:positionComplement ?membership.
                    # ?person_genderUri skos:prefLabel ?person_gender.
                    } 
                   filter(?membership_uri=<"""+uri+""">)
                   FILTER(langMatches(lang(?membership), "en")).
                   FILTER(langMatches(lang(?person_gender), "en")).
                   }ORDER BY ?person
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['membership',
#    'person',
#    'person_uri',
#    'person_gender',
#    'person_genderUri']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'membership': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Programme Manager - EU policies'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'H. KASK'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/COM_00000AA30C66'},
#     'person_gender': {'type': 'literal', 'xml:lang': 'en', 'value': 'female'},
#     'person_genderUri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/human-sex/FEMALE'}}]}}

# %%
uri='http://publications.europa.eu/resource/directory/person/COM_00000AA34CA0'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?s ?p ?o
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/COM_00000AA34CA0'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/Person'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/COM_00000AA34CA0'},
#     'p': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/name'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'E. TROTEMANN'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/COM_00000AA34CA0'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#notation'},
#     'o': {'type': 'typed-literal',
# ...

# %%
http://publications.europa.eu/ontology/euvoc#startDate
'http://publications.europa.eu/ontology/euvoc#endDate'
'http://publications.europa.eu/ontology/euvoc#order'
'http://publications.europa.eu/ontology/euvoc#positionComplement'
'http://publications.europa.eu/ontology/euvoc#positionStatus'
'http://publications.europa.eu/ontology/euvoc#roleQualification'
'http://publications.europa.eu/ontology/euvoc#contactPoint'

# %%
uri='http://publications.europa.eu/resource/directory/organization/ECA/ECA_ECA.CH3'
uri='http://publications.europa.eu/resource/directory/organization/EMPL/COM_CRF_1583'
uri='http://publications.europa.eu/resource/directory/organization/EP_MEPS/EP_MEPS'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?directoryOrg ?membership_uri ?membership_startDate ?membership_endDate ?membership_order ?membership ?membership_positionStatusUri ?membership_positionStatus
            where {{?membership_uri org:organization ?directoryOrg_uri;
                       euvoc:startDate ?membership_startDate;
                       euvoc:endDate ?membership_endDate;
                       euvoc:order ?membership_order;
                       euvoc:positionComplement ?membership;
                       euvoc:positionStatus ?membership_positionStatusUri.
                       #euvoc:roleQualification ?roleQualification_uri;
                       #euvoc:contactPoint ?contactPoint.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?membership_positionStatusUri skos:prefLabel ?membership_positionStatus.
                    #?membership_uri skos:prefLabel ?membership.
                    #?roleQualification_uri skos:prefLabel ?roleQualification.
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   FILTER(langMatches(lang(?membership), "en")).
                   FILTER(langMatches(lang(?membership_positionStatus), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   }ORDER BY ?membership
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
#result_value=[]
#for r in results["results"]["bindings"]:
#    result_value.append({"membership":r["s"]["value"],"organization":r["o"]["value"]})
#df_temp=pd.DataFrame(result_value)
#df_temp
# Out:
# {'head': {'link': [],
#   'vars': ['directoryOrg',
#    'membership_uri',
#    'membership_startDate',
#    'membership_endDate',
#    'membership_order',
#    'membership',
#    'membership_positionStatusUri',
#    'membership_positionStatus']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
            SELECT DISTINCT ?directoryOrg ?directoryOrg2 ?directoryOrg_uri2 ?directoryOrg_order2 ?directoryOrg_protocolLevel2 ?directoryOrg_email2 ?directoryOrg_telephone2 ?directoryOrg_locality2 ?directoryOrg_postalCode2 ?directoryOrg_streetAddress2 ?directoryOrg_homepage2
            where {{?directoryOrg_uri org:hasSubOrganization ?directoryOrg_uri2.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?directoryOrg_uri2 skos:prefLabel ?directoryOrg2;
                                      euvoc:order ?directoryOrg_order2;
                                      euvoc:protocolLevel ?directoryOrg_protocolLevel2.
                                      #euvoc:contactPoint ?directoryOrg_contactPoint2.
                    #OPTIONAL {
                    #?directoryOrg_uri2 euvoc:contactPoint ?directoryOrg_contactPoint2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:hasEmail ?directoryOrg_email2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:hasTelephone ?directoryOrg_telephoneBN2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:locality ?directoryOrg_locality2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:postal-code ?directoryOrg_postalCode2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 vcard:street-address ?directoryOrg_streetAddress2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint2 foaf:homepage ?directoryOrg_homepage2.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_telephoneBN2 vcard:hasValue ?directoryOrg_telephone2.  
                    #}
                    } 
                   filter(?directoryOrg_uri=<"""+uri+""">).
                   FILTER(langMatches(lang(?directoryOrg2), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   }
                   #ORDER BY ?whoiswhoOrg ?country ?location
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['directoryOrg',
#    'directoryOrg2',
#    'directoryOrg_uri2',
#    'directoryOrg_order2',
#    'directoryOrg_protocolLevel2',
#    'directoryOrg_email2',
#    'directoryOrg_telephone2',
#    'directoryOrg_locality2',
#    'directoryOrg_postalCode2',
#    'directoryOrg_streetAddress2',
#    'directoryOrg_homepage2']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Members of the European Parliament (MEPs)'},
#     'directoryOrg2': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Parliament’s political groups'},
#     'directoryOrg_uri2': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP'},
#     'directoryOrg_order2': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '8'},
# ...

# %%
uri='http://publications.europa.eu/resource/directory/organization/EP_MEPS/EP_DPPEBU'

# %%
uri='http://publications.europa.eu/resource/directory/organization/EP_MEPS/EP_DPPEBU'
uri='http://publications.europa.eu/resource/directory/organization/EP_MEPS/EP_DPPEBURO'
uri='http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEBURO-DPPE197525---'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">).
                   #FILTER(langMatches(lang(?label), "en")).
                   #filter (!strStarts(str(?s), 'nodeID://')).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EP_MEPS/EP_MEPS'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EP_MEPS/EP_MEPS'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#Organization'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EP_MEPS/EP_MEPS'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s org:organization ?o.
                    } 
                   #filter(?s=<"""+uri+""">).
                   #FILTER(langMatches(lang(?label), "en")).
                   filter (!strStarts(str(?s), 'nodeID://')).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
result_value=[]
for r in results["results"]["bindings"]:
    result_value.append({"membership":r["s"]["value"],"organization":r["o"]["value"]})
df_temp=pd.DataFrame(result_value)
df_temp
# Out:
#                                               membership  \
# 0      http://publications.europa.eu/resource/directo...
# 1      http://publications.europa.eu/resource/directo...
# 2      http://publications.europa.eu/resource/directo...
# 3      http://publications.europa.eu/resource/directo...
# 4      http://publications.europa.eu/resource/directo...
# ...                                                  ...
# 48976  http://publications.europa.eu/resource/directo...
# 48977  http://publications.europa.eu/resource/directo...
# 48978  http://publications.europa.eu/resource/directo...
# 48979  http://publications.europa.eu/resource/directo...
# 48980  http://publications.europa.eu/resource/directo...
#
#                                             organization
# 0      http://publications.europa.eu/resource/directo...
# 1      http://publications.europa.eu/resource/directo...
# 2      http://publications.europa.eu/resource/directo...
# ...

# %%
df_temp.to_excel("df_temp2.xlsx",index=False,encoding="utf-8")

# %%
uri='http://www.w3.org/ns/org#subOrganizationOf'
uri='http://publications.europa.eu/resource/directory/membership/EMPL/COM-CRF_1583-0000DDC2-000037AD0C--'

# %%
uri="nodeID://b72148471"

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{<nodeID://b72147860> ?p ?o.
                    } 
                   #filter(?s=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
#result_value=[]
#for r in results["results"]["bindings"]:
#    result_value.append({"suborganization":r["s"]["value"],"organization":r["o"]["value"]})
#df_temp=pd.DataFrame(result_value)
#df_temp
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/address-type/TEL'}},
#    {'p': {'type': 'uri', 'value': 'http://www.w3.org/2006/vcard/ns#hasValue'},
#     'o': {'type': 'uri', 'value': 'tel:+32-229-62523'}}]}}

# %%
df_temp.to_excel("df_temp3.xlsx",index=False,encoding="utf-8")

# %%
df_temp.suborganization.tolist()
# Out:
# ['http://publications.europa.eu/resource/authority/corporate-body/DEL_USA',
#  'http://publications.europa.eu/resource/authority/corporate-body/ACER',
#  'http://publications.europa.eu/resource/authority/corporate-body/EP_OFF_LIT',
#  'http://publications.europa.eu/resource/authority/corporate-body/DEL_MAR',
#  'http://publications.europa.eu/resource/authority/corporate-body/DEL_IND_BTN',
#  'http://publications.europa.eu/resource/authority/corporate-body/AGRI',
#  'http://publications.europa.eu/resource/authority/corporate-body/BUDG',
#  'http://publications.europa.eu/resource/authority/corporate-body/CJ',
#  'http://publications.europa.eu/resource/authority/corporate-body/COM',
#  'http://publications.europa.eu/resource/authority/corporate-body/COMP',
#  'http://publications.europa.eu/resource/authority/corporate-body/CONSIL',
#  'http://publications.europa.eu/resource/authority/corporate-body/COR',
#  'http://publications.europa.eu/resource/authority/corporate-body/EAC',
# ...

# %%
df_temp.organization.tolist()
# Out:
# ['http://publications.europa.eu/resource/authority/corporate-body/EEAS_DEL',
#  'http://publications.europa.eu/resource/directory/organization/AGENCIES/AGENCIES',
#  'http://publications.europa.eu/resource/directory/organization/EP_SG/EP_DPPE04B',
#  'http://publications.europa.eu/resource/authority/corporate-body/EEAS_DEL',
#  'http://publications.europa.eu/resource/authority/corporate-body/EEAS_DEL',
#  'http://publications.europa.eu/resource/authority/corporate-body/COM',
#  'http://publications.europa.eu/resource/authority/corporate-body/COM',
#  'http://publications.europa.eu/resource/authority/corporate-body/CURIA',
#  'http://publications.europa.eu/resource/authority/corporate-body/EURUN',
#  'http://publications.europa.eu/resource/authority/corporate-body/COM',
#  'http://publications.europa.eu/resource/authority/corporate-body/EURUN',
#  'http://publications.europa.eu/resource/authority/corporate-body/EURUN',
# ...

# %%
set(df_temp.organization.tolist())-set(df_temp.suborganization.tolist())
# Out:
# {'http://publications.europa.eu/resource/authority/corporate-body/EURUN',
#  'http://publications.europa.eu/resource/directory/organization/EASME/_CRF_100010',
#  'http://publications.europa.eu/resource/directory/organization/EIB/_RACINE',
#  'http://publications.europa.eu/resource/directory/organization/EISMEA/_CRF_100010',
#  'http://publications.europa.eu/resource/directory/organization/ERC/_CRF_99996',
#  'http://publications.europa.eu/resource/directory/organization/REA/_CRF_99997'}

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/EEAS_DEL'

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/EURUN'

# %%
#uri='http://publications.europa.eu/resource/directory/organization/EASME/_CRF_100010'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
            SELECT DISTINCT ?eurun ?eurun_uri ?eurun_image ?whoiswhoOrg ?whoiswhoOrg_uri ?whoiswhoOrg_image ?whoiswhoOrg_country ?whoiswhoOrg_countryUri ?whoiswhoOrg_location ?whoiswhoOrg_locationUri   
            where {{?eurun_uri org:hasSubOrganization ?whoiswhoOrg_uri;
                           skos:prefLabel ?eurun;
                           foaf:depiction ?eurun_image.
                    # ?whoiswhoOrg_uri skos:prefLabel ?whoiswhoOrg;
                       foaf:depiction ?whoiswhoOrg_image;
                       geo:location ?whoiswhoOrg_locationUri.
                    # ?whoiswhoOrg_locationUri skos:prefLabel ?whoiswhoOrg_location;
                              geosparql:sfWithin ?whoiswhoOrg_countryUri.
                    # ?whoiswhoOrg_countryUri skos:prefLabel ?whoiswhoOrg_country          
                    } 
                   filter(?eurun_uri=<http://publications.europa.eu/resource/authority/corporate-body/EURUN>).
                   FILTER(langMatches(lang(?eurun), "en")).
                   FILTER(langMatches(lang(?whoiswhoOrg), "en")).
                   FILTER(langMatches(lang(?whoiswhoOrg_location), "en")).
                   FILTER(langMatches(lang(?whoiswhoOrg_country), "en")).
                   }ORDER BY ?eurun ?whoiswhoOrg
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['eurun',
#    'eurun_uri',
#    'eurun_image',
#    'whoiswhoOrg',
#    'whoiswhoOrg_uri',
#    'whoiswhoOrg_image',
#    'whoiswhoOrg_country',
#    'whoiswhoOrg_countryUri',
#    'whoiswhoOrg_location',
#    'whoiswhoOrg_locationUri']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'eurun': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Union'},
#     'eurun_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EURUN'},
#     'eurun_image': {'type': 'uri',
#      'value': 'http://publications.europa.eu/code/images/scan/5000200-flag-cl.jpg'},
#     'whoiswhoOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Council of the European Union'},
#     'whoiswhoOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL'},
#     'whoiswhoOrg_image': {'type': 'uri',
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
            SELECT DISTINCT ?eurun ?eurun_uri ?eurun_image ?whoiswhoOrg ?whoiswhoOrg_uri ?whoiswhoOrg_image ?country ?country_uri ?location ?location_uri   
            where {{?eurun_uri org:hasSubOrganization ?whoiswhoOrg_uri;
                           skos:prefLabel ?eurun;
                           foaf:depiction ?eurun_image.
                    # ?whoiswhoOrg_uri skos:prefLabel ?whoiswhoOrg;
                       foaf:depiction ?whoiswhoOrg_image;
                       geo:location ?location_uri.
                    # ?location_uri skos:prefLabel ?location;
                              geosparql:sfWithin ?country_uri.
                    # ?country_uri skos:prefLabel ?country          
                    } 
                   filter(?eurun_uri=<"""+uri+""">).
                   FILTER(langMatches(lang(?eurun), "en")).
                   FILTER(langMatches(lang(?whoiswhoOrg), "en")).
                   FILTER(langMatches(lang(?location), "en")).
                   FILTER(langMatches(lang(?country), "en")).
                   }ORDER BY ?eurun ?whoiswhoOrg ?country ?location
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
#result_value=[]
#for r in results["results"]["bindings"]:
#    result_value.append({"organization":r["o"]["value"]})
#df_temp=pd.DataFrame(result_value)
#df_temp

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/ECA'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
            SELECT DISTINCT ?directoryOrg ?directoryOrg_uri ?directoryOrg_order ?directoryOrg_protocolLevel ?directoryOrg_email ?directoryOrg_telephone ?directoryOrg_locality ?directoryOrg_postalCode ?directoryOrg_streetAddress ?directoryOrg_homepage
            where {{?s org:hasSubOrganization ?directoryOrg_uri.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg;
                                      euvoc:order ?directoryOrg_order;
                                      euvoc:protocolLevel ?directoryOrg_protocolLevel;
                                      euvoc:contactPoint ?directoryOrg_contactPoint.
                    # ?directoryOrg_contactPoint vcard:hasEmail ?directoryOrg_email;
                                      vcard:hasTelephone ?directoryOrg_telephoneBN;
                                      vcard:locality ?directoryOrg_locality;
                                      vcard:postal-code ?directoryOrg_postalCode;
                                      vcard:street-address ?directoryOrg_streetAddress;
                                      foaf:homepage ?directoryOrg_homepage.
                    # ?directoryOrg_telephoneBN vcard:hasValue ?directoryOrg_telephone.       
                    } 
                   filter(?s=<"""+uri+""">).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   #FILTER(langMatches(lang(?location), "en")).
                   #FILTER(langMatches(lang(?country), "en")).
                   }
                   #ORDER BY ?whoiswhoOrg ?country ?location
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
#result_value=[]
#for r in results["results"]["bindings"]:
#    result_value.append({"organization":r["o"]["value"]})
#df_temp=pd.DataFrame(result_value)
#df_temp
# Out:
# {'head': {'link': [],
#   'vars': ['directoryOrg',
#    'directoryOrg_uri',
#    'directoryOrg_order',
#    'directoryOrg_protocolLevel',
#    'directoryOrg_email',
#    'directoryOrg_telephone',
#    'directoryOrg_locality',
#    'directoryOrg_postalCode',
#    'directoryOrg_streetAddress',
#    'directoryOrg_homepage']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/EURCOU'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
            SELECT DISTINCT ?corporateBody ?directoryOrg ?directoryOrg_uri ?directoryOrg_order ?directoryOrg_protocolLevel ?directoryOrg_email ?directoryOrg_telephone ?directoryOrg_locality ?directoryOrg_postalCode ?directoryOrg_streetAddress ?directoryOrg_homepage
            where {{?corporateBody org:hasSubOrganization ?directoryOrg_uri.    
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg;
                                      euvoc:order ?directoryOrg_order;
                                      euvoc:protocolLevel ?directoryOrg_protocolLevel;
                                      euvoc:contactPoint ?directoryOrg_contactPoint.
                    OPTIONAL {
                    # ?directoryOrg_contactPoint vcard:hasEmail ?directoryOrg_email.
                    }
                    OPTIONAL {
                    # ?directoryOrg_contactPoint vcard:hasTelephone ?directoryOrg_telephoneBN.
                    }
                    OPTIONAL {
                    # ?directoryOrg_contactPoint vcard:locality ?directoryOrg_locality.
                    }
                    OPTIONAL {
                    # ?directoryOrg_contactPoint vcard:postal-code ?directoryOrg_postalCode.
                    }
                    OPTIONAL {
                    # ?directoryOrg_contactPoint vcard:street-address ?directoryOrg_streetAddress.
                    }
                    OPTIONAL {
                    # ?directoryOrg_contactPoint foaf:homepage ?directoryOrg_homepage.
                    }
                    OPTIONAL {
                    # ?directoryOrg_telephoneBN vcard:hasValue ?directoryOrg_telephone.  
                    }
                    } 
                   filter(?corporateBody=<http://publications.europa.eu/resource/authority/corporate-body/EURCOU>).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   }
                   #ORDER BY ?whoiswhoOrg ?country ?location
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['corporateBody',
#    'directoryOrg',
#    'directoryOrg_uri',
#    'directoryOrg_order',
#    'directoryOrg_protocolLevel',
#    'directoryOrg_email',
#    'directoryOrg_telephone',
#    'directoryOrg_locality',
#    'directoryOrg_postalCode',
#    'directoryOrg_streetAddress',
#    'directoryOrg_homepage']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'corporateBody': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EURCOU'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'President'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EURCOU/EURCOU_EURCOUPRES'},
#     'directoryOrg_order': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '1'},
#     'directoryOrg_protocolLevel': {'type': 'typed-literal',
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
            SELECT DISTINCT ?corporateBody ?directoryOrg ?directoryOrg_uri ?directoryOrg_order ?directoryOrg_protocolLevel ?directoryOrg_email ?directoryOrg_telephone ?directoryOrg_locality ?directoryOrg_postalCode ?directoryOrg_streetAddress ?directoryOrg_homepage
            where {{?corporateBody org:hasSubOrganization ?directoryOrg_uri. 
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    OPTIONAL {
                    # ?directoryOrg_uri euvoc:order ?directoryOrg_order.
                    }
                    OPTIONAL {
                    # ?directoryOrg_uri euvoc:protocolLevel ?directoryOrg_protocolLevel.
                    }
                    #OPTIONAL {
                    #?directoryOrg_uri euvoc:contactPoint ?directoryOrg_contactPoint.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint vcard:hasEmail ?directoryOrg_email.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint vcard:hasTelephone ?directoryOrg_telephoneBN.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint vcard:locality ?directoryOrg_locality.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint vcard:postal-code ?directoryOrg_postalCode.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint vcard:street-address ?directoryOrg_streetAddress.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint foaf:homepage ?directoryOrg_homepage.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_telephoneBN vcard:hasValue ?directoryOrg_telephone.  
                    #}
                    } 
                   filter(?corporateBody=<http://publications.europa.eu/resource/authority/corporate-body/EP>).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   }
                   #ORDER BY ?whoiswhoOrg ?country ?location
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['corporateBody',
#    'directoryOrg',
#    'directoryOrg_uri',
#    'directoryOrg_order',
#    'directoryOrg_protocolLevel',
#    'directoryOrg_email',
#    'directoryOrg_telephone',
#    'directoryOrg_locality',
#    'directoryOrg_postalCode',
#    'directoryOrg_streetAddress',
#    'directoryOrg_homepage']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'corporateBody': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Secretariat-General of the European Parliament'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_SG'},
#     'directoryOrg_order': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '30'},
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{<http://publications.europa.eu/resource/directory/organization/EP_PR/EP_PR> ?p ?o.
                    } 
                   #filter(?s=<nodeID://b73152874>)
                   #FILTER(langMatches(lang(?label), "en")).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#Organization'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/EURUN'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/EP_PR'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
            SELECT DISTINCT ?corporateBody ?directoryOrg ?directoryOrg_uri ?directoryOrg_order ?directoryOrg_protocolLevel ?directoryOrg_email ?directoryOrg_telephone ?directoryOrg_locality ?directoryOrg_postalCode ?directoryOrg_streetAddress ?directoryOrg_homepage
            where {{?corporateBody org:hasSubOrganization ?directoryOrg_uri.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg;
                                      euvoc:order ?directoryOrg_order;
                                      euvoc:protocolLevel ?directoryOrg_protocolLevel;
                                      euvoc:contactPoint ?directoryOrg_contactPoint.
                    # ?directoryOrg_contactPoint vcard:hasEmail ?directoryOrg_email;
                                      vcard:hasTelephone ?directoryOrg_telephoneBN;
                                      vcard:locality ?directoryOrg_locality;
                                      vcard:postal-code ?directoryOrg_postalCode;
                                      vcard:street-address ?directoryOrg_streetAddress;
                                      foaf:homepage ?directoryOrg_homepage.
                    # ?directoryOrg_telephoneBN vcard:hasValue ?directoryOrg_telephone.       
                    } 
                   #filter(?corporateBody=<http://publications.europa.eu/resource/authority/corporate-body/EURCOU>).
                   filter(?corporateBody=<"""+uri+""">).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   #FILTER(langMatches(lang(?location), "en")).
                   #FILTER(langMatches(lang(?country), "en")).
                   }
                   #ORDER BY ?whoiswhoOrg ?country ?location
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['corporateBody',
#    'directoryOrg',
#    'directoryOrg_uri',
#    'directoryOrg_order',
#    'directoryOrg_protocolLevel',
#    'directoryOrg_email',
#    'directoryOrg_telephone',
#    'directoryOrg_locality',
#    'directoryOrg_postalCode',
#    'directoryOrg_streetAddress',
#    'directoryOrg_homepage']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
uri='http://publications.europa.eu/resource/directory/organization/ECA/ECA_2CC'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EURCOU'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EURCOU'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EURCOU'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
# ...

# %%
'http://publications.europa.eu/ontology/euvoc#order'
'http://publications.europa.eu/ontology/euvoc#protocolLevel'
'http://publications.europa.eu/ontology/euvoc#contactPoint'-blank node
    'http://publications.europa.eu/ontology/euvoc#countryCode'
    'http://www.w3.org/2006/vcard/ns#hasEmail'
    'http://www.w3.org/2006/vcard/ns#hasTelephone'
    'http://www.w3.org/2006/vcard/ns#locality'
    'http://www.w3.org/2006/vcard/ns#postal-code'
    'http://www.w3.org/2006/vcard/ns#street-address'
    'http://xmlns.com/foaf/0.1/homepage'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?p ?o #?label
            where {{<nodeID://b73165443> ?p ?o.
                    } 
                   #filter(?s=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/address-type/TEL'}},
#    {'p': {'type': 'uri', 'value': 'http://www.w3.org/2006/vcard/ns#hasValue'},
#     'o': {'type': 'uri', 'value': 'tel:+352-4398-1'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?o #?label
            where {{?s skos:narrower ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
result_value=[]
for r in results["results"]["bindings"]:
    result_value.append({"organization":r["o"]["value"]})
df_temp=pd.DataFrame(result_value)
df_temp
# Out:
#                                          organization
# 0   http://publications.europa.eu/resource/authori...
# 1   http://publications.europa.eu/resource/authori...
# 2   http://publications.europa.eu/resource/authori...
# 3   http://publications.europa.eu/resource/authori...
# 4   http://publications.europa.eu/resource/authori...
# ..                                                ...
# 75  http://publications.europa.eu/resource/authori...
# 76  http://publications.europa.eu/resource/authori...
# 77  http://publications.europa.eu/resource/authori...
# 78  http://publications.europa.eu/resource/authori...
# 79  http://publications.europa.eu/resource/authori...
#
# [80 rows x 1 columns]

# %%
narrower=df_temp.organization.tolist()

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?o #?label
            where {{?s org:hasSubOrganization ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
result_value=[]
for r in results["results"]["bindings"]:
    result_value.append({"organization":r["o"]["value"]})
df_temp=pd.DataFrame(result_value)
df_temp
# Out:
#                                          organization
# 0   http://publications.europa.eu/resource/authori...
# 1   http://publications.europa.eu/resource/authori...
# 2   http://publications.europa.eu/resource/authori...
# 3   http://publications.europa.eu/resource/authori...
# 4   http://publications.europa.eu/resource/authori...
# 5   http://publications.europa.eu/resource/authori...
# 6   http://publications.europa.eu/resource/authori...
# 7   http://publications.europa.eu/resource/authori...
# 8   http://publications.europa.eu/resource/authori...
# 9   http://publications.europa.eu/resource/authori...
# 10  http://publications.europa.eu/resource/authori...
# 11  http://publications.europa.eu/resource/authori...
# 12  http://publications.europa.eu/resource/authori...
# 13  http://publications.europa.eu/resource/authori...
# 14  http://publications.europa.eu/resource/directo...

# %%
suborg=df_temp.organization.tolist()

# %%
set(narrower)-set(suborg)
# Out:
# {'http://publications.europa.eu/resource/authority/corporate-body/AEPPEPF',
#  'http://publications.europa.eu/resource/authority/corporate-body/BEREC',
#  'http://publications.europa.eu/resource/authority/corporate-body/CBRN_COE',
#  'http://publications.europa.eu/resource/authority/corporate-body/CERT',
#  'http://publications.europa.eu/resource/authority/corporate-body/CMT_ADVIS_MERGER',
#  'http://publications.europa.eu/resource/authority/corporate-body/CMT_ADVIS_MONOPOL',
#  'http://publications.europa.eu/resource/authority/corporate-body/CMT_AMB_EU_ACP',
#  'http://publications.europa.eu/resource/authority/corporate-body/CMT_CONC',
#  'http://publications.europa.eu/resource/authority/corporate-body/CMT_CONJOIN',
#  'http://publications.europa.eu/resource/authority/corporate-body/CMT_CONS',
#  'http://publications.europa.eu/resource/authority/corporate-body/CMT_COOP',
#  'http://publications.europa.eu/resource/authority/corporate-body/CMT_COOP_CUSTOM',
# ...

# %%
set(suborg)-set(narrower)
# Out:
# {'http://publications.europa.eu/resource/authority/corporate-body/EIF',
#  'http://publications.europa.eu/resource/directory/organization/AGEN_OTH/AGEN_OTH'}

# %%
uri='http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_463CS'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_463CS'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_463CS'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#Organization'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_463CS'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
# ...

# %%
'http://www.w3.org/ns/org#classification'-'http://publications.europa.eu/resource/authority/organization-type/UNIT'
'http://publications.europa.eu/ontology/euvoc#order'- '430'
'http://publications.europa.eu/ontology/euvoc#protocolLevel'-'6'

# %%
uri="http://publications.europa.eu/resource/authority/corporate-body/COM_COLL"

# %%
uri="nodeID://b72926239"
uri='nodeID://b72955868'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{<nodeID://b72955868> ?p ?o.
                       #skos:prefLabel ?label.
                    } 
                   #filter(?o=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#Membership'}},
#    {'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#member'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/country/PYF'}},
#    {'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#organization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EEAREA'}},
#    {'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#role'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/role/MEMBER'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#entryDate'},
#     'o': {'type': 'typed-literal',
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{<http://publications.europa.eu/resource/authority/country/PYF> ?p ?o.
                       #skos:prefLabel ?label.
                    } 
                   #filter(?o=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#Country'}},
#    {'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/created'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2010-01-01'}},
#    {'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#versionInfo'},
#     'o': {'type': 'literal', 'value': '20210317-0'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{<http://publications.europa.eu/resource/authority/corporate-body/EEAREA> ?p ?o.
                       #skos:prefLabel ?label.
                    } 
                   #filter(?o=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#Corporate'}},
#    {'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/created'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2012-08-07'}},
#    {'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#versionInfo'},
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                       #skos:prefLabel ?label.
                    } 
                   filter(?o=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
'http://publications.europa.eu/resource/directory/COM_COLL'

# %%
'http://xmlns.com/foaf/0.1/homepage'-'https://ec.europa.eu/commission/commissioners/'
'http://www.w3.org/2004/02/skos/core#definition'

# %%
uri='http://eurovoc.europa.eu/1451'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?o ?label
            where {{?s skos:concept ?o;
                       skos:prefLabel ?label
                    } 
                   filter(?o=<"""+uri+""">)
                   filter (!strStarts(str(?s), 'http://publications.europa.eu/resource/authority/corporate-body/')).
                   FILTER(langMatches(lang(?label), "en")).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'o', 'label']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/IAS/COM_CRF_217041'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1451'},
#     'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'Audit Unit B.1'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/IAS/COM_CRF_217042'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1451'},
#     'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'Audit Unit B.2'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/IAS/COM_CRF_217043'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1451'},
#     'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'Audit Unit B.3'}},
#    {'s': {'type': 'uri',
# ...

# %%
uri="http://publications.europa.eu/resource/directory/organization/IAS/COM_CRF_230000"

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                       #skos:prefLabel ?label.
                    } 
                   filter(?s=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   #filter (!strStarts(str(?s), 'https://europeandataportal.eu/set/data/https-data-norge-no-node')).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/IAS/COM_CRF_230000'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/IAS/COM_CRF_230000'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#Organization'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/IAS/COM_CRF_230000'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
# ...

# %%
uri="http://publications.europa.eu/resource/directory/IAS"

# %%
uri='http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_MDR2_GOVREP_LTU'

# %%
uri='http://publications.europa.eu/resource/directory/membership/CONSIL/CONSIL-MDR2_GOVREP_LTU-IND_CONSIL.LTU.70---'

# %%
uri='http://publications.europa.eu/resource/directory/organization/CURIA/CURIA_4CJ'
uri='http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_MDR2_GOVREP_ROU'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                       #skos:prefLabel ?label.
                    } 
                   filter(?s=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   #filter (!strStarts(str(?s), 'https://europeandataportal.eu/set/data/https-data-norge-no-node')).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_MDR2_GOVREP_ROU'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_MDR2_GOVREP_ROU'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#Organization'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_MDR2_GOVREP_ROU'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
# ...

# %%
'http://publications.europa.eu/ontology/euvoc#order'

# %%
'http://publications.europa.eu/resource/authority/use-context/ID_ENTITY'

# %%
'http://publications.europa.eu/ontology/euvoc#protocolLevel'

# %%
uri="http://publications.europa.eu/resource/authority/corporate-body/IAS"
uri='http://publications.europa.eu/resource/directory/EURUN'
#uri='nodeID://b73306229'

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/EURUN'
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?o ?q ?r #?label
            where {{?s org:hasSubOrganization ?o.
                    # ?o org:hasSubOrganization ?q.
                    # ?q org:hasSubOrganization ?r.
                    #?r org:hasMembership ?member1.
                       #skos:prefLabel ?label.
                    } 
                   filter(?s=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   #filter (!strStarts(str(?s), 'https://europeandataportal.eu/set/data/https-data-norge-no-node')).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'o', 'q', 'r']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EURUN'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CURIA'},
#     'q': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CJ'},
#     'r': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CURIA/CURIA_4CJPAP2'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EURUN'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CURIA'},
#     'q': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/GCEU'},
#     'r': {'type': 'uri',
# ...

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/EURUN'
'http://www.w3.org/ns/org#classification'-'http://publications.europa.eu/resource/authority/corporate-body-classification/CB_EU'
'http://www.w3.org/2004/02/skos/core#topConceptOf'-'http://publications.europa.eu/resource/authority/corporate-body'
'http://www.w3.org/2004/02/skos/core#topConceptOf'- 'http://publications.europa.eu/resource/directory/EURUN'
'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'-'nodeID://b73306229'
'http://www.w3.org/ns/org#hasSubOrganization'-'http://publications.europa.eu/resource/authority/corporate-body/COM'
'http://www.w3.org/2004/02/skos/core#exactMatch'- 'http://eurovoc.europa.eu/4060'
'http://www.w3.org/2004/02/skos/core#narrower'- 'http://publications.europa.eu/resource/authority/corporate-body/ESDC'
'http://xmlns.com/foaf/0.1/depiction'- 'http://publications.europa.eu/code/images/scan/5000200-flag-cl.jpg'
'http://www.w3.org/2004/02/skos/core#concept'- 'http://eurovoc.europa.eu/1451'
'http://publications.europa.eu/ontology/euvoc#contactPoint'-'nodeID://b73306487'
'http://publications.europa.eu/ontology/euvoc#legallyBasedOnTreaty'- 'http://publications.europa.eu/resource/authority/treaty/LIS'

# %%
uri="http://publications.europa.eu/resource/authority/corporate-body"
'http://www.w3.org/2004/02/skos/core#inScheme'- 'http://publications.europa.eu/resource/authority/corporate-body/MARE'

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/EURUN'
uri='http://publications.europa.eu/resource/authority/corporate-body/COM'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX authority: <http://publications.europa.eu/ontology/authority/>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?o
            where {{?s skos:hasSubOrganization ?o.} 
                   filter(?o=<"""+uri+""">)
                   #filter (!strStarts(str(?s), 'https://europeandataportal.eu/set/data/https-data-norge-no-node')).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'o']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX authority: <http://publications.europa.eu/ontology/authority/>
            SELECT DISTINCT ?s ?o ?label
            where {{?s skos:topConceptOf ?o;
                       authority:deprecated ?deprecated;
                       skos:prefLabel ?label
                       #skos:prefLabel ?label.
                    } 
                   filter(?o=<"""+uri+""">)
                   filter(?deprecated="false").
                   FILTER(langMatches(lang(?label), "en")).
                   #filter (!strStarts(str(?s), 'https://europeandataportal.eu/set/data/https-data-norge-no-node')).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'o', 'label']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/SPC'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body'},
#     'label': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Pacific Community'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/REPRES_FRA'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body'},
#     'label': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Representation in France'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ICAO'},
#     'o': {'type': 'uri',
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>

            SELECT DISTINCT ?s ?o ?label
            where {{?s org:classification ?o.
                    # ?o skos:prefLabel ?label.
                    } 
                   #filter(?s=<"""+uri+""">)
                   FILTER(langMatches(lang(?label), "en")).
                   #filter (!strStarts(str(?s), 'https://europeandataportal.eu/set/data/https-data-norge-no-node')).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'o', 'label']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/COM_CAB/COM_CRF_248653'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/organization-type/CAB'},
#     'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'Cabinet'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/COM_CAB/COM_CRF_248654'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/organization-type/CAB'},
#     'label': {'type': 'literal', 'xml:lang': 'en', 'value': 'Cabinet'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/COM_CAB/COM_CRF_248656'},
#     'o': {'type': 'uri',
# ...

# %%
uri='http://publications.europa.eu/resource/authority/organization-type/SECTOR'

# %%
uri='http://publications.europa.eu/resource/directory/organization/IAS/COM_CRF_230000'

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/IAS'

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/COM'

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/EURUN'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s org:subOrganizationOf ?o.
                       #skos:prefLabel ?label.
                    } 
                   filter(?s=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   #filter (!strStarts(str(?s), 'https://europeandataportal.eu/set/data/https-data-norge-no-node')).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
'http://www.w3.org/ns/org#subOrganizationOf' uri='http://publications.europa.eu/resource/directory/organization/IAS/COM_CRF_217041'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                       #skos:prefLabel ?label.
                    } 
                   filter(?o=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   #filter (!strStarts(str(?s), 'https://europeandataportal.eu/set/data/https-data-norge-no-node')).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'bnode', 'value': 'nodeID://b72128975'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlObject'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/IAS/COM_CRF_230000'}},
#    {'s': {'type': 'bnode', 'value': 'nodeID://b72129515'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlObject'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/IAS/COM_CRF_230000'}},
#    {'s': {'type': 'bnode', 'value': 'nodeID://b72129710'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlObject'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/IAS/COM_CRF_230000'}},
# ...

# %%
uri='http://publications.europa.eu/resource/authority/organization-type'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX authority: <http://publications.europa.eu/resource/authority/>
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?orgTypeMain ?orgTypeMain_uri ?orgType ?orgType_uri ?directoryOrg ?directoryOrg_uri
            where {{?orgTypeMain_uri skos:prefLabel ?orgTypeMain.
                    # ?orgType_uri skos:topConceptOf authority:organization-type;
                       skos:prefLabel ?orgType.
                    # ?directoryOrg_uri org:classification ?orgType_uri;
                       skos:prefLabel ?directoryOrg.
                    } 
                   FILTER(langMatches(lang(?orgType), "en")).
                   FILTER(langMatches(lang(?orgTypeMain), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(?orgTypeMain_uri=<http://publications.europa.eu/resource/authority/organization-type>)
                   #filter (!strStarts(str(?s), 'https://europeandataportal.eu/set/data/https-data-norge-no-node')).
                   }ORDER BY ?orgTypeMain ?orgType ?directoryOrg
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['orgTypeMain',
#    'orgTypeMain_uri',
#    'orgType',
#    'orgType_uri',
#    'directoryOrg',
#    'directoryOrg_uri']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'orgTypeMain': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Organization type'},
#     'orgTypeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/organization-type'},
#     'orgType': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Attached to the institution'},
#     'orgType_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/organization-type/INSTIT_ATT'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Supervisor/EDPB Chair/EDPB Vice Chair'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EDPS/EDPS_CRF_241312'}},
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX authority: <http://publications.europa.eu/resource/authority/>
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?orgTypeMain ?orgTypeMain_uri ?orgType ?orgType_uri ?directoryOrg ?directoryOrg_uri
            where {{?orgTypeMain_uri skos:prefLabel ?orgTypeMain.
                    # ?orgType_uri skos:topConceptOf authority:organization-type;
                       skos:prefLabel ?orgType.
                    # ?directoryOrg_uri org:classification ?orgType_uri;
                       skos:prefLabel ?directoryOrg.
                    } 
                   FILTER(langMatches(lang(?orgType), "en")).
                   FILTER(langMatches(lang(?orgTypeMain), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(?orgTypeMain_uri=<http://publications.europa.eu/resource/authority/organization-type>)
                   #filter (!strStarts(str(?s), 'https://europeandataportal.eu/set/data/https-data-norge-no-node')).
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['orgTypeMain',
#    'orgTypeMain_uri',
#    'orgType',
#    'orgType_uri',
#    'directoryOrg',
#    'directoryOrg_uri']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'orgTypeMain': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Organization type'},
#     'orgTypeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/organization-type'},
#     'orgType': {'type': 'literal', 'xml:lang': 'en', 'value': 'Directorate'},
#     'orgType_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/organization-type/DIR'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Audit in Commission, Executive Agencies, EU Agencies and other autonomous bodies II'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/IAS/COM_CRF_230000'}},
# ...

# %%
uri='http://publications.europa.eu/resource/directory/organization/IAS/COM_CRF_230000'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s org:organization ?o.
                       #skos:prefLabel ?label.
                    } 
                   filter(?o=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   #filter (!strStarts(str(?s), 'https://europeandataportal.eu/set/data/https-data-norge-no-node')).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/IAS/COM-CRF_230000-0000C460F-00007ACD3--'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/IAS/COM_CRF_230000'}}]}}

# %%
uri='http://publications.europa.eu/resource/directory/membership/IAS/COM-CRF_230000-0000C460F-00007ACD3--'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                       #skos:prefLabel ?label.
                    } 
                   filter(?s=<"""+uri+""">)
                   #FILTER(langMatches(lang(?label), "en")).
                   #filter (!strStarts(str(?s), 'https://europeandataportal.eu/set/data/https-data-norge-no-node')).
                   }
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/organization-type'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Ontology'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/organization-type'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2002/07/owl#NamedIndividual'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/organization-type'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
# ...

# %%
uri='http://publications.europa.eu/resource/directory/person/COM_00006A0440FF'
uri='http://publications.europa.eu/resource/directory/person/COM_0000C460F'

# %%
label="Markku Markkula"
label="Uwe Conradt"
label="David Sassoli"

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT ?article WHERE {
                   # ?item rdfs:label '"""+ label +"""'@en.
                  # ?article schema:about ?item .
                  # ?article schema:inLanguage "en" .
                  # ?article schema:isPartOf <https://en.wikipedia.org/> .
            }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'vars': ['article']},
#  'results': {'bindings': [{'article': {'type': 'uri',
#      'value': 'https://en.wikipedia.org/wiki/David_Sassoli'}}]}}

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT ?o WHERE {
                   # ?item rdfs:label '"""+ label +"""'@en;
                         # ?p ?o.
            }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'vars': ['o']},
#  'results': {'bindings': [{'o': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/statement/Q1805993-6ebb8707-47f3-b724-baa7-77282a810b09'}},
#    {'o': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/statement/Q1805993-5eae7540-44c9-d4ff-e7e8-11a4f9bb8b80'}},
#    {'o': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/statement/Q1805993-97daaf49-40cb-cd08-3579-db1bc79c4993'}},
#    {'o': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/statement/Q1805993-2C460B20-1126-4C55-B704-9E502E2B111C'}},
#    {'o': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/statement/Q1805993-F9F20224-D3BC-4653-AB9C-9362231DBF7C'}},
#    {'o': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/statement/Q1805993-c1c476fb-4793-70d0-60c1-32ffd22da0d2'}},
#    {'o': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/statement/Q1805993-4595009A-2C8E-4310-B1F4-8BA44A8613AB'}},
# ...

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT ?o WHERE {
                   # ?item rdfs:label '"""+ label +"""'@en;
                         <http://www.wikidata.org/prop/direct-normalized/P646> ?o.
            }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT ?o WHERE {
                   # ?item rdfs:label '"""+ label +"""'@en;
                         <http://www.wikidata.org/prop/direct-normalized/P646> ?o.
            }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'vars': ['o']}, 'results': {'bindings': []}}

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT ?p ?o WHERE {
                   # ?item rdfs:label '"""+ label +"""'@en;
                         # ?p ?o.
            filter (strStarts(str(?p), 'http://www.wikidata.org/prop/direct-normalized/')).
            filter (strStarts(str(?o), 'http://g.co/kg/')).
            }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'vars': ['p', 'o']},
#  'results': {'bindings': [{'p': {'type': 'uri',
#      'value': 'http://www.wikidata.org/prop/direct-normalized/P2671'},
#     'o': {'type': 'uri', 'value': 'http://g.co/kg/g/11h1sww3m'}}]}}

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT ?p ?o WHERE {
                   # ?item rdfs:label '"""+ label +"""'@en;
                   OPTIONAL {
                      # ?article schema:about ?cid .
                      # ?article schema:inLanguage "en" .
                      # ?article schema:isPartOf <https://en.wikipedia.org/> .
                    }
            }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
PREFIX schema: <http://schema.org/>
PREFIX wikibase: <http://wikiba.se/ontology#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>

SELECT ?cid ?country ?article WHERE {
    # ?cid wdt:P31 wd:Q3624078 .
    OPTIONAL {
      # ?cid rdfs:label ?country filter (lang(?country) = "en") .
    }
    OPTIONAL {
      # ?article schema:about ?cid .
      # ?article schema:inLanguage "en" .
      # ?article schema:isPartOf <https://en.wikipedia.org/> .
    }
} 
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'vars': ['cid', 'country', 'article']},
#  'results': {'bindings': [{'cid': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q16'},
#     'article': {'type': 'uri',
#      'value': 'https://en.wikipedia.org/wiki/Canada'},
#     'country': {'xml:lang': 'en', 'type': 'literal', 'value': 'Canada'}},
#    {'cid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q258'},
#     'article': {'type': 'uri',
#      'value': 'https://en.wikipedia.org/wiki/South_Africa'},
#     'country': {'xml:lang': 'en', 'type': 'literal', 'value': 'South Africa'}},
#    {'cid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q298'},
#     'article': {'type': 'uri', 'value': 'https://en.wikipedia.org/wiki/Chile'},
#     'country': {'xml:lang': 'en', 'type': 'literal', 'value': 'Chile'}},
#    {'cid': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q29'},
#     'article': {'type': 'uri', 'value': 'https://en.wikipedia.org/wiki/Spain'},
# ...

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT ?article WHERE {
                  # ?item rdfs:label "Charles Michel"@en.
                  # ?article schema:about ?item .
                  # ?article schema:inLanguage "en" .
                  # ?article schema:isPartOf <https://en.wikipedia.org/> .
            }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'vars': ['article']},
#  'results': {'bindings': [{'article': {'type': 'uri',
#      'value': 'https://en.wikipedia.org/wiki/Charles_Michel'}},
#    {'article': {'type': 'uri',
#      'value': 'https://en.wikipedia.org/wiki/Charles_Michel_(ophthalmologist)'}},
#    {'article': {'type': 'uri',
#      'value': 'https://en.wikipedia.org/wiki/Charles_Michel_(disambiguation)'}}]}}

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX schema: <http://schema.org/>
            SELECT ?article WHERE {
                  # ?item rdfs:label "Charles Michel"@en.
                  # ?article schema:about ?item .
                  # ?article schema:inLanguage "en" .
                  # ?article schema:isPartOf <https://en.wikipedia.org/> .
            }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'vars': ['article']},
#  'results': {'bindings': [{'article': {'type': 'uri',
#      'value': 'https://en.wikipedia.org/wiki/Charles_Michel'}},
#    {'article': {'type': 'uri',
#      'value': 'https://en.wikipedia.org/wiki/Charles_Michel_(ophthalmologist)'}},
#    {'article': {'type': 'uri',
#      'value': 'https://en.wikipedia.org/wiki/Charles_Michel_(disambiguation)'}}]}}

# %%
'http://schema.org/description'
'http://www.wikidata.org/prop/direct/P18' photo

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?directoryOrg2 ?membership_uri ?membership_startDate ?membership_endDate ?membership_order ?membership ?membership_positionStatusUri ?membership_positionStatus
            where {{?membership_uri org:organization ?directoryOrg2_uri;
                       euvoc:startDate ?membership_startDate;
                       euvoc:endDate ?membership_endDate;
                       euvoc:order ?membership_order;
                       euvoc:positionComplement ?membership;
                       euvoc:positionStatus ?membership_positionStatusUri.
                       #euvoc:roleQualification ?roleQualification_uri;
                       #euvoc:contactPoint ?contactPoint.
                    # ?directoryOrg2_uri skos:prefLabel ?directoryOrg2.
                    # ?membership_positionStatusUri skos:prefLabel ?membership_positionStatus.
                    #?membership_uri skos:prefLabel ?membership.
                    #?roleQualification_uri skos:prefLabel ?roleQualification.
                    } 
                   filter(?directoryOrg2_uri=<http://publications.europa.eu/resource/directory/organization/EP_CMT_WIW/EP_CMT_WIW>).
                   FILTER(langMatches(lang(?membership), "en")).
                   FILTER(langMatches(lang(?membership_positionStatus), "en")).
                   FILTER(langMatches(lang(?directoryOrg2), "en")).
                   }ORDER BY ?membership
    """)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['directoryOrg2',
#    'membership_uri',
#    'membership_startDate',
#    'membership_endDate',
#    'membership_order',
#    'membership',
#    'membership_positionStatusUri',
#    'membership_positionStatus']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
uri="http://publications.europa.eu/resource/directory/organization/EP_CMT_WIW/EP_CMT_WIW"

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EP_CMT_WIW/EP_CMT_WIW'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EP_CMT_WIW/EP_CMT_WIW'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#Organization'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EP_CMT_WIW/EP_CMT_WIW'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?directoryOrg ?membership_uri ?membership_startDate ?membership_endDate ?membership_order ?membership ?membership_positionStatusUri ?membership_positionStatus
            where {{?membership_uri org:organization ?directoryOrg_uri;
                       euvoc:positionComplement ?membership;
                       euvoc:startDate ?membership_startDate;
                       euvoc:endDate ?membership_endDate;
                       euvoc:order ?membership_order;
                       euvoc:positionComplement ?membership;
                       euvoc:positionStatus ?membership_positionStatusUri.
                       #euvoc:roleQualification ?roleQualification_uri;
                       #euvoc:contactPoint ?contactPoint.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?membership_positionStatusUri skos:prefLabel ?membership_positionStatus.
                    #?membership_uri skos:prefLabel ?membership.
                    #?roleQualification_uri skos:prefLabel ?roleQualification.
                    } 
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/authority/corporate-body/EP_BUDG>).
                   FILTER(langMatches(lang(?membership), "en")).
                   FILTER(langMatches(lang(?membership_positionStatus), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   #FILTER(?membership='Substitute').
                   }ORDER BY ?membership_order
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['directoryOrg',
#    'membership_uri',
#    'membership_startDate',
#    'membership_endDate',
#    'membership_order',
#    'membership',
#    'membership_positionStatusUri',
#    'membership_positionStatus']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Committee on Budgets'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEC04-DPPE125106---'},
#     'membership_startDate': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2021-03-30'},
#     'membership_endDate': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '9999-12-31'},
#     'membership_order': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
    select  ?directoryOrg ?membership ?membership_order
    where {
    SELECT ?directoryOrg ?membership
            where {{?membership_uri org:organization ?directoryOrg_uri;
                                    euvoc:order ?membership_order;
                                    euvoc:positionComplement ?membership.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    } 
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/authority/corporate-body/EP_BUDG>).
                   FILTER(langMatches(lang(?membership), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   }ORDER BY xsd:integer(?membership_order)
    }   GROUP BY ?membership 
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['directoryOrg', 'membership', 'membership_order']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Committee on Budgets'},
#     'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'}},
#    {'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Committee on Budgets'},
#     'membership': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Vice-Chair'}},
#    {'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Committee on Budgets'},
#     'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Chair'}},
#    {'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Committee on Budgets'},
#     'membership': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Substitute'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?membership ?person ?person_uri ?person_gender ?person_genderUri 
            where {{?person_uri org:hasMembership ?membership_uri;
                                vcard:hasGender ?person_genderUri;
                                foaf:name ?person.
                    # ?membership_uri euvoc:positionComplement ?membership.
                    # ?person_genderUri skos:prefLabel ?person_gender.
                    } 
                   filter(?membership_uri=<http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEC04-DPPE197412--->)
                   FILTER(langMatches(lang(?membership), "en")).
                   FILTER(langMatches(lang(?person_gender), "en")).
                   }ORDER BY ?person
                   #LIMIT 50
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['membership',
#    'person',
#    'person_uri',
#    'person_gender',
#    'person_genderUri']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'membership': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Vice-Chair'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Niclas HERBST'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE197412'},
#     'person_gender': {'type': 'literal', 'xml:lang': 'en', 'value': 'male'},
#     'person_genderUri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/human-sex/MALE'}}]}}

# %%
uri='http://publications.europa.eu/resource/directory/person/EP_DPPE197412'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
select    ?directoryOrg ?membership

where {
    SELECT *
            where {{?membership_uri org:organization ?directoryOrg_uri;
                                    euvoc:order ?membership_order;
                                    euvoc:positionComplement ?membership.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    } 
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/authority/corporate-body/EP_BUDG>).
                   FILTER(langMatches(lang(?membership), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   }ORDER BY ?membership

}   GROUP BY ?membership  
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['directoryOrg', 'membership']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Committee on Budgets'},
#     'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Member'}},
#    {'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Committee on Budgets'},
#     'membership': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Vice-Chair'}},
#    {'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Committee on Budgets'},
#     'membership': {'type': 'literal', 'xml:lang': 'en', 'value': 'Chair'}},
#    {'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Committee on Budgets'},
#     'membership': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Substitute'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?directoryOrg ?membership
            where {{?membership_uri org:organization ?directoryOrg_uri;
                                    euvoc:order ?membership_order;
                                    euvoc:positionComplement ?membership.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    } 
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/directory/organization/EIB/EIB_EIB-020203>).
                   FILTER(langMatches(lang(?membership), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   }GROUP BY ?membership
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['directoryOrg', 'membership']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Portfolio Management'},
#     'membership': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Head of Division'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?membership ?membership_uri ?membership_startDate ?membership_endDate ?membership_order ?membership_positionStatusUri ?membership_positionStatus ?person ?person_uri ?person_gender ?person_genderUri
            where {{?membership_uri org:organization ?directoryOrg_uri;
                       euvoc:startDate ?membership_startDate;
                       euvoc:endDate ?membership_endDate;
                       euvoc:order ?membership_order;
                       euvoc:positionComplement ?membership;
                       euvoc:positionStatus ?membership_positionStatusUri.
                       #euvoc:roleQualification ?roleQualification_uri;
                       #euvoc:contactPoint ?contactPoint.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?membership_positionStatusUri skos:prefLabel ?membership_positionStatus.
                    # ?person_uri org:hasMembership ?membership_uri;
                    #            vcard:hasGender ?person_genderUri;
                                foaf:name ?person.
                    #?person_genderUri skos:prefLabel ?person_gender.
                    } 
                   BIND('Head of Division' AS ?membership)
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/directory/organization/EIB/EIB_EIB-020203>).
                   FILTER(langMatches(lang(?membership), "en")).
                   FILTER(langMatches(lang(?membership_positionStatus), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   #FILTER(langMatches(lang(?person_gender), "en")).
                   }ORDER BY ?membership_order ?person
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['membership',
#    'membership_uri',
#    'membership_startDate',
#    'membership_endDate',
#    'membership_order',
#    'membership_positionStatusUri',
#    'membership_positionStatus',
#    'person',
#    'person_uri',
#    'person_gender',
#    'person_genderUri']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'membership': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Head of Division'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EIB/EIB-EIB-020203-EIB-7838---'},
#     'membership_startDate': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2021-03-22'},
#     'membership_endDate': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '9999-12-31'},
#     'membership_order': {'type': 'typed-literal',
# ...

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_SEC'
uri='http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEC04-DPPE197805---'
uri='http://publications.europa.eu/resource/directory/person/EP_DPPE125106'
uri='http://publications.europa.eu/resource/directory/organization/EIB/EIB_EIB-110800'
uri='http://publications.europa.eu/resource/directory/membership/EIB/EIB-EIB-110800-EIB-1099---'
uri='http://publications.europa.eu/resource/directory/organization/EIB/EIB_EIB-020203'
#uri='http://eurovoc.europa.eu/1451'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?directoryOrg ?membership ?directoryOrg_uri AS ?membership_directoryOrg
            where {{?membership_uri org:organization ?directoryOrg_uri;
                                    euvoc:order ?membership_order;
                                    euvoc:positionComplement ?membership.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    } 
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/directory/organization/EIB/EIB_EIB-110800>).
                   FILTER(langMatches(lang(?membership), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   }GROUP BY ?membership
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['directoryOrg', 'membership', 'membership_directoryOrg']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'EIB Institute'},
#     'membership': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Dean of the Institute'},
#     'membership_directoryOrg': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EIB/EIB_EIB-110800'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EIB/EIB_EIB-020203'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EIB/EIB_EIB-020203'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#Organization'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EIB/EIB_EIB-020203'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
# ...

# %%
uri='http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEC04-DPPE125106---'

# %%
uri='http://publications.europa.eu/resource/directory/person/EP_DPPE125106'

# %%
#uri='http://publications.europa.eu/resource/directory/person/EP_DPPE197808'

# %%
uri='http://publications.europa.eu/resource/directory/person/EP_DPPE094607'

# %%
uri='http://publications.europa.eu/resource/directory/membership/EP_SGP_ECR/EP-DPPEGP_5903-DPPE094607---'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?membership ?person ?person_uri ?person_gender ?person_genderUri 
            where {{?person_uri org:hasMembership ?membership_uri;
                                vcard:hasGender ?person_genderUri;
                                foaf:name ?person.
                    # ?membership_uri euvoc:positionComplement ?membership.
                    # ?person_genderUri skos:prefLabel ?person_gender.
                    } 
                   filter(?membership_uri=<"""+uri+""">)
                   FILTER(langMatches(lang(?membership), "en")).
                   FILTER(langMatches(lang(?person_gender), "en")).
                   }ORDER BY ?person
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['membership',
#    'person',
#    'person_uri',
#    'person_gender',
#    'person_genderUri']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'membership': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Assistant'},
#     'person': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Eva BENJAMIN BRADIKOVA'},
#     'person_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE094607'},
#     'person_gender': {'type': 'literal', 'xml:lang': 'en', 'value': 'female'},
#     'person_genderUri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/human-sex/FEMALE'}}]}}

# %%
uri='http://publications.europa.eu/resource/directory/organization/EP_SGP_ECR/EP_DPPEGP_5903'

# %%
uri='http://publications.europa.eu/resource/directory/organization/EP_SGP_ECR/EP_SGP_ECR'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EP_SGP_ECR/EP_SGP_ECR'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EP_SGP_ECR/EP_SGP_ECR'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#Organization'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EP_SGP_ECR/EP_SGP_ECR'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
# ...

# %%
SECRETARY GENERAL
ECR: European Conservatives and Reformists Group'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX resource: <http://publications.europa.eu/resource/>
            SELECT DISTINCT ?membership ?membership_uri ?membership_startDate ?membership_endDate ?membership_order ?membership_positionStatusUri ?membership_positionStatus ?person ?person_uri ?person_img ?person_citiz ?person_gender ?person_genderUri
            where {{?membership_uri org:organization ?directoryOrg_uri;
                       euvoc:startDate ?membership_startDate;
                       euvoc:endDate ?membership_endDate;
                       euvoc:order ?membership_order;
                       euvoc:positionComplement ?membership;
                       euvoc:positionStatus ?membership_positionStatusUri.
                       #euvoc:roleQualification ?roleQualification_uri;
                       #euvoc:contactPoint ?contactPoint.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?membership_positionStatusUri skos:prefLabel ?membership_positionStatus.
                    # ?person_uri org:hasMembership ?membership_uri;
                                foaf:img ?person_img;
                    #            vcard:hasGender ?person_genderUri;
                                foaf:name ?person.
                    OPTIONAL{
                        # ?person_uri foaf:img ?person_img;
                                    resource:personcitizenship ?person_citizUri.
                        # ?person_citizUri skos:prefLabel ?person_citiz.
                        FILTER(langMatches(lang(?person_citiz), "en")).
                    }
                    #?person_genderUri skos:prefLabel ?person_gender.
                    } 
                   #BIND('Vice-Chair' AS ?membership).
                   FILTER(STR(?membership)="Vice-Chair").
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/authority/corporate-body/EP_LIBE>).
                   FILTER(langMatches(lang(?membership), "en")).
                   FILTER(langMatches(lang(?membership_positionStatus), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   #FILTER(langMatches(lang(?person_gender), "en")).
                   }ORDER BY ?membership_order ?person
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['membership',
#    'membership_uri',
#    'membership_startDate',
#    'membership_endDate',
#    'membership_order',
#    'membership_positionStatusUri',
#    'membership_positionStatus',
#    'person',
#    'person_uri',
#    'person_img',
#    'person_citiz',
#    'person_gender',
#    'person_genderUri']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'membership': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Vice-Chair'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_MEPS/EP-DPPEC17-DPPE197808---'},
#     'membership_startDate': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2021-03-30'},
#     'membership_endDate': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '9999-12-31'},
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
            SELECT DISTINCT ?membership ?membership_uri ?membership_startDate ?membership_endDate ?membership_order ?membership_positionStatusUri ?membership_positionStatus ?person ?person_uri ?person_gender ?person_genderUri
            where {{?membership_uri org:organization ?directoryOrg_uri;
                       euvoc:startDate ?membership_startDate;
                       euvoc:endDate ?membership_endDate;
                       euvoc:order ?membership_order;
                       euvoc:positionComplement ?membership;
                       euvoc:positionStatus ?membership_positionStatusUri.
                       #euvoc:roleQualification ?roleQualification_uri;
                       #euvoc:contactPoint ?contactPoint.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?membership_positionStatusUri skos:prefLabel ?membership_positionStatus.
                    # ?person_uri org:hasMembership ?membership_uri;
                    #            vcard:hasGender ?person_genderUri;
                                foaf:name ?person.
                    #?person_genderUri skos:prefLabel ?person_gender.
                    } 
                   FILTER(STR(?membership)="Assistant").
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/directory/organization/EP_SGP_ECR/EP_DPPEGP_5903>).
                   FILTER(langMatches(lang(?membership), "en")).
                   FILTER(langMatches(lang(?membership_positionStatus), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   #FILTER(langMatches(lang(?person_gender), "en")).
                   }ORDER BY ?membership_order ?person
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['membership',
#    'membership_uri',
#    'membership_startDate',
#    'membership_endDate',
#    'membership_order',
#    'membership_positionStatusUri',
#    'membership_positionStatus',
#    'person',
#    'person_uri',
#    'person_gender',
#    'person_genderUri']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'membership': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Assistant'},
#     'membership_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/membership/EP_SGP_ECR/EP-DPPEGP_5903-DPPE094607---'},
#     'membership_startDate': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2021-03-30'},
#     'membership_endDate': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '9999-12-31'},
#     'membership_order': {'type': 'typed-literal',
# ...

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX schema: <http://schema.org/>
            SELECT ?article WHERE {
                  # ?item rdfs:label "PARAMETER"@en.
                  # ?article schema:about ?item .
                  # ?article schema:inLanguage "en" .
                  # ?article schema:isPartOf <https://en.wikipedia.org/> .
            }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'vars': ['article']}, 'results': {'bindings': []}}

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
SELECT ?human ?humanLabel ?representedPartyLabel ?startDate 
WHERE {   ?human p:P39 ?stmt.
          # ?stmt ps:P39 wd:Q27169 .
          # ?stmt pq:P1268 ?representedParty .
          # ?stmt pq:P580 ?startDate 
          #SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE]". } 
          }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'vars': ['human',
#    'humanLabel',
#    'representedPartyLabel',
#    'startDate']},
#  'results': {'bindings': [{'human': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q297856'},
#     'startDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '1995-01-01T00:00:00Z'}},
#    {'human': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q301358'},
#     'startDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '2004-07-20T00:00:00Z'}},
#    {'human': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q301358'},
#     'startDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
#      'type': 'literal',
#      'value': '1994-07-19T00:00:00Z'}},
#    {'human': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q301358'},
#     'startDate': {'datatype': 'http://www.w3.org/2001/XMLSchema#dateTime',
# ...

# %%
uri='http://publications.europa.eu/resource/directory/person/EP_DPPE017509'
uri='http://publications.europa.eu/resource/directory/person/EP_DPPE125038'
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE125038'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/Person'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE125038'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/personcitizenship'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/country/ESP'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/person/EP_DPPE125038'},
#     'p': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/name'},
#     'o': {'type': 'typed-literal',
# ...

# %%
uri='http://www.wikidata.org/entity/Q297856'
uri='http://publications.europa.eu/resource/directory/person/EP_DPPE017509'
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'vars': ['s', 'p', 'o']}, 'results': {'bindings': []}}

# %%
uri='http://publications.europa.eu/resource/directory/person/EP_DPPE125106'

# %%
#uri='http://publications.europa.eu/resource/directory/person/EP_DPPE197808'

# %%
#uri='http://publications.europa.eu/resource/directory/person/EP_DPPE094607'

# %%
http://publications.europa.eu/resource/directory/person/EP_DPPE096864

# %%
uri='http://www.wikidata.org/entity/Q297856'
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?article 
            where {{?s <http://www.wikidata.org/prop/direct/P1186> '124693'.
                    # ?article schema:about ?s .
                    # ?article schema:inLanguage "en" .
                    # ?article schema:isPartOf <https://en.wikipedia.org/> .
                    } 
                   #filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {}, 'boolean': False}

# %%
uri='http://www.wikidata.org/entity/Q297856'
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?article 
            where {{?s <http://www.wikidata.org/prop/direct/P1186> '124693'.
                    # ?article schema:about ?s .
                    # ?article schema:inLanguage "en" .
                    # ?article schema:isPartOf <https://en.wikipedia.org/> .
                    } 
                   #filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'vars': ['article']},
#  'results': {'bindings': [{'article': {'type': 'uri',
#      'value': 'https://en.wikipedia.org/wiki/Pascal_Durand'}}]}}

# %%
uri='http://www.wikidata.org/prop/direct/P269'

# %%
substr("foobar", 4)

# %%
uri='http://www.wikidata.org/entity/Q297856'
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX schema: <http://schema.org/>
            SELECT ?item ?article WHERE {
                  # ?item rdfs:label "Elisabeth Rehn"@en.
                  # ?article schema:about ?item .
                  # ?article schema:inLanguage "en" .
                  # ?article schema:isPartOf <https://en.wikipedia.org/> .
            }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'vars': ['item', 'article']},
#  'results': {'bindings': [{'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q297856'},
#     'article': {'type': 'uri',
#      'value': 'https://en.wikipedia.org/wiki/Elisabeth_Rehn'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX resource: <http://publications.europa.eu/resource/>
            SELECT DISTINCT ?str_event ?membership ?membership_uri ?membership_startDate ?membership_endDate ?membership_order ?membership_positionStatusUri ?membership_positionStatus ?person ?person_uri ?person_img ?person_citiz ?person_gender ?person_genderUri
            where {{?membership_uri org:organization ?directoryOrg_uri;
                       euvoc:startDate ?membership_startDate;
                       euvoc:endDate ?membership_endDate;
                       euvoc:order ?membership_order;
                       euvoc:positionComplement ?membership;
                       euvoc:positionStatus ?membership_positionStatusUri.
                       #euvoc:roleQualification ?roleQualification_uri;
                       #euvoc:contactPoint ?contactPoint.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?membership_positionStatusUri skos:prefLabel ?membership_positionStatus.
                    # ?person_uri org:hasMembership ?membership_uri;
                    #            vcard:hasGender ?person_genderUri;
                                foaf:name ?person.
                    #?person_genderUri skos:prefLabel ?person_gender.
                    OPTIONAL{
                        # ?person_uri foaf:img ?person_img;
                                    resource:personcitizenship ?person_citizUri.
                        # ?person_citizUri skos:prefLabel ?person_citiz.
                        FILTER(langMatches(lang(?person_citiz), "en")).
                        #BIND (SUBSTR(STR(?person_img),41) AS ?str_event)
                        FILTER (regex(STR(?person_img), "(?<=https://www.europarl.europa.eu/mepphoto/)(.*)(?=.jpg)","i"])).
                    }
                    } 
                   FILTER(STR(?membership)="President").
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/directory/organization/EP_PR/EP_PR>).
                   FILTER(langMatches(lang(?membership), "en")).
                   FILTER(langMatches(lang(?membership_positionStatus), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   #FILTER(langMatches(lang(?person_gender), "en")).
                   }ORDER BY ?membership_order ?person
    """)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/SPARQLWrapper/Wrapper.py in _query(self)
#    1072             else:
# -> 1073                 response = urlopener(request)
#    1074             return response, self.returnFormat
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#
# /usr/local/Cellar/python/3.7.3/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
            SELECT *
            where {{?corporateBody_uri skos:prefLabel ?corporateBody.
                    # ?corporateBody_uri org:hasSubOrganization ?directoryOrg_uri. 
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    OPTIONAL {
                    # ?directoryOrg_uri euvoc:order ?directoryOrg_order.
                    }
                    OPTIONAL {
                    # ?directoryOrg_uri euvoc:protocolLevel ?directoryOrg_protocolLevel.
                    }
                    #OPTIONAL {
                    #?directoryOrg_uri euvoc:contactPoint ?directoryOrg_contactPoint.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint vcard:hasEmail ?directoryOrg_email.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint vcard:hasTelephone ?directoryOrg_telephoneBN.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint vcard:locality ?directoryOrg_locality.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint vcard:postal-code ?directoryOrg_postalCode.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint vcard:street-address ?directoryOrg_streetAddress.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint foaf:homepage ?directoryOrg_homepage.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_telephoneBN vcard:hasValue ?directoryOrg_telephone.  
                    #}
                    } 
                   filter(?corporateBody_uri=<PARAMETER>).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(langMatches(lang(?corporateBody), "en")).
                   }
                   #ORDER BY ?whoiswhoOrg ?country ?location
                   #LIMIT 50
    """)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['corporateBody_uri',
#    'corporateBody',
#    'directoryOrg_uri',
#    'directoryOrg',
#    'directoryOrg_order',
#    'directoryOrg_protocolLevel']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
    PREFIX geosparql: <http://www.opengis.net/ont/geosparql#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
            select distinct * where {{?corporateBody_uri skos:prefLabel ?corporateBody.
                    # ?corporateBody_uri org:hasSubOrganization ?directoryOrg_uri. 
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    OPTIONAL {
                    # ?directoryOrg_uri euvoc:order ?directoryOrg_order.
                    }
                    OPTIONAL {
                    # ?directoryOrg_uri euvoc:protocolLevel ?directoryOrg_protocolLevel.
                    }
                    #OPTIONAL {
                    #?directoryOrg_uri euvoc:contactPoint ?directoryOrg_contactPoint.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint vcard:hasEmail ?directoryOrg_email.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint vcard:hasTelephone ?directoryOrg_telephoneBN.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint vcard:locality ?directoryOrg_locality.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint vcard:postal-code ?directoryOrg_postalCode.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint vcard:street-address ?directoryOrg_streetAddress.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_contactPoint foaf:homepage ?directoryOrg_homepage.
                    #}
                    #OPTIONAL {
                    #?directoryOrg_telephoneBN vcard:hasValue ?directoryOrg_telephone.  
                    #}
                    } 
                   filter(?corporateBody_uri=<http://publications.europa.eu/resource/authority/corporate-body/CURIA>).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   FILTER(langMatches(lang(?corporateBody), "en")).
                   }
    """)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['corporateBody_uri',
#    'corporateBody',
#    'directoryOrg_uri',
#    'directoryOrg',
#    'directoryOrg_order',
#    'directoryOrg_protocolLevel']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CURIA'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Court of Justice of the European Union'},
#     'directoryOrg_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CJ'},
#     'directoryOrg': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Court of Justice'},
#     'directoryOrg_order': {'type': 'literal', 'value': 'A51'},
#     'directoryOrg_protocolLevel': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '2'}},
# ...

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
    PREFIX euvoc: <http://publications.europa.eu/ontology/euvoc#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    PREFIX resource: <http://publications.europa.eu/resource/>
            ASK where {{?membership_uri org:organization ?directoryOrg_uri;
                       euvoc:startDate ?membership_startDate;
                       euvoc:endDate ?membership_endDate;
                       euvoc:order ?membership_order;
                       euvoc:positionComplement ?membership;
                       euvoc:positionStatus ?membership_positionStatusUri.
                       #euvoc:roleQualification ?roleQualification_uri;
                       #euvoc:contactPoint ?contactPoint.
                    # ?directoryOrg_uri skos:prefLabel ?directoryOrg.
                    # ?membership_positionStatusUri skos:prefLabel ?membership_positionStatus.
                    # ?person_uri org:hasMembership ?membership_uri;
                    #            vcard:hasGender ?person_genderUri;
                                foaf:name ?person.
                    #?person_genderUri skos:prefLabel ?person_gender.
                    OPTIONAL{
                        # ?person_uri foaf:img ?person_image;
                                    resource:personcitizenship ?person_citizUri.
                        # ?person_citizUri skos:prefLabel ?person_citiz.
                        FILTER(langMatches(lang(?person_citiz), "en")).
                        BIND (STRBEFORE(STRAFTER( STR(?person_image), "https://www.europarl.europa.eu/mepphoto/" ), ".jpg" ) AS ?person_id)
                        #BIND (regex(STR(?person_img), "^https", "i") AS ?str_event)
                    }
                    } 
                   FILTER(STR(?membership)="Prime Minister").
                   filter(?directoryOrg_uri=<http://publications.europa.eu/resource/directory/organization/EURCOU/EURCOU_EURCOU.MEMB.SVN>).
                   FILTER(langMatches(lang(?membership), "en")).
                   FILTER(langMatches(lang(?membership_positionStatus), "en")).
                   FILTER(langMatches(lang(?directoryOrg), "en")).
                   #FILTER(langMatches(lang(?person_gender), "en")).
                   }
    """)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': []}, 'boolean': True}

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/AGRI'

# %%
uri='http://publications.europa.eu/resource/directory/organization/EIB/EIB_EIB-050005'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX org: <http://www.w3.org/ns/org#>
            SELECT DISTINCT ?s ?p ?o #?label
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EIB/EIB_EIB-050005'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EIB/EIB_EIB-050005'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#Organization'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/EIB/EIB_EIB-050005'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
# ...
