# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd

# %%
uri='http://publications.europa.eu/ontology/cdm#resource_legal'
list_classes=[]
df=pd.DataFrame(get_results(uri,"subclass",list_classes))
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-01bd119611d1> in <module>
#       1 uri='http://publications.europa.eu/ontology/cdm#resource_legal'
#       2 list_classes=[]
# ----> 3 df=pd.DataFrame(get_results(uri,"subclass",list_classes))
#       4 df
#
# NameError: name 'get_results' is not defined

# %%
len(df)
# Out:
# 369

# %%
df["class"].value_counts()
# Out:
# http://publications.europa.eu/ontology/cdm#case-law                                 68
# http://publications.europa.eu/ontology/cdm#act_preparatory                          49
# http://publications.europa.eu/ontology/cdm#legislation_secondary                    28
# http://publications.europa.eu/ontology/cdm#case-law_national                        18
# http://publications.europa.eu/ontology/cdm#resource_legal                           15
# http://publications.europa.eu/ontology/cdm#measure_national_implementing            15
# http://publications.europa.eu/ontology/cdm#proposal_act                             14
# http://publications.europa.eu/ontology/cdm#act_consolidated                         13
# http://publications.europa.eu/ontology/cdm#communication_cjeu                       10
# http://publications.europa.eu/ontology/cdm#question_parliamentary                    8
# http://publications.europa.eu/ontology/cdm#act_preparatory_ep                        8
# http://publications.europa.eu/ontology/cdm#official-journal                          8
# http://publications.europa.eu/ontology/cdm#agreement_international                   7
# http://publications.europa.eu/ontology/cdm#document_efta                             7
# http://publications.europa.eu/ontology/cdm#communication_case_new                    6
# http://publications.europa.eu/ontology/cdm#legislation_complementary                 5
# http://publications.europa.eu/ontology/cdm#staff-working-document                    5
# http://publications.europa.eu/ontology/cdm#act_preparatory_council                   5
# http://publications.europa.eu/ontology/cdm#archive_package                           4
# http://publications.europa.eu/ontology/cdm#act_preparatory_eesc                      4
# http://publications.europa.eu/ontology/cdm#treaty                                    4
# http://publications.europa.eu/ontology/cdm#directive                                 4
# http://publications.europa.eu/ontology/cdm#decision                                  3
# http://publications.europa.eu/ontology/cdm#staff-working-document_ec                 3
# http://publications.europa.eu/ontology/cdm#document_com_other_ec                     3
# http://publications.europa.eu/ontology/cdm#regulation                                3
# http://publications.europa.eu/ontology/cdm#com_package                               3
# http://publications.europa.eu/ontology/cdm#question_parliamentary_with-debate        3
# http://publications.europa.eu/ontology/cdm#act_other_ep                              2
# http://publications.europa.eu/ontology/cdm#fragment_resource_legal                   2
# http://publications.europa.eu/ontology/cdm#decision_internal_ep                      2
# http://publications.europa.eu/ontology/cdm#resolution_legislative_ep                 2
# http://publications.europa.eu/ontology/cdm#opinion_ep                                2
# http://publications.europa.eu/ontology/cdm#opinion_consultation_cor                  2
# http://publications.europa.eu/ontology/cdm#opinion_other_cor                         2
# http://publications.europa.eu/ontology/cdm#opinion_other_eesc                        2
# http://publications.europa.eu/ontology/cdm#act_other_eesc                            2
# http://publications.europa.eu/ontology/cdm#opinion_eesc                              2
# http://publications.europa.eu/ontology/cdm#opinion_consultation_eesc                 2
# http://publications.europa.eu/ontology/cdm#document_cjeu                             2
# http://publications.europa.eu/ontology/cdm#text-adopted                              2
# http://publications.europa.eu/ontology/cdm#resolution_other_ep                       2
# http://publications.europa.eu/ontology/cdm#act_other_cor                             2
# http://publications.europa.eu/ontology/cdm#joint-staff-working-document              2
# http://publications.europa.eu/ontology/cdm#document_budget_ep                        2
# http://publications.europa.eu/ontology/cdm#communication_request_opinion             1
# http://publications.europa.eu/ontology/cdm#act_legislative_other_oj_c                1
# http://publications.europa.eu/ontology/cdm#opinion_advocate-general                  1
# http://publications.europa.eu/ontology/cdm#cooperation_police-and-judicial           1
# http://publications.europa.eu/ontology/cdm#resolution_legislative                    1
# http://publications.europa.eu/ontology/cdm#non-opposition_joint-venture_notified     1
# http://publications.europa.eu/ontology/cdm#opinion_cjeu                              1
# http://publications.europa.eu/ontology/cdm#recommendation                            1
# http://publications.europa.eu/ontology/cdm#report_ep                                 1
# http://publications.europa.eu/ontology/cdm#recommendation_ecsc                       1
# http://publications.europa.eu/ontology/cdm#act_legislative_other_oj_l                1
# http://publications.europa.eu/ontology/cdm#non-opposition_concentration_notified     1
# Name: class, dtype: int64

# %%
df["element"].value_counts()
# Out:
# http://publications.europa.eu/ontology/cdm#act_consolidated                                                1
# http://publications.europa.eu/ontology/cdm#communication_cjeu_has_type_procedure_concept_type_procedure    1
# http://publications.europa.eu/ontology/cdm#fragment_resource_legal                                         1
# http://publications.europa.eu/ontology/cdm#document_com_other_ec_service_responsible                       1
# http://publications.europa.eu/ontology/cdm#case-law_national_keywords                                      1
#                                                                                                           ..
# http://publications.europa.eu/ontology/cdm#document_budget_ep_reported_by_person                           1
# http://publications.europa.eu/ontology/cdm#com_package_reference_volume                                    1
# http://publications.europa.eu/ontology/cdm#communication_ec_council-position                               1
# http://publications.europa.eu/ontology/cdm#opinion_cjeu                                                    1
# http://publications.europa.eu/ontology/cdm#decision_date_transposition                                     1
# Name: element, Length: 369, dtype: int64

# %%
df
# Out:
#                                                  class      type  \
# 0    http://publications.europa.eu/ontology/cdm#res...  subclass
# 1    http://publications.europa.eu/ontology/cdm#act...  property
# 2    http://publications.europa.eu/ontology/cdm#act...  property
# 3    http://publications.europa.eu/ontology/cdm#act...  property
# 4    http://publications.europa.eu/ontology/cdm#act...  property
# ..                                                 ...       ...
# 364  http://publications.europa.eu/ontology/cdm#treaty  subclass
# 365  http://publications.europa.eu/ontology/cdm#res...  subclass
# 366  http://publications.europa.eu/ontology/cdm#tex...  property
# 367  http://publications.europa.eu/ontology/cdm#tex...  subclass
# 368  http://publications.europa.eu/ontology/cdm#res...  property
#
#                                                element
# 0    http://publications.europa.eu/ontology/cdm#act...
# 1    http://publications.europa.eu/ontology/cdm#act...
# 2    http://publications.europa.eu/ontology/cdm#act...
# 3    http://publications.europa.eu/ontology/cdm#act...
# 4    http://publications.europa.eu/ontology/cdm#act...
# ..                                                 ...
# 364  http://publications.europa.eu/ontology/cdm#tre...
# 365  http://publications.europa.eu/ontology/cdm#tex...
# 366  http://publications.europa.eu/ontology/cdm#tex...
# 367  http://publications.europa.eu/ontology/cdm#res...
# 368  http://publications.europa.eu/ontology/cdm#res...
#
# [369 rows x 3 columns]

# %%
df.to_excel("output.xlsx")

# %% [markdown]
# ## OLD

# %%
def get_results(uri,typeQuery,list_subclasses):
    df_total=pd.DataFrame()
    results=get_subclasses(uri)
    if(len(results["results"]["bindings"])!=0):
        for r in results["results"]["bindings"]:
            list_subclasses.append({"class":uri,"type":typeQuery,"element":r[typeQuery]["value"]})
            get_results(r[typeQuery]["value"],"subclass",list_subclasses)
    return list_subclasses

# %% [markdown]
# ## NEW

# %%
def get_results(uri,typeQuery,list_subclasses):
    df_total=pd.DataFrame()
    results=get_subclasses(uri)
    if(len(results["results"]["bindings"])!=0):
        for r in results["results"]["bindings"]:
            list_subclasses.append({"class":uri,"type":typeQuery,"element":r[typeQuery]["value"]})
            results_properties=get_properties(r[typeQuery]["value"])
            if(len(results_properties["results"]["bindings"])!=0):
                for p in results_properties["results"]["bindings"]:
                    list_subclasses.append({"class":r[typeQuery]["value"],"type":"property","element":p["property"]["value"]})
            get_results(r[typeQuery]["value"],"subclass",list_subclasses)
    return list_subclasses

# %%
def get_properties(uri):

    query="""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX : <http://publications.europa.eu/ontology/cdm#>

    SELECT ?class ?property
    WHERE 
    {{ ?property rdfs:domain <"""+uri+"""> }
    }
    """

    return exec_query(query)

# %%
def get_subclasses(uri):

    query="""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX owl:  <http://www.w3.org/2002/07/owl#>

    SELECT DISTINCT ?subclass
    WHERE 
    { ?subclass rdfs:subClassOf <"""+uri+""">}
    """

    return exec_query(query)

# %%
def exec_query(query):
    sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

    sparql.setQuery(query)

    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    return results

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX : <http://publications.europa.eu/ontology/cdm#>

SELECT DISTINCT ?o
WHERE 
{{?s <http://publications.europa.eu/ontology/cdm#resource_legal_type> ?o}
}
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [], 'vars': ['o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'PC'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Y'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'E'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2003/019/33'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'AP'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'R'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'IP'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'TA'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2002/074/10'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'CN'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'DC'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'CC'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'D'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'CJ'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'XG'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'H'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2009/189/09'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'L'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2010/322/04'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'AG'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2008/167/05'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'SC'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1996/370/17'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'AC'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2012/231/04'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1995/337/13'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2008/229/06'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1999/288/10'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'XC'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'TJ'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'DE'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2011/217/09'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'CO'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'A'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1997/336/03'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'TO'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'M'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2007/248/11'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/108/44'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1998/227/02'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1998/042/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2003/247/07'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'B'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'XR'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2003/297/09'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1999/145/02'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1996/057/16'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2005/115/69'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2007/056/64'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'G'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1995/086/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2010/138/12'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'FA'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'X'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1995/074/03'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/259/27'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'IE'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1997/387/24'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1995/118/09'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'S'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2015/051/05'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'CB'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'O'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'AE'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2004/094/114'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'FJ'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'XX'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2007/082/09'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'CA'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2006/317A/05'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'V'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1997/252/35'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'KG'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/209/04'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'TN'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1999/309A/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/245/37'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2000/321/07'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/187/07'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2008/166/05'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2012/366/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'FB'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'T'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1996/104/14'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2007/116/03'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1997/181/39'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2008/031/03'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2004/094/68'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2005/217/19'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2005/276/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/094/07'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2011/111/05'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1998/166/35'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1995/350/26'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/160/16'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1999/280/02'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2008/146/'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'DP'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1996/258/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1999/193/04'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'BP'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2006/040/09'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/278/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2014/232/08'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2000/031/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2003/289/53'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2005/048/10'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2012/057/07'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2006/303/30'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2005/257/08'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'TB'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'XP'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2002/096/07'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'FO'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2003/248/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/130/06'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2003/118/23'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'P'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2012/349/03'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1997/137/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1999/222/14'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2010/030/12'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/166/14'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2009/216/07'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'U'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2007/170/18'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/019/08'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2010/038/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2007/056/43'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2011/129/05'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1999/157/03'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'UK'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2003/113/03'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2004/007/39'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1997/110/02'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'PT'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1995/144/08'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1996/043/08'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'AR'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': '
}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1996/202/03'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2002/323/49'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1998/026/17'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2008/189/02'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2006/165/72'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1996/370/04'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1998/278/36'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1995/350/22'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2002/097/21'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1998/018/04'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2008/061/03'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2000/335/62'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2002/289/53'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2003/101/48'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1997/009/15'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2000/149/62'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1997/354/06'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2005/262A/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2002/323/34'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1997/054/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2003/244/03'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2002/305/10'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2007/027/02'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/096E/21'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2005/095/02'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1997/212/45'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1998/387/09'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2005/239/06'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/022/06'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2005/035/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2005/178A/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1997/252/78'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2000/316/07'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2009/139/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2006/178/47'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2005/217/02'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1997/040/07'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2000/032/08(01)'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2003/309/09'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2013/252/05'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1995/337/07'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/186/23'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1997/027/12'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2000/044/08'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/156/06'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1996/294/22'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1996/158/25'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2005/023A/01'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2007/199/65'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2002/247/19'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2000/038/04'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1997/040/23'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1996/272/02'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2007/199/70'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1995/128/10'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/212/35'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2007/183/37'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2012/134/07'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1996/353/02'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1997/344/02'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2000/233/56'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2012/202/07'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1995/194/06'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2009/280/02'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1996/236/12'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1998/041/12'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2000/293/20'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1996/232/14'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2001/315A/02'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2002/309/09'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'SE'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2004/118/74'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2007/289/10'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2012/111/04'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C1997/177/03'}},
#    {'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'C2005/082/65'}},
#    ...]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl:  <http://www.w3.org/2002/07/owl#>

SELECT DISTINCT ?subclass
WHERE 
{ ?subclass rdfs:subClassOf <http://publications.europa.eu/ontology/cdm#resource_legal> }
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [], 'vars': ['subclass']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#act_consolidated'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#act_preparatory'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#agreement_international'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_efta'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#fragment_resource_legal'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#legislation_complementary'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#legislation_secondary'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#measure_national_implementing'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#official-journal'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#oj_c'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#treaty'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#text-adopted'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl:  <http://www.w3.org/2002/07/owl#>

SELECT DISTINCT ?subclass
WHERE 
{ ?subclass rdfs:subClassOf <http://publications.europa.eu/ontology/cdm#treaty> }
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [], 'vars': ['subclass']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#treaty_consolidated'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl:  <http://www.w3.org/2002/07/owl#>

SELECT DISTINCT ?subclass
WHERE 
{ ?subclass rdfs:subClassOf <http://publications.europa.eu/ontology/cdm#case-law> }
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [], 'vars': ['subclass']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_national'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#judgement'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#opinion_advocate-general'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#order_cjeu'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#opinion_cjeu'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#decision_cjeu'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#seizure'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#report_case'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#proceeding_third-party'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#decision_review_cjeu'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#ruling_cjeu'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#info_decision_cjeu'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX : <http://publications.europa.eu/ontology/cdm#>

SELECT ?class ?property
WHERE 
{{ ?property rdfs:domain <http://publications.europa.eu/ontology/cdm#case-law> }
}
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [], 'vars': ['class', 'property']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_immediately_enforces_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_affaire_jurisdiction'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_affaire_number'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_affaire_type'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_affaire_year'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_article_journal_related'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_commented_by_agent'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_defended_by_agent'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_delivered_by_advocate-general'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_delivered_by_judge'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_ecli'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_has_procjur'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_has_type_procedure_concept_type_procedure'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_interpretes_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_is_about_concept_case-law'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_is_about_concept_new_case-law'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_national-judgement'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_originates_in_country'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_published_in_erecueil'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_requested_by_agent'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_requests_for_failure_to_fulfill_an_obligation_for_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_states_failure_concerning_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_confirms_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_delivered_by_court-formation'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_has_conclusions_opinion_advocate-general'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_originates_in_country_role-qualifier'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_uses_procedure_language'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_declares_valid_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_declares_void_by_preliminary_ruling_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_requests_annulment_of_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_delivered_by_court_national'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_declares_void_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_joins_case_court'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_requests_interpretation_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_subject_to_appeal_in_case_court'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_declares_incidentally_valid_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_incidentally_declares_void_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_corrects_judgement_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_amends_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_partially_annuls_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_interpretes_judgement_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_suspends_application_of_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_requests_opinion_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_reviews_judgement_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_requests_validation_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_reexamined_by_case_court'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_affects_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_communicated_on_by_communication_cjeu'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_decision_review_requested_by_communication_case_new'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_defers_application_of_resource_legal'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_delivered_by_institution'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_judgement_national'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_referred_to_for_preliminary_ruling_case-law'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_refers_for_preliminary_ruling_case-law'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_refers_to_for_preliminary_ruling_case-law'}},
#    {'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law_source_ruling_preliminary'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX : <http://publications.europa.eu/ontology/cdm#>

SELECT ?class ?property
WHERE 
{{ ?property rdfs:domain <http://publications.europa.eu/ontology/cdm#treaty> }
}
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [], 'vars': ['class', 'property']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX : <http://publications.europa.eu/ontology/cdm#>

SELECT ?class ?property
WHERE 
{{ ?property rdfs:domain <http://publications.europa.eu/ontology/cdm#judgement> }
}
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [], 'vars': ['class', 'property']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX : <http://publications.europa.eu/ontology/cdm#>

SELECT DISTINCT ?p ?o
WHERE 
{{<http://publications.europa.eu/ontology/cdm#decision_cjeu> ?p ?o}
}
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [], 'vars': ['p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Decision of the Court of Justice'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/annotation#date'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Decision of the Court of Justice  (6CD)'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl:  <http://www.w3.org/2002/07/owl#>

SELECT DISTINCT ?subclass ?label ?comment
WHERE 
{ ?subclass rdfs:subClassOf <http://publications.europa.eu/ontology/cdm#case-law>;
            rdfs:label ?label;
            rdfs:comment ?comment.}
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [], 'vars': ['subclass', 'label', 'comment']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#judgement'},
#     'label': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Judgement'},
#     'comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Judgement in sector 6  (6CJ/6TJ/6FJ)'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#opinion_advocate-general'},
#     'label': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Opinion of advocate general'},
#     'comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Opinion of the advocate general in sector 6 (6CC/6TC).\nCurrently encoded by table FD'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#order_cjeu'},
#     'label': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Court order'},
#     'comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Order in sector 6 (6CO/6TO/6FO)'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#opinion_cjeu'},
#     'label': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Opinion of the Court of Justice'},
#     'comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Opinion of the Court of Justice in sector 6 (= type 6CV)'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#seizure'},
#     'label': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Seizure'},
#     'comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Seizure in sector 6 (6CS)'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#report_case'},
#     'label': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Case report'},
#     'comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Case report in sector 6 (6CP)'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#proceeding_third-party'},
#     'label': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Third party proceeding'},
#     'comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Third party proceeding in sector 6 (6CT/6TT/6FT)'}},
#    {'subclass': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#ruling_cjeu'},
#     'label': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Court ruling'},
#     'comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Ruling of the Court of Justice in sector 6 (6CX)'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl:  <http://www.w3.org/2002/07/owl#>

SELECT DISTINCT ?p
WHERE 
{ ?subclass rdfs:subClassOf <http://publications.europa.eu/ontology/cdm#case-law>;
            # ?p ?o.}
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [], 'vars': ['p']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#comment'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/annotation#date'}}]}}

# %%
uri='http://publications.europa.eu/ontology/cdm#opinion_advocate-general'
uri='http://publications.europa.eu/ontology/cdm#question_written'
uri='http://publications.europa.eu/ontology/cdm#question_parliamentary'
uri='http://publications.europa.eu/resource/cellar/02740371-b529-4c4f-80a1-9b9480cbd701'
uri='http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'

# %%
'http://publications.europa.eu/ontology/cdm#question_parliamentary_asked_by_group_parliamentary'
'http://publications.europa.eu/ontology/cdm#resource_legal_is_about_subject-matter'
'http://publications.europa.eu/ontology/cdm#work_date_document'
'http://publications.europa.eu/ontology/cdm#work_is_about_concept_eurovoc'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   } #LIMIT 1
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#Organization'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#Corporate'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/created'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2012-11-21'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#versionInfo'},
#     'o': {'type': 'literal', 'value': '20210616-0'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/EP_MEPS'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'hu',
#      'value': 'A Zöldek/Európai Szabad Szövetség képviselőcsoportja'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'nl',
#      'value': 'Fractie De Groenen/Vrije Europese Alliantie'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'de',
#      'value': 'Fraktion der Grünen / Freie Europäische Allianz'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Group of the Greens/European Free Alliance'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'fr',
#      'value': 'Groupe des Verts/Alliance libre européenne'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'pl',
#      'value': 'Grupa Zielonych / Wolne Przymierze Europejskie'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'es',
#      'value': 'Grupo de los Verdes/Alianza Libre Europea'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'pt',
#      'value': 'Grupo dos Verdes/Aliança Livre Europeia'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'mt',
#      'value': 'Grupp tal-Ħodor/Alleanza Ħielsa Ewropea'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'da',
#      'value': 'Gruppen De Grønne/Den Europæiske Fri Alliance'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'sv',
#      'value': 'Gruppen De gröna/Europeiska fria alliansen'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'it',
#      'value': 'Gruppo Verde/Alleanza libera europea'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'ro',
#      'value': 'Grupul Verzilor/Alianţa Liberă Europeană'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'hr',
#      'value': 'Klub zastupnika Zelenih/Europskog slobodnog saveza'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'ga',
#      'value': 'Na Glasaigh/ agus Saor-Chomhghuaillíochta Eorpaí'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'et',
#      'value': 'Roheliste/Euroopa Vabaliidu fraktsioon'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'sl',
#      'value': 'Skupina Zelenih/Evropske svobodne zveze'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'sk',
#      'value': 'Skupina Zelených/Európska slobodná aliancia'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'cs',
#      'value': 'Skupina Zelených/Evropské svobodné aliance'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'fi',
#      'value': 'Vihreät / Euroopan vapaa allianssi -ryhmä'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'lv',
#      'value': 'Zaļo un Eiropas Brīvās apvienības grupa'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'el',
#      'value': 'Ομάδα τωv Πρασίvωv / Ευρωπαϊκή Ελεύθερη Συμμαχία'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'bg',
#      'value': 'Група на Зелените/Европейски свободен алианс'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'lt',
#      'value': 'Žaliųjų frakcija/Europos laisvasis aljansas'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#startDate'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '1999-07-20'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body-classification/EP_GROUP'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri', 'value': 'http://lemon-model.net/lemon#context'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri', 'value': 'http://lemon-model.net/lemon#context'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/IMMC'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2003/01/geo/wgs84_pos#location'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/place/BEL_BRU'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81041027'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81047059'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81047282'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81049182'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81052369'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81054258'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81054834'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058558'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81060298'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81060645'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81064876'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81065638'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81068250'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81070480'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81071968'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81073215'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81077572'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81077863'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81078466'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81078990'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81080094'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81080649'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81081414'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81082465'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81082911'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81083331'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81084762'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81087301'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81088137'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089461'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089462'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089465'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089466'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089468'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089469'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089471'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089472'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089474'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089475'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089476'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089478'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089479'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089480'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089481'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089485'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089486'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089488'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81039109'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81044047'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81057939'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81059390'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81062874'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81064093'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81065930'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81066777'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81069046'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81076255'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81081768'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81082188'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81084300'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81084894'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81085769'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089463'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089464'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089467'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089470'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089473'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089477'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089482'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089484'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089487'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#classification'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body-classification/EP_GROUP'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/dateAccepted'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2012-11-27'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/dateSubmitted'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2012-11-27'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#notation'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/ontology/euvoc#FD_290',
#      'value': 'FRACTIO-04/004'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#notation'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/ontology/euvoc#FD_290',
#      'value': 'FRACTIO-09/004'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#notation'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/ontology/euvoc#FD_290',
#      'value': 'FRACTIO-99/001'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#notation'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/ontology/euvoc#WHOISWHO',
#      'value': 'EP_DPPEVERTSANDALE'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#topConceptOf'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#order'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '12'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#protocolLevel'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '3'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#status'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/concept-status/CURRENT'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlClassification'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body-classification/EP_GROUP'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81052381'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81056931'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81062084'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81069947'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89988183'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlOrder'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89988181'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlProtocolLevel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89988182'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlSubOrganizationOf'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89988184'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/homepage'},
#     'o': {'type': 'uri', 'value': 'https://www.greens-efa.eu'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#identifier'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/resource/authority/use-context/WHOISWHO-institution-uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#identifier'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/resource/authority/use-context/ID_ENTITY',
#      'value': 'DPPEVERTSANDALE'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#identifier'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/resource/authority/use-context/MNEMONIC',
#      'value': 'Verts/ALE'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#subOrganizationOf'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#broader'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://purl.org/dc/elements/1.1/identifier'},
#     'o': {'type': 'literal', 'value': 'EP_GROUP_GREEN_EFA'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/authority-code'},
#     'o': {'type': 'literal', 'value': 'EP_GROUP_GREEN_EFA'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/deprecated'},
#     'o': {'type': 'literal', 'value': 'false'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/op-code'},
#     'o': {'type': 'literal', 'value': 'EP_GROUP_GREEN_EFA'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/start.use'},
#     'o': {'type': 'literal', 'value': '1999-07-20'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/op-code'},
#     'o': {'type': 'literal', 'value': 'EP_GROUP_GREEN_EFA'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/op-mapped-code'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81038590'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/op-mapped-code'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81074140'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/op-mapped-code'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089292'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/op-mapped-code'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81089483'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/replaces'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_GROUP_GREEN_EFA'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#concept'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1451'}}]}}

# %%
uri='http://publications.europa.eu/resource/cellar/132d6d18-acdf-44d6-ba41-5bacf0eea071'

# %%
uri='http://publications.europa.eu/ontology/cdm#treaty'
uri='http://publications.europa.eu/ontology/cdm#act_consolidated_based_on_resource_legal'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#act_consolidated_based_on_resource_legal'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#act_consolidated_based_on_resource_legal'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#subPropertyOf'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#based_on'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#act_consolidated_based_on_resource_legal'},
#     'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#inverseOf'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal_basis_for_act_consolidated'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#act_consolidated_based_on_resource_legal'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Consolidated act based on legal resource'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#act_consolidated_based_on_resource_legal'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#domain'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#act_consolidated'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#act_consolidated_based_on_resource_legal'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#range'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#act_consolidated_based_on_resource_legal'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#comment'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'This consolidated act starts out with this legal resource as its basic act.\nCould be used as the basis for links between consolidated acts of one base act, use either CONSOLIF_FAMILY or CONSLEG_REFER depending on the type of consolidated act, relating \nto a layer or to a family.  '}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#act_consolidated_based_on_resource_legal'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/annotation#in_notice'},
#     'o': {'type': 'literal', 'value': 'true'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#act_consolidated_based_on_resource_legal'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/annotation#to_be_indexed'},
#     'o': {'type': 'literal', 'value': 'true'}}]}}

# %%
uri='http://publications.europa.eu/ontology/cdm#document_cjeu'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            SELECT DISTINCT ?s ?p ?o
            where {{?s rdfs:type ?o.
                    } 
                   filter(?o=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/09e46454-41db-4b8a-89ed-4c468b943cdc'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/132d6d18-acdf-44d6-ba41-5bacf0eea071'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/1e3100ce-8a71-433a-8135-15f5cc0e927c'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/30b14a36-02ea-42b0-aecc-67f0c67863b7'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/32869030-3baa-42a4-97bf-75f1448e33f8'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/33c68af6-1ea1-42b7-8d40-08fd7b756e7b'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar/46a3db3b-e1ae-11e4-b1d3-01aa75ed71a1'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/cellar
| conclusion | Opinion of the advocate-general of the court of Justice | C | CC | TC |\n\n| saisie-arrêt | seizure | S | CS | |\n\n| tierce opposition | third-party proceedings | T | CT | TT | FT |\n\n| avis | Opinion of the Court of justice | V | CV | | |\n\n| délibération | ruling | X | CX | | |\n\n| décision | decision | D | CD | | |\n\n| prises de position | case report | P | CP | | |\n\n| communication nouvelle affaire | communication new case | N | CN | TN | FN |\n\n| communication arrêt | communication judgement | A | CA | TA | FA |\n\n| communication ordonnance | communication order | B | CB | TB | FB |\n\n| communication demande avis | communication request for an opinion | U | CU | | |\n\n| communication avis | communication opinion | G | CG | | |\n\nSector 6 documents can be either case law or communications of the Court of Justice.'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX : <http://publications.europa.eu/ontology/cdm#>

SELECT ?class ?property
WHERE 
{{ ?property rdfs:domain <http://publications.europa.eu/ontology/cdm#document_cjeu> }
}
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [], 'vars': ['class', 'property']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'property': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu_published_in_court-report'}}]}}

# %%
uri='http://publications.europa.eu/ontology/cdm#document_cjeu_published_in_court-report'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu_published_in_court-report'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2002/07/owl#ObjectProperty'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu_published_in_court-report'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#subPropertyOf'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#published_in'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu_published_in_court-report'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Court document published in the Court report'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu_published_in_court-report'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#domain'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu_published_in_court-report'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#range'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#court-report'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu_published_in_court-report'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#comment'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Case law published in Reports. DEPRECATED;  The court document is published in a given edition of the Court report'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu_published_in_court-report'},
#     'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#deprecated'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': ''}}]}}

# %%
uri='http://publications.europa.eu/ontology/cdm#court-report'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX : <http://publications.europa.eu/ontology/cdm#>

SELECT ?class ?property
WHERE 
{{ ?property rdfs:domain <http://publications.europa.eu/ontology/cdm#document_cjeu> }
}
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
prefix cdm: <http://publications.europa.eu/ontology/cdm#>
PREFIX lemon: <http://lemon-model.net/lemon#>
prefix dstype: <http://publications.europa.eu/resource/authority/dataset-type/>
Select distinct ?vocabulary ?VocabularyLabel ?useContext ?def
where
{?vocabulary a <http://www.w3.org/2004/02/skos/core#ConceptScheme>;
<http://publications.europa.eu/ontology/authority/prefLabel> ?VocabularyLabel.
# ?s skos:topConceptOf ?vocabulary;
lemon:context ?useContext.
# ?useContext skos:definition ?def
FILTER (?useContext = <http://publications.europa.eu/resource/authority/use-context/EURLEX>)
}
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [],
#   'vars': ['vocabulary', 'VocabularyLabel', 'useContext', 'def']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Corporate body'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/language'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Language'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/resource-type'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Resource type'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/country'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Country'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/role-qualifier'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Role qualifier'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/event'},
#     'VocabularyLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Event'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/procedure'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Interinstitutional procedure'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/procjur'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Legal proceeding'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/procresult'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Legal proceeding result'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/treaty'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Treaty'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/case-report'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Case report'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subject-matter'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Subject matter'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/multilingual'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Multilingual'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/place'},
#     'VocabularyLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Place'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/role'},
#     'VocabularyLabel': {'type': 'literal', 'xml:lang': 'en', 'value': 'Role'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/file-status'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'File status'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/modification-type'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Modification type'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subdivision-position'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Subdivision position'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/subdivision'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Subdivision'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}},
#    {'vocabulary': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/dir-eu-legal-act'},
#     'VocabularyLabel': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directory of EU legal acts'},
#     'useContext': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'},
#     'def': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Use context in several authority tables for filtering concepts used by EurLex domain in ATTO (Atelier des Tables de Traductions de l’Office des publications).'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX owl:  <http://www.w3.org/2002/07/owl#>
    
    SELECT DISTINCT ?mainEULawClass ?mainEULawClass_uri ?subclass ?subclass_uri ?subclass_label ?subclass_comment
    WHERE 
    {
    {?subclass_uri rdfs:subClassOf ?mainEULawClass_uri;
        rdfs:label ?subclass;
        rdfs:comment ?subclass_comment.
    # ?mainEULawClass_uri rdfs:label ?mainEULawClass 
     }filter(?mainEULawClass_uri=<http://publications.europa.eu/ontology/cdm#resource_legal>)
     }ORDER BY ?mainEULawClass ?subclass
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [],
#   'vars': ['mainEULawClass',
#    'mainEULawClass_uri',
#    'subclass',
#    'subclass_uri',
#    'subclass_label',
#    'subclass_comment']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'mainEULawClass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Legal resource'},
#     'mainEULawClass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Case law'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#case-law'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': '"Real" case law in sector 6 (= a subset of the complete sector 6) and sector 8.\nChanged to subclass of: resource_legal.\n\nCase law of the Court of Justice also inherits from document_cjeu\n\nRemarks:\n* case-law_XXX_resource_legal can all be seen as sub-properties of a generic "affects" property\n* These fields by and large correspond to the specific fields of the VOLET_CDJ\n* NOMUSUEL and NOMUSUEL_XX: Appears as title in the corresponding expression'}},
#    {'mainEULawClass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Legal resource'},
#     'mainEULawClass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Complementary legislation'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#legislation_complementary'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': ' Complementary legislation (= sector 4)'}},
#    {'mainEULawClass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Legal resource'},
#     'mainEULawClass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Consolidated act'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#act_consolidated'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Consolidated acts (= sector 0): Non-official documents integrating acts of sector 3 with their amendments and corrections.\n\nNote: The original VOLET_CONSLEG contains also more fields:\n* CONSOLID_SEQ: Sequence in the list\n* CONSOLID_ACT set: Logical grouping element: Used if the act is modified\n* CONSOLID_ROLE: "IN ou OUT suivant prise en compte dans consolidation"\n* CONSOLID_FICHE: contains links from the acts to the consolidating acts\n* BF_NAT, BF, LE and TM are old Consolidation fields that need to be taken into account\n\nThe pertinence of these fields must be discussed\n'}},
#    {'mainEULawClass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Legal resource'},
#     'mainEULawClass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Court of Justice document'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_cjeu'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Case law / jurisprudence and other communications of the Court of Justice (= sector 6). In contrast to the original structure a further subdevision by author is not represented in the class structure itself, but will be done by linking it to the author property. This does not preclude that we could calculate these classes based on that information and suitable inference rules.\n\nThe following table --- which is based on the new structure of case law as proposed for the ongoing reunumerotation --- specifies the combination of case-law classes and the court handing out these type of case law (English translations of types based on a mail from Jean-Philippe Loucheur):\n\n|| Type (en français) || Type (in English) || Sigle || Cour || TPI || TFP || Subclass ||\n\n| | | | C | T | F | |\n\n| arrêt | judgement | J | CJ | TJ | FJ |\n\n| ordonnance | order | O | CO | TO | FO |\n\n| conclusion | Opinion of the advocate-general of the court of Justice | C | CC | TC |\n\n| saisie-arrêt | seizure | S | CS | |\n\n| tierce opposition | third-party proceedings | T | CT | TT | FT |\n\n| avis | Opinion of the Court of justice | V | CV | | |\n\n| délibération | ruling | X | CX | | |\n\n| décision | decision | D | CD | | |\n\n| prises de position | case report | P | CP | | |\n\n| communication nouvelle affaire | communication new case | N | CN | TN | FN |\n\n| communication arrêt | communication judgement | A | CA | TA | FA |\n\n| communication ordonnance | communication order | B | CB | TB | FB |\n\n| communication demande avis | communication request for an opinion | U | CU | | |\n\n| communication avis | communication opinion | G | CG | | |\n\nSector 6 documents can be either case law or communications of the Court of Justice.'}},
#    {'mainEULawClass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Legal resource'},
#     'mainEULawClass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'EFTA document'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#document_efta'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'European Free Trade Association (EFTA) document (= sector E in EUR-Lex)'}},
#    {'mainEULawClass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Legal resource'},
#     'mainEULawClass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'International agreement'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#agreement_international'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'International agreements (= sector 2 in EUR-Lex)'}},
#    {'mainEULawClass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Legal resource'},
#     'mainEULawClass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Legal fragment'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#fragment_resource_legal'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': ' Fragment of a legal resource (e.g. §2 of the Treaty on European Union and the Treaty establishing the European Community, always linked to that resource)'}},
#    {'mainEULawClass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Legal resource'},
#     'mainEULawClass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'National implementing measures'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#measure_national_implementing'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'National implementing measures (= sector 7 in EUR-Lex).\n\nInformation on National implementing measures aka NIMs are currently typically expressed in VOLET_MNE (MNE: mésure nationale d\'exécution = NIM). This volet contains references to the national implementing measures enacted in order to comply with European directives. The volet is usually directly fed by data issued by the Secretariat General.\n\nNote: Information on National Implementing Measures are currently partially encoded as "true" sector 7 document, but for the most part they are stored in the VOLET_MNE of their "mother" directive. However, for conversion these must become their own objects, only linked to the directive(s) they implement.\n\nAs an example the <VOLET_MNE> of the Council directive Council Directive 2009/158/EC of 30 November 2009 (= 32009L0158) on "animal health conditions governing intra-Community trade in, and imports from third countries of, poultry and hatching eggs" that shows how the country codes are used to encode the title(s) of the NIMs belonging to a given directive. The number of different implementing measures can vary per country.\n\n\n{code}\n<VOLET_MNE>\n<DE>1. - Neunte Verordnung zur Änderung der Binnenmarkt-Tiersuchenverordnung vom 27. März 2006</DE>\n<DE>2. - Zehnte Verordnung zur Änderung der Binnenmarkt-Tierseuchenschutzverordnung vom 11. Dezember 2006</DE>\n<DE>3. - Bekanntmachung der Neufassung der Binnenmarkt-Tierseuchenschutzverordnung vom 6. April 2005</DE>\n<LV>1. - Mājputnu un inkubējamo olu aprites kārtība</LV>\n<CZ>1. - Zákon č. 131/2003 Sb., kterým se mění zákon č. 166/1999 Sb., o veterinární péči a o změně některých souvisejících zákonů (veterinární zákon), ve znění pozdějších předpisů, a některé další zákony</CZ>\n[...]\n<CZ>8. - Vyhláška č. 12/2010 Sb., kterou se mění vyhláška č. 299/2003 Sb., o opatřeních pro předcházení a zdolávání nákaz a nemocí přenosných ze zvířat na člověka, ve znění pozdějších předpisů</CZ>\n<CZ>9. - Zákon č. 182/2008 Sb., kterým se mění zákon č. 166/1999 Sb., o veterinární péči a o změně některých souvisejících zákonů (veterinární zákon), ve znění pozdějších předpisů, zákon č. 634/2004 Sb., o správních poplatcích, ve znění pozdějších předpisů, a zákon č. 154/2000 Sb., o šlechtění, plemenitbě a evidenci hospodářských zvířat a o změně některých souvisejících zákonů (plemenářský zákon), ve znění pozdějších předpisů</CZ>\n[...]\n</VOLET_MNE>\n{code}\n\n'}},
#    {'mainEULawClass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Legal resource'},
#     'mainEULawClass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OJ C series'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#oj_c'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Other documents published in the Official Journal C Series (= sector C in EUR-Lex) .\nSector C effectively has only one subsector called again C, so no further subclasses are needed.'}},
#    {'mainEULawClass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Legal resource'},
#     'mainEULawClass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Official Journal'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#official-journal'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': ' The Official Journal itself'}},
#    {'mainEULawClass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Legal resource'},
#     'mainEULawClass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Parliamentary question'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#question_parliamentary'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Parliamentary questions (= sector 9 in EUR-Lex)'}},
#    {'mainEULawClass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Legal resource'},
#     'mainEULawClass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Preparatory act'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#act_preparatory'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'As per the decision of the meeting of 2010-05-11 the works in sector 5 will be split in real preparatory acts and others such as the report of the Court of Auditors. They will be distinguished by document type and author (e.g. the opinion of the ECB). The preparatory acts have thus been restructured to clearly distinguish between preparatory acts in a strict sense (COMs etc.) and other types of documents that have traditionally been grouped in sector 5.\n\n'}},
#    {'mainEULawClass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Legal resource'},
#     'mainEULawClass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Secondary legislation'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#legislation_secondary'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Secondary legislation (= sector 3 in EUR-Lex) '}},
#    {'mainEULawClass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Legal resource'},
#     'mainEULawClass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Text adopted'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#text-adopted'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Texts adopted by the European Parliament'}},
#    {'mainEULawClass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Legal resource'},
#     'mainEULawClass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Treaty'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#treaty'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'The class treaty does has concrete treaty instances that correspond to the subsectors of sector 1'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX dcterms: <http://purl.org/dc/terms/>
SELECT DISTINCT ?opThemeMain ?opThemeMain_uri ?opTheme ?opTheme_uri ?opTheme_dateCreated
where
{
{?opTheme_uri rdf:type ?opThemeMain_uri;
skos:prefLabel ?opTheme;
dcterms:created ?opTheme_dateCreated.
# ?opThemeMain_uri rdfs:label ?opThemeMain                    
}
filter(?opThemeMain_uri=<http://publications.europa.eu/ontology/cdm#concept_op_theme>)
FILTER(langMatches(lang(?opTheme), "en")).
filter not exists {?opTheme_uri skos:broader ?broader}
}ORDER BY ?opThemeMain ?opTheme
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [],
#   'vars': ['opThemeMain',
#    'opThemeMain_uri',
#    'opTheme',
#    'opTheme_uri',
#    'opTheme_dateCreated']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Activities of the European Union'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/A'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Economy — Finance'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/E'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal', 'xml:lang': 'en', 'value': 'Energy'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/J'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Environment — Ecology'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/L'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'External relations'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/C'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Information — Education — Culture — Sport'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/G'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Law and justice'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/B'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Scientific and technical research'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/M'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal', 'xml:lang': 'en', 'value': 'Social'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/F'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal', 'xml:lang': 'en', 'value': 'Statistics'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/N'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Trade — Competition'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/D'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal', 'xml:lang': 'en', 'value': 'Transport'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/K'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}}]}}

# %%
uri='http://publications.europa.eu/ontology/cdm#legislation_complementary'
#uri='http://publications.europa.eu/ontology/cdm#agent'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX owl:  <http://www.w3.org/2002/07/owl#>
    
    SELECT DISTINCT ?class ?class_uri ?class_comment ?subclass ?subclass_uri ?subclass_comment
    WHERE 
    {
    {?subclass_uri rdfs:subClassOf ?class_uri;
        rdfs:label ?subclass;
        rdfs:comment ?subclass_comment.
    # ?class_uri rdfs:label ?class;
        rdfs:comment ?class_comment.
     }filter(?class_uri=<"""+uri+""">)
     }ORDER BY ?mainEULawClass ?subclass
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [],
#   'vars': ['class',
#    'class_uri',
#    'class_comment',
#    'subclass',
#    'subclass_uri',
#    'subclass_comment']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'class': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Agent'},
#     'class_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#agent'},
#     'class_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': '"A resource that acts or has the power to act. Examples of Agent include person, organization, and software agent" (Dublin Core) '},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Committee'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#committee'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'A group of\xa0representatives from EU countries assisting the Commission for implementing acts\xa0during the internal decision-making process'}},
#    {'class': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Agent'},
#     'class_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#agent'},
#     'class_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': '"A resource that acts or has the power to act. Examples of Agent include person, organization, and software agent" (Dublin Core) '},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Concept representing possible role qualifiers'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#role-qualifier'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Values currently used in the Court schema: INDIV, TC, IO, MS, CI, STAFF\n\nTraced in MDR-1937'}},
#    {'class': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Agent'},
#     'class_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#agent'},
#     'class_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': '"A resource that acts or has the power to act. Examples of Agent include person, organization, and software agent" (Dublin Core) '},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Country'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#country'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': ' Country. The list of instances of this class is provided by the Metadata Registry.\n\nA country can in our context both act as an agent and as an administrative unit. '}},
#    {'class': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Agent'},
#     'class_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#agent'},
#     'class_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': '"A resource that acts or has the power to act. Examples of Agent include person, organization, and software agent" (Dublin Core) '},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Court formation'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#court-formation'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Formation of a court delivering a decision, e.g.CP\tCour plénière'}},
#    {'class': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Agent'},
#     'class_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#agent'},
#     'class_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': '"A resource that acts or has the power to act. Examples of Agent include person, organization, and software agent" (Dublin Core) '},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Expert group'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#expert-group'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': ' A group of\xa0representatives from EU countries assisting the Commission for implementing acts\xa0during the internal decision-making process '}},
#    {'class': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Agent'},
#     'class_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#agent'},
#     'class_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': '"A resource that acts or has the power to act. Examples of Agent include person, organization, and software agent" (Dublin Core) '},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Institution'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Institution (typically public).\nThe class institution has as instances institutions like the European Commission, the European Parliament, the European Council, the Council of the Regions etc.\nInstitutions are defined by the corporate-body table'}},
#    {'class': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Agent'},
#     'class_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#agent'},
#     'class_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': '"A resource that acts or has the power to act. Examples of Agent include person, organization, and software agent" (Dublin Core) '},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'National court'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#court_national'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'National court, used esp. in the context of JURE'}},
#    {'class': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Agent'},
#     'class_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#agent'},
#     'class_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': '"A resource that acts or has the power to act. Examples of Agent include person, organization, and software agent" (Dublin Core) '},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Organization'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#organization'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Organization (typically private) '}},
#    {'class': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Agent'},
#     'class_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#agent'},
#     'class_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': '"A resource that acts or has the power to act. Examples of Agent include person, organization, and software agent" (Dublin Core) '},
#     'subclass': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Person'},
#     'subclass_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#person'},
#     'subclass_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'The FOAF vocabulary http://xmlns.com/foaf/spec can be used to specify other attributes such as name, email addresses etc. as applicable and needed. Such attributes are however currently not covered in Procat.\n\nhttp://xmlns.com/foaf/0.1/Person\n\nIf we want to map a person specifically to an authority table (e.g. FD table 013 or 014) this works with inScheme to the appropriate table, e.g. FD 014 in this case:\n\n      <CMROntology:document_budget_ep_reported_by_person>\n         <CMROntology:ATTO_FD_014 rdf:about="http://publications.europa.eu/resource/authority/fd_014/AALTONEN">\n            <skos:inScheme xmlns:skos="http://www.w3.org/2004/02/skos/core#"\n                           rdf:resource="&cellar-authority;/fd_014"/>\n         </CMROntology:ATTO_FD_014>\n      </CMROntology:document_budget_ep_reported_by_person>\n\nThe person is then correctly decoded using the authority table in question'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX : <http://publications.europa.eu/ontology/cdm#>

    SELECT DISTINCT ?class ?class_uri ?class_comment ?property ?property_uri ?property_comment
    WHERE 
    {{ ?property_uri rdfs:domain ?class_uri;
         rdfs:label ?property;
         rdfs:comment ?property_comment.
    # ?class_uri rdfs:label ?class;
        rdfs:comment ?class_comment. 
    }filter(?class_uri=<"""+uri+""">)
    }ORDER BY ?class ?property
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
# Out:
# {'head': {'link': [],
#   'vars': ['class',
#    'class_uri',
#    'class_comment',
#    'property',
#    'property_uri',
#    'property_comment']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'class': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Complementary legislation'},
#     'class_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#legislation_complementary'},
#     'class_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': ' Complementary legislation (= sector 4)'},
#     'property': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Complementary legislation stored by agent'},
#     'property_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#legislation_complementary_stored_by_agent'},
#     'property_comment': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Complementary lesiglation is stored by an agent acting as depositary. DP (1) / depositary.  Relevant for legal analysis: true.'}}]}}

# %%
uri='http://publications.europa.eu/ontology/cdm#legislation_complementary_stored_by_agent'
#uri='http://publications.europa.eu/ontology/cdm#court-report_publishes_document_cjeu'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX : <http://publications.europa.eu/ontology/cdm#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>

    SELECT DISTINCT ?property ?property_uri ?property_comment
    WHERE 
    {{ ?property_uri rdfs:domain ?class_uri;
         rdfs:label ?property;
         rdfs:comment ?property_comment.
    # ?s ?property_uri ?p.
    # ?p rdfs:type ?class_uri;
        rdfs:label ?class;
        rdfs:comment ?class_comment. 
    }filter(?property_uri=<"""+uri+""">)
    }ORDER BY ?class ?property
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            SELECT DISTINCT ?o
            where {{?s ?p ?o.
                    #?o rdfs:type ?class.
                    } 
                   filter(?p=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'}},
#    {'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CONS-SG'}},
#    {'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'}},
#    {'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CEU-SG'}},
#    {'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/L-G'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            SELECT DISTINCT ?class
            where {{?s ?p ?o.
                    # ?o rdfs:type ?class.
                    } 
                   filter(?p=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['class']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'class': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#ATTO_FD_040'}},
#    {'class': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'class': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution'}},
#    {'class': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#Organization'}},
#    {'class': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#Corporate'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX dcterms: <http://purl.org/dc/terms/>
SELECT DISTINCT ?opThemeMain ?opThemeMain_uri ?opTheme ?opTheme_uri ?opTheme_dateCreated
where
{
    {?opTheme_uri rdf:type ?opThemeMain_uri;
     skos:prefLabel ?opTheme;
     dcterms:created ?opTheme_dateCreated.
     # ?opThemeMain_uri rdfs:label ?opThemeMain
    }
    filter(?opThemeMain_uri=<http://publications.europa.eu/ontology/cdm#concept_op_theme>)
    FILTER(langMatches(lang(?opTheme), "en")).
    filter not exists {
    # ?opTheme_uri skos:broader ?broader
    }    }ORDER BY ?opThemeMain ?opTheme
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['opThemeMain',
#    'opThemeMain_uri',
#    'opTheme',
#    'opTheme_uri',
#    'opTheme_dateCreated']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Activities of the European Union'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/A'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Economy — Finance'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/E'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal', 'xml:lang': 'en', 'value': 'Energy'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/J'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Environment — Ecology'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/L'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'External relations'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/C'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Industry — Enterprise — Services'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/I'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Information — Education — Culture — Sport'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/G'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Law and justice'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/B'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Scientific and technical research'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/M'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal', 'xml:lang': 'en', 'value': 'Social'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/F'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal', 'xml:lang': 'en', 'value': 'Statistics'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/N'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Trade — Competition'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/D'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}},
#    {'opThemeMain': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'OP Theme concept'},
#     'opThemeMain_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#concept_op_theme'},
#     'opTheme': {'type': 'literal', 'xml:lang': 'en', 'value': 'Transport'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/K'},
#     'opTheme_dateCreated': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2014-11-26'}}]}}

# %%
uri='http://publications.europa.eu/resource/authority/pub-theme/H'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX cdm: <http://publications.europa.eu/ontology/cdm#>
SELECT DISTINCT ?opTheme ?opTheme_uri ?corporateBody ?corporateBody_uri ?opTheme_uri AS ?corporateBody_opTheme
where {{?publicationDocument_uri cdm:publication_general_is_about_concept_op_theme ?opTheme_uri;
        cdm:work_authored_by_agent ?corporateBody_uri.
        # ?opTheme_uri skos:prefLabel ?opTheme.
        # ?corporateBody_uri skos:prefLabel ?corporateBody.
       } 
       filter(?opTheme_uri=<"""+uri+""">)
       FILTER(langMatches(lang(?corporateBody), "en")).
       FILTER(langMatches(lang(?opTheme), "en")).
      }ORDER BY ?opTheme ?corporateBody
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [],
#   'vars': ['opTheme',
#    'opTheme_uri',
#    'corporateBody',
#    'corporateBody_uri',
#    'corporateBody_opTheme']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Community Plant Variety Office'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CPVO'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Consumers, Health, Agriculture and Food Executive Agency'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CHAFEA'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'DG X – Information, Communication, Culture and Audiovisual Media'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/DG10'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Delegation to North Macedonia'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/DEL_MKD'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate for Health and Food Audits and Analysis'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/FVO'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Parliamentary Research Services'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_RESEARCH'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for External Policies of the Union'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_EXTERN_POL'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Internal Market, Industry, Entrepreneurship and SMEs'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/GROW'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Climate Action'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CLIMA'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Communication'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/COMMU'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Environment'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ENV'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Health and Food Safety'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/SANTE'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Research and Innovation'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/RTD'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Internal Policies of the Union'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EP_INTERNAL_POL'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Agriculture and Rural Development'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/AGRI'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Neighbourhood and Enlargement Negotiations'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/NEAR'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Directorate-General for Maritime Affairs and Fisheries'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/MARE'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Central Bank'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ECB'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Commission'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/COM'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Committee of the Regions'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/COR'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Economic and Social Committee'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EESC'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Environment Agency'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EEA'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Institute for Gender Equality'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EIGE'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'European Investment Bank'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EIB'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Eurostat'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/ESTAT'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Executive Agency for Small and Medium-sized Enterprises'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/EASME'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for Environment and Sustainability'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/IES'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for Health and Consumer Protection'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/IHCP'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for Prospective Technological Studies'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/JRCSEV'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for Reference Materials and Measurements'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/JRCGEEL'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Institute for the Protection and Security of the Citizen'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/IPSC'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Joint Research Centre'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/JRC'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}},
#    {'opTheme': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Agriculture — Forestry — Fisheries'},
#     'opTheme_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'},
#     'corporateBody': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Publications Office'},
#     'corporateBody_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/PUBL'},
#     'corporateBody_opTheme': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/pub-theme/H'}}]}}

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/DEL_MKD'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            SELECT DISTINCT ?class
            where {{?s ?p ?o.
                    # ?s skos:inScheme ?class
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['class', 'label']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            SELECT DISTINCT ?class
            where {{?s rdfs:type ?class.
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['class']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'class': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution'}},
#    {'class': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'class': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#Organization'}},
#    {'class': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#Corporate'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            SELECT DISTINCT ?class
            where {{?s ?p ?o.
                    # ?o skos:inScheme ?class.
                    } 
                   filter(?p=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['class']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'class': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/'}},
#    {'class': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040'}},
#    {'class': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body'}},
#    {'class': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/'}},
#    {'class': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/CONSIL'}},
#    {'class': {'type': 'uri', 'value': 'file:///'}}]}}

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            SELECT DISTINCT ?s ?p ?o
            where {{?s ?p ?o.
                    #?o rdfs:type ?class.
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#Organization'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#Corporate'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/created'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2013-01-11'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#versionInfo'},
#     'o': {'type': 'literal', 'value': '20210616-0'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/CONSIL'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri', 'value': 'file:///'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'hu',
#      'value': 'A Tanács Főtitkársága'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'ga',
#      'value': 'Ardrúnaíocht na Comhairle'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'General Secretariat of the Council'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'sl',
#      'value': 'Generalni sekretariat Sveta'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'de',
#      'value': 'Generalsekretariat des Rates'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'da',
#      'value': 'Generalsekretariatet for Rådet'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'sk',
#      'value': 'Generálny sekretariát Rady'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'cs',
#      'value': 'Generální sekretariát Rady'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'hr',
#      'value': 'Glavno tajništvo Vijeća'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'mt',
#      'value': 'Is-Segretarjat Ġenerali tal-Kunsill'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'fi',
#      'value': 'Neuvoston pääsihteeristö'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'et',
#      'value': 'Nõukogu peasekretariaat'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'lv',
#      'value': 'Padomes Ģenerālsekretariāts'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'sv',
#      'value': 'Rådets generalsekretariat'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'nl',
#      'value': 'Secretariaat-generaal van de Raad'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'pt',
#      'value': 'Secretariado-Geral do Conselho'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'ro',
#      'value': 'Secretariatul General al Consiliului'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'es',
#      'value': 'Secretaría General del Consejo'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'fr',
#      'value': 'Secrétariat général du Conseil'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'it',
#      'value': 'Segretariato generale del Consiglio'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'pl',
#      'value': 'Sekretariat Generalny Rady'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'lt',
#      'value': 'Tarybos generalinis sekretoriatas'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'bg',
#      'value': 'Генералния секретар на Съвета'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'el',
#      'value': 'Γενική Γραμματεία του Συμβουλίου'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#startDate'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '1967-07-01'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body-classification/CB_EU'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#hasSite'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/site/JL'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri', 'value': 'http://lemon-model.net/lemon#context'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/PUB_CORP'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri', 'value': 'http://lemon-model.net/lemon#context'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri', 'value': 'http://lemon-model.net/lemon#context'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/IMMC'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2003/01/geo/wgs84_pos#location'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/place/BEL_BRU'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81040960'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81043864'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81043984'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81046379'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81051184'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81052312'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81055954'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81057074'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058384'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058386'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058389'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058390'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058392'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058394'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058395'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058399'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058400'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058401'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058405'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058407'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058415'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058416'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058418'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058424'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058426'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058427'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058428'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058431'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81037854'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81039935'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81041606'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81043887'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81053966'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058383'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058385'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058387'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058391'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058393'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058396'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058397'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058402'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058409'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058410'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058411'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058412'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058413'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058419'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058421'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058422'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058423'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058425'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058430'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#classification'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body-classification/CB_EU'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/dateAccepted'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2013-04-24'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/dateSubmitted'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2013-04-16'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#notation'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/ontology/euvoc#FD_010',
#      'value': 'SGC'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#notation'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/ontology/euvoc#PUB_CORP',
#      'value': 'SGC_1'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#notation'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/ontology/euvoc#WHOISWHO',
#      'value': 'CM_CRF_246812'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#topConceptOf'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#order'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '66'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#protocolLevel'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '2'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#status'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/concept-status/CURRENT'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlClassification'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body-classification/CB_EU'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89856624'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89861389'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89862368'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868985'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868986'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868987'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868988'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868989'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868991'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868992'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868993'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868994'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81051081'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058388'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058398'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058404'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058408'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058414'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058417'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058420'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058429'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlOrder'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89855083'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlProtocolLevel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868990'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlSubOrganizationOf'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89850728'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/homepage'},
#     'o': {'type': 'uri',
#      'value': 'https://www.consilium.europa.eu/en/general-secretariat'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CONSIL_SG.A'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CONSIL_SG.F'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_3052CS'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CONSIL_SG.E'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CONSIL_SG.G'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_205CS'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CS01094'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CS00205'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CS01135'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CONSIL_SG.B'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CONSIL_SG.C'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CONSIL_SG.D'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#identifier'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/resource/authority/use-context/WHOISWHO-institution-uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#identifier'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/resource/authority/use-context/ID_ENTITY',
#      'value': 'CONSIL_SG'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#subOrganizationOf'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#broader'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://purl.org/dc/elements/1.1/identifier'},
#     'o': {'type': 'literal', 'value': 'CONSIL_SG'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/authority-code'},
#     'o': {'type': 'literal', 'value': 'CONSIL_SG'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/deprecated'},
#     'o': {'type': 'literal', 'value': 'false'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/op-code'},
#     'o': {'type': 'literal', 'value': 'CONSIL_SG'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/start.use'},
#     'o': {'type': 'literal', 'value': '1967-07-01'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/op-code'},
#     'o': {'type': 'literal', 'value': 'CONSIL_SG'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/op-mapped-code'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81049126'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/op-mapped-code'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058403'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/op-mapped-code'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058406'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#concept'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1451'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#contactPoint'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89852988'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            SELECT DISTINCT ?class
            where {{?s ?p ?o.
                    # ?o rdfs:type ?class.
                    } 
                   filter(?p=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['class']},
#  'results': {'distinct': False, 'ordered': True, 'bindings': []}}

# %%
uri='http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            SELECT DISTINCT ?p ?o
            where {{?s ?p ?o.
                    #?o rdfs:type ?class.
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#Organization'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#Corporate'}},
#    {'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/created'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2013-01-11'}},
#    {'p': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#versionInfo'},
#     'o': {'type': 'literal', 'value': '20210616-0'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/CONSIL'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri', 'value': 'file:///'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'hu',
#      'value': 'A Tanács Főtitkársága'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'ga',
#      'value': 'Ardrúnaíocht na Comhairle'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'General Secretariat of the Council'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'sl',
#      'value': 'Generalni sekretariat Sveta'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'de',
#      'value': 'Generalsekretariat des Rates'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'da',
#      'value': 'Generalsekretariatet for Rådet'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'sk',
#      'value': 'Generálny sekretariát Rady'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'cs',
#      'value': 'Generální sekretariát Rady'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'hr',
#      'value': 'Glavno tajništvo Vijeća'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'mt',
#      'value': 'Is-Segretarjat Ġenerali tal-Kunsill'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'fi',
#      'value': 'Neuvoston pääsihteeristö'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'et',
#      'value': 'Nõukogu peasekretariaat'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'lv',
#      'value': 'Padomes Ģenerālsekretariāts'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'sv',
#      'value': 'Rådets generalsekretariat'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'nl',
#      'value': 'Secretariaat-generaal van de Raad'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'pt',
#      'value': 'Secretariado-Geral do Conselho'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'ro',
#      'value': 'Secretariatul General al Consiliului'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'es',
#      'value': 'Secretaría General del Consejo'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'fr',
#      'value': 'Secrétariat général du Conseil'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'it',
#      'value': 'Segretariato generale del Consiglio'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'pl',
#      'value': 'Sekretariat Generalny Rady'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'lt',
#      'value': 'Tarybos generalinis sekretoriatas'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'bg',
#      'value': 'Генералния секретар на Съвета'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'el',
#      'value': 'Γενική Γραμματεία του Συμβουλίου'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#startDate'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '1967-07-01'}},
#    {'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body-classification/CB_EU'}},
#    {'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#hasSite'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/site/JL'}},
#    {'p': {'type': 'uri', 'value': 'http://lemon-model.net/lemon#context'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/PUB_CORP'}},
#    {'p': {'type': 'uri', 'value': 'http://lemon-model.net/lemon#context'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/EURLEX'}},
#    {'p': {'type': 'uri', 'value': 'http://lemon-model.net/lemon#context'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/use-context/IMMC'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2003/01/geo/wgs84_pos#location'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/place/BEL_BRU'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81040960'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81043864'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81043984'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81046379'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81051184'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81052312'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81055954'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81057074'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058384'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058386'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058389'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058390'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058392'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058394'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058395'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058399'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058400'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058401'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058405'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058407'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058415'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058416'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058418'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058424'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058426'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058427'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058428'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#altLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058431'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81037854'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81039935'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81041606'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81043887'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81053966'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058383'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058385'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058387'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058391'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058393'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058396'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058397'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058402'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058409'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058410'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058411'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058412'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058413'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058419'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058421'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058422'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058423'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058425'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2008/05/skos-xl#prefLabel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058430'}},
#    {'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#classification'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body-classification/CB_EU'}},
#    {'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/dateAccepted'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2013-04-24'}},
#    {'p': {'type': 'uri', 'value': 'http://purl.org/dc/terms/dateSubmitted'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#date',
#      'value': '2013-04-16'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#notation'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/ontology/euvoc#FD_010',
#      'value': 'SGC'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#notation'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/ontology/euvoc#PUB_CORP',
#      'value': 'SGC_1'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#notation'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/ontology/euvoc#WHOISWHO',
#      'value': 'CM_CRF_246812'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#topConceptOf'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#order'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '66'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#protocolLevel'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'value': '2'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#status'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/concept-status/CURRENT'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlClassification'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body-classification/CB_EU'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89856624'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89861389'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89862368'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868985'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868986'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868987'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868988'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868989'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868991'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868992'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868993'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlHasSubOrganization'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868994'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81051081'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058388'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058398'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058404'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058408'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058414'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058417'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058420'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlNotation'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058429'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlOrder'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89855083'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlProtocolLevel'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89868990'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#xlSubOrganizationOf'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89850728'}},
#    {'p': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/homepage'},
#     'o': {'type': 'uri',
#      'value': 'https://www.consilium.europa.eu/en/general-secretariat'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CONSIL_SG.A'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CONSIL_SG.F'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_3052CS'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CONSIL_SG.E'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CONSIL_SG.G'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_205CS'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CS01094'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CS00205'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CS01135'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CONSIL_SG.B'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CONSIL_SG.C'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#hasSubOrganization'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/directory/organization/CONSIL/CONSIL_CONSIL_SG.D'}},
#    {'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#identifier'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/resource/authority/use-context/WHOISWHO-institution-uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL'}},
#    {'p': {'type': 'uri', 'value': 'http://www.w3.org/ns/org#identifier'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://publications.europa.eu/resource/authority/use-context/ID_ENTITY',
#      'value': 'CONSIL_SG'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#subOrganizationOf'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#broader'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL'}},
#    {'p': {'type': 'uri',
#      'value': 'http://purl.org/dc/elements/1.1/identifier'},
#     'o': {'type': 'literal', 'value': 'CONSIL_SG'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/authority-code'},
#     'o': {'type': 'literal', 'value': 'CONSIL_SG'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/deprecated'},
#     'o': {'type': 'literal', 'value': 'false'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/op-code'},
#     'o': {'type': 'literal', 'value': 'CONSIL_SG'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/start.use'},
#     'o': {'type': 'literal', 'value': '1967-07-01'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/op-code'},
#     'o': {'type': 'literal', 'value': 'CONSIL_SG'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/op-mapped-code'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81049126'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/op-mapped-code'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058403'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/op-mapped-code'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b81058406'}},
#    {'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#concept'},
#     'o': {'type': 'uri', 'value': 'http://eurovoc.europa.eu/1451'}},
#    {'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#contactPoint'},
#     'o': {'type': 'bnode', 'value': 'nodeID://b89852988'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            SELECT DISTINCT ?class
            where {{?s ?p ?o.
                    # ?o rdfs:type ?class.
                    } 
                   filter(?p=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['class']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'class': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#ATTO_FD_040'}},
#    {'class': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'class': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#institution'}},
#    {'class': {'type': 'uri',
#      'value': 'http://www.w3.org/ns/org#Organization'}},
#    {'class': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/euvoc#Corporate'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#legislation_complementary'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Class'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#legislation_complementary'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#label'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': 'Complementary legislation'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#legislation_complementary'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#comment'},
#     'o': {'type': 'typed-literal',
#      'datatype': 'http://www.w3.org/2001/XMLSchema#string',
#      'value': ' Complementary legislation (= sector 4)'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#legislation_complementary'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2000/01/rdf-schema#subClassOf'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#resource_legal'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?example ?example_uri
            where {{?s ?p ?example_uri.
                    # ?example_uri skos:prefLabel ?example.
                    } 
                   filter(?p=<"""+uri+""">).
                   FILTER(langMatches(lang(?example), "en")).
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['example', 'example_uri']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'example': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Council of the European Union-General Secretariat'},
#     'example_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'}},
#    {'example': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Council of the EC - Secretary-General'},
#     'example_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CONS-SG'}},
#    {'example': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'General Secretariat of the Council'},
#     'example_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/corporate-body/CONSIL_SG'}},
#    {'example': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Council of Europe - Secretary-General'},
#     'example_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CEU-SG'}},
#    {'example': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Luxembourg - Government'},
#     'example_uri': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/L-G'}}]}}

# %%
uri='http://publications.europa.eu/resource/authority/fd_040/CUE-SG'

# %%
http://www.w3.org/1999/02/22-rdf-syntax-ns#type
http://www.w3.org/2004/02/skos/core#prefLabel
    FILTER(langMatches(lang(?opTheme), "en")).

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX rdfs: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
            SELECT DISTINCT ?propertyRange ?class
            where {{?propertyRange_URI rdfs:type ?class;
                                    skos:prefLabel ?propertyRange
                    } 
                   filter(?propertyRange_URI=<"""+uri+""">).
                   FILTER(langMatches(lang(?propertyRange), "en")).
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['propertyRange', 'class']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'propertyRange': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Council of the European Union-General Secretariat'},
#     'class': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#ATTO_FD_040'}},
#    {'propertyRange': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Council of the European Union-General Secretariat'},
#     'class': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")
#sparql = SPARQLWrapper("https://data.europa.eu/sparql")
sparql.setQuery("""
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
            SELECT DISTINCT ?s ?p ?o
            where {{?s ?p ?o.
                    } 
                   filter(?s=<"""+uri+""">)
                   }
    """)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
results
# Out:
# {'head': {'link': [], 'vars': ['s', 'p', 'o']},
#  'results': {'distinct': False,
#   'ordered': True,
#   'bindings': [{'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/cdm#ATTO_FD_040'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#     'o': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#Concept'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#inScheme'},
#     'o': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'bg',
#      'value': 'Съвет на Европейския съюз'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'fr',
#      'value': "Conseil de l'Union européenne - secrétariat général"}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'mt',
#      'value': 'il-Kunsill tal-Unjoni Ewropea - Segretarju-Ġenerali'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'hu',
#      'value': 'Az Európai Unió Tanácsa – főtitkárság'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'ga',
#      'value': 'Comhairle an Aontais Eorpaigh - an Ardrúnaíocht'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'es',
#      'value': 'Consejo de la Unión Europea - secretaría general'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'pt',
#      'value': 'Conselho da União Europeia - secretariado-geral'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'ro',
#      'value': 'Consiliul Uniunii Europene - Secretariat General'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'en',
#      'value': 'Council of the European Union-General Secretariat'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'lv',
#      'value': 'Eiropas Savienības Padome - ģenerālsekretārs'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'et',
#      'value': 'Euroopa Liidu Nõukogu peasekretariaat'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'fi',
#      'value': 'Euroopan unionin neuvosto-pääsihteeristö'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'sv',
#      'value': 'Europeiska unionens råd - generalsekretariatet'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'cs',
#      'value': 'Generální tajemník Rady Evropské unie'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'nl',
#      'value': 'Raad van de Europese Unie - secretariaat-generaal'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'sk',
#      'value': 'Rada Európskej únie - generálny sekretariát'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'pl',
#      'value': 'Rada Unii Europejskiej - Sekretariat Generalny'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'de',
#      'value': 'Rat der Europäischen Union - Generalsekretariat'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'sl',
#      'value': 'Svet Evropske Unije – generalni sekretariat'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'hr',
#      'value': 'Vijeće Europske unije – Glavno tajništvo'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'it',
#      'value': "Consiglio dell'Unione europea, segretariato generale"}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'da',
#      'value': 'Rådet for Den Europæiske Union - Generalsekretariatet'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'lt',
#      'value': 'Europos Sąjungos Taryba - Generalinis sekretoriatas'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://www.w3.org/2004/02/skos/core#prefLabel'},
#     'o': {'type': 'literal',
#      'xml:lang': 'el',
#      'value': 'Συμβούλιο της Ευρωπαϊκής Ένωσης - Γενική Γραμματεία'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://purl.org/dc/elements/1.1/identifier'},
#     'o': {'type': 'literal', 'value': 'CUE-SG'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/ontology/authority/op-code'},
#     'o': {'type': 'literal', 'value': 'CUE-SG'}},
#    {'s': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/fd_040/CUE-SG'},
#     'p': {'type': 'uri',
#      'value': 'http://publications.europa.eu/resource/authority/op-code'},
#     'o': {'type': 'literal', 'value': 'CUE-SG'}}]}}

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX : <http://publications.europa.eu/ontology/cdm#>

    SELECT DISTINCT ?class ?class_uri ?class_comment ?property ?property_uri ?property_comment
    WHERE 
    {{ ?property_uri rdfs:domain ?class_uri;
         rdfs:label ?property;
         rdfs:comment ?property_comment.
    # ?class_uri rdfs:label ?class;
        rdfs:comment ?class_comment. 
    }filter(?class_uri=<"""+uri+""">)
    }ORDER BY ?class ?property
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results

# %%
sparql = SPARQLWrapper("https://publications.europa.eu/webapi/rdf/sparql")

sparql.setQuery("""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX : <http://publications.europa.eu/ontology/cdm#>

    SELECT DISTINCT ?class ?class_uri ?class_comment ?property ?property_uri ?property_comment
    WHERE 
    {{ ?property_uri rdfs:domain ?class_uri;
         rdfs:label ?property;
         rdfs:comment ?property_comment.
    # ?class_uri rdfs:label ?class;
        rdfs:comment ?class_comment. 
    }filter(?class_uri=<"""+uri+""">)
    }ORDER BY ?class ?property
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

results
